# %%
# US Open Pool Scraper

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import csv

# %%
url = "https://cuescore.com/tournament/US+Open+9-ball+Championship+2019/5185877"
my_page = requests.get(url)

# %%
# Use content 
soup = BeautifulSoup(my_page.content, "html.parser")

# %%
# Get div of interest
table = soup.find('table', attrs={'class' : 'score'})

# %%
table
# Out:
# <table class="score" data-format="2"><tbody><tr class="round" data-roundno="1" id="round-1"><th colspan="100" style="padding: 0; padding-top: 20px;"><div class="roundHead material"><h3>Round 1</h3> <div class="distance"><span>Race to</span> <span class="distanceHolder">11</span> </div> </div> </th></tr>
# <tr class="match public finished" data-matchno="1" data-roundno="1" data-starttime="2019-04-21 15:43:05" id="match-5215697">
# <td class="matchno" id="match-1">1</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Jayson Shaw
# "><div><div class="flag"><img alt="Scotland" src="/img/flags/png-country-4x2-none/res-40x30/gb-sct.png" title="Scotland"/></div><div class="name">Jayson Shaw</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="0"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Marcus Westen
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name loser">Marcus Westen</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:43"><span class="date">Sun</span> <span class="time">08:43</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="2" data-roundno="1" data-starttime="2019-04-21 15:55:07" id="match-5215698">
# <td class="matchno" id="match-2">2</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Tom Staveley
# "><div><div class="flag"><img alt="United Kingdom" src="/img/flags/png-country-4x2-none/res-40x30/gb.png" title="United Kingdom"/></div><div class="name">Tom Staveley</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="4"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Jason Williams
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Jason Williams</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 2 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="3" data-roundno="1" data-starttime="2019-04-21 15:55:09" id="match-5215699">
# <td class="matchno" id="match-3">3</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Hunter Lombardo
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name">Hunter Lombardo</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="10"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Kosuke Tojo
# "><div><div class="flag"><img alt="Japan" src="/img/flags/png-country-4x2-none/res-40x30/jp.png" title="Japan"/></div><div class="name loser">Kosuke Tojo</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 3 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="4" data-roundno="1" data-starttime="2019-04-21 15:55:13" id="match-5215700">
# <td class="matchno" id="match-4">4</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Radwan Jameel R Sorouji
# "><div><div class="flag"><img alt="Saudi Arabia" src="/img/flags/png-country-4x2-none/res-40x30/sa.png" title="Saudi Arabia"/></div><div class="name">Radwan Jameel R Sorouji</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="4"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Chad Rhodes
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Chad Rhodes</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 4 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="5" data-roundno="1" data-starttime="2019-04-21 15:55:14" id="match-5215701">
# <td class="matchno" id="match-5">5</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Naoyuki Oi
# "><div><div class="flag"><img alt="Japan" src="/img/flags/png-country-4x2-none/res-40x30/jp.png" title="Japan"/></div><div class="name loser">Naoyuki Oi</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="9"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Marco Vignola
# "><div><div class="flag"><img alt="Italy" src="/img/flags/png-country-4x2-none/res-40x30/it.png" title="Italy"/></div><div class="name">Marco Vignola</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 5 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="6" data-roundno="1" data-starttime="2019-04-21 15:55:15" id="match-5215702">
# <td class="matchno" id="match-6">6</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Alex Montpellier
# "><div><div class="flag"><img alt="France" src="/img/flags/png-country-4x2-none/res-40x30/fr.png" title="France"/></div><div class="name">Alex Montpellier</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="9"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Jason Klatt
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name loser">Jason Klatt</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R3</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 6 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="7" data-roundno="1" data-starttime="2019-04-21 15:55:16" id="match-5215703">
# <td class="matchno" id="match-7">7</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Martin Daigle
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name">Martin Daigle</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="3"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Patrick Flemming
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Patrick Flemming</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 7 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="8" data-roundno="1" data-starttime="2019-04-21 15:55:16" id="match-5215704">
# <td class="matchno" id="match-8">8</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Angelo Salzano
# "><div><div class="flag"><img alt="Italy" src="/img/flags/png-country-4x2-none/res-40x30/it.png" title="Italy"/></div><div class="name loser">Angelo Salzano</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="1"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Corey Deuel
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name">Corey Deuel</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R4</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 8 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="9" data-roundno="1" data-starttime="2019-04-21 15:55:16" id="match-5215705">
# <td class="matchno" id="match-9">9</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Petri Makkonen
# "><div><div class="flag"><img alt="Finland" src="/img/flags/png-country-4x2-none/res-40x30/fi.png" title="Finland"/></div><div class="name">Petri Makkonen</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="6"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Marcel Price
# "><div><div class="flag"><img alt="Wales" src="/img/flags/png-country-4x2-none/res-40x30/gb-wls.png" title="Wales"/></div><div class="name loser">Marcel Price</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 9 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="10" data-roundno="1" data-starttime="2019-04-21 15:49:34" id="match-5215706">
# <td class="matchno" id="match-10">10</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Peter Busarac
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name">Peter Busarac</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="6"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Amar Kang
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Amar Kang</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:49"><span class="date">Sun</span> <span class="time">08:49</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 10 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="11" data-roundno="1" data-starttime="2019-04-21 15:50:03" id="match-5215707">
# <td class="matchno" id="match-11">11</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Franklin Hernandez
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name">Franklin Hernandez</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="2"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Ellis Brown
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Ellis Brown</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:50"><span class="date">Sun</span> <span class="time">08:50</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 11 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="12" data-roundno="1" data-starttime="2019-04-21 17:10:57" id="match-5215708">
# <td class="matchno" id="match-12">12</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Paul Juarez
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Paul Juarez</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="5"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Justin Bergman
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name">Justin Bergman</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 10:10"><span class="date">Sun</span> <span class="time">10:10</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="13" data-roundno="1" data-starttime="2019-04-21 15:50:05" id="match-5215709">
# <td class="matchno" id="match-13">13</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="James Aranas
# "><div><div class="flag"><img alt="Philippines" src="/img/flags/png-country-4x2-none/res-40x30/ph.png" title="Philippines"/></div><div class="name">James Aranas</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="0"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Roderick Malone
# "><div><div class="flag"><img alt="Bahamas" src="/img/flags/png-country-4x2-none/res-40x30/bs.png" title="Bahamas"/></div><div class="name loser">Roderick Malone</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:50"><span class="date">Sun</span> <span class="time">08:50</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 12 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="14" data-roundno="1" data-starttime="2019-04-21 15:50:06" id="match-5215710">
# <td class="matchno" id="match-14">14</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="MASATO YOSHIOKA
# "><div><div class="flag"><img alt="Japan" src="/img/flags/png-country-4x2-none/res-40x30/jp.png" title="Japan"/></div><div class="name">MASATO YOSHIOKA</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="9"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Erik  Hjorleifson
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name loser">Erik  Hjorleifson</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R4</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:50"><span class="date">Sun</span> <span class="time">08:50</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 13 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="15" data-roundno="1" data-starttime="2019-04-21 15:49:23" id="match-5215711">
# <td class="matchno" id="match-15">15</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Stephen Folan
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name">Stephen Folan</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="3"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Jochen Kluge
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name loser">Jochen Kluge</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:49"><span class="date">Sun</span> <span class="time">08:49</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 14 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="16" data-roundno="1" data-starttime="2019-04-21 15:50:06" id="match-5215712">
# <td class="matchno" id="match-16">16</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Jon Demet
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Jon Demet</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="2"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Toru Kurabayashi
# "><div><div class="flag"><img alt="Japan" src="/img/flags/png-country-4x2-none/res-40x30/jp.png" title="Japan"/></div><div class="name">Toru Kurabayashi</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:50"><span class="date">Sun</span> <span class="time">08:50</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 15 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="17" data-roundno="1" data-starttime="2019-04-21 15:50:08" id="match-5215713">
# <td class="matchno" id="match-17">17</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Fedor Gorst
# "><div><div class="flag"><img alt="Russia" src="/img/flags/png-country-4x2-none/res-40x30/ru.png" title="Russia"/></div><div class="name">Fedor Gorst</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R4</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="1"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Gary Onomura
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Gary Onomura</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:50"><span class="date">Sun</span> <span class="time">08:50</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 16 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="18" data-roundno="1" data-starttime="2019-04-21 15:55:00" id="match-5215714">
# <td class="matchno" id="match-18">18</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Stanley Walton
# "><div><div class="flag"><img alt="Cayman Islands" src="/img/flags/png-country-4x2-none/res-40x30/ky.png" title="Cayman Islands"/></div><div class="name loser">Stanley Walton</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="8"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Paul Duell
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name">Paul Duell</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 17 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="19" data-roundno="1" data-starttime="2019-04-21 15:51:10" id="match-5215715">
# <td class="matchno" id="match-19">19</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Omar Al Shaheen
# "><div><div class="flag"><img alt="Kuwait" src="/img/flags/png-country-4x2-none/res-40x30/kw.png" title="Kuwait"/></div><div class="name">Omar Al Shaheen</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="7"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Bradley Shearer
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Bradley Shearer</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:51"><span class="date">Sun</span> <span class="time">08:51</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 18 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="20" data-roundno="1" data-starttime="2019-04-21 15:51:10" id="match-5215716">
# <td class="matchno" id="match-20">20</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Amer Al-Darbani
# "><div><div class="flag"><img alt="Saudi Arabia" src="/img/flags/png-country-4x2-none/res-40x30/sa.png" title="Saudi Arabia"/></div><div class="name loser">Amer Al-Darbani</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="6"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Mateusz Sniegocki
# "><div><div class="flag"><img alt="Poland" src="/img/flags/png-country-4x2-none/res-40x30/pl.png" title="Poland"/></div><div class="name">Mateusz Sniegocki</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R4</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:51"><span class="date">Sun</span> <span class="time">08:51</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 19 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="21" data-roundno="1" data-starttime="2019-04-21 15:51:16" id="match-5215717">
# <td class="matchno" id="match-21">21</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Da-Li Lin
# "><div><div class="flag"><img alt="Chinese Taipei" src="/img/flags/png-country-4x2-none/res-40x30/chinesetaipei.png" title="Chinese Taipei"/></div><div class="name">Da-Li Lin</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R3</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="8"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Fabio Rizzi
# "><div><div class="flag"><img alt="France" src="/img/flags/png-country-4x2-none/res-40x30/fr.png" title="France"/></div><div class="name loser">Fabio Rizzi</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:51"><span class="date">Sun</span> <span class="time">08:51</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 20 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="22" data-roundno="1" data-starttime="2019-04-21 15:51:17" id="match-5215718">
# <td class="matchno" id="match-22">22</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Jason Hitzfeld
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Jason Hitzfeld</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="0"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Jeremy jones
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name">Jeremy jones</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:51"><span class="date">Sun</span> <span class="time">08:51</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 21 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="23" data-roundno="1" data-starttime="2019-04-21 15:51:18" id="match-5215719">
# <td class="matchno" id="match-23">23</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Philipp Stojanovic
# "><div><div class="flag"><img alt="" src="..." title=""/></div><div class="name">Philipp Stojanovic</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="3"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Steve Van Ness
# "><div><div class="flag"><img alt="United States" src="/img/flags/png-country-4x2-none/res-40x30/us.png" title="United States"/></div><div class="name loser">Steve Van Ness</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:51"><span class="date">Sun</span> <span class="time">08:51</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 22 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="24" data-roundno="1" data-starttime="2019-04-21 15:55:23" id="match-5215720">
# <td class="matchno" id="match-24">24</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Dalibor Nikolin
# "><div><div class="flag"><img alt="Serbia" src="/img/flags/png-country-4x2-none/res-40x30/rs.png" title="Serbia"/></div><div class="name loser">Dalibor Nikolin</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="3"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Francisco Sanchez Ruiz
# "><div><div class="flag"><img alt="Spain" src="/img/flags/png-country-4x2-none/res-40x30/es.png" title="Spain"/></div><div class="name">Francisco Sanchez Ruiz</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R1</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="21.Apr 2019 08:55"><span class="date">Sun</span> <span class="time">08:55</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 23 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="25" data-roundno="1" data-starttime="2019-04-21 15:51:18" id="match-5215721">
# ...
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="7"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Wu Jiaqing
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name">Wu Jiaqing</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="25.Apr 2019 11:22"><span class="date">Thu</span> <span class="time">11:22</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr><tr class="round" data-roundno="7" id="round-7"><th colspan="100" style="padding: 0; padding-top: 20px;"><div class="roundHead material"><h3>Quarter final</h3> <div class="distance"><span>Race to</span> <span class="distanceHolder">11</span> </div> </div> </th></tr>
# <tr class="match public finished" data-matchno="497" data-roundno="7" data-starttime="2019-04-25 20:48:00" id="match-5216193">
# <td class="matchno" id="match-497">497</td>
# <td class="info"><span class="comment" data-comment="Session 2 | Match 1" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Joshua Filler
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name">Joshua Filler</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="4"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Francisco Sanchez Ruiz
# "><div><div class="flag"><img alt="Spain" src="/img/flags/png-country-4x2-none/res-40x30/es.png" title="Spain"/></div><div class="name loser">Francisco Sanchez Ruiz</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="25.Apr 2019 13:48"><span class="date">Thu</span> <span class="time">13:48</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="498" data-roundno="7" data-starttime="2019-04-25 23:00:00" id="match-5216194">
# <td class="matchno" id="match-498">498</td>
# <td class="info"><span class="comment" data-comment="Session 2 | Match 2" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Jeffrey De Luna
# "><div><div class="flag"><img alt="Philippines" src="/img/flags/png-country-4x2-none/res-40x30/ph.png" title="Philippines"/></div><div class="name">Jeffrey De Luna</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="5"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Alex Pagulayan
# "><div><div class="flag"><img alt="Canada" src="/img/flags/png-country-4x2-none/res-40x30/ca.png" title="Canada"/></div><div class="name loser">Alex Pagulayan</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="25.Apr 2019 16:00"><span class="date">Thu</span> <span class="time">16:00</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="499" data-roundno="7" data-starttime="2019-04-26 01:00:00" id="match-5216195">
# <td class="matchno" id="match-499">499</td>
# <td class="info"><span class="comment" data-comment="Session 3 | Match 1" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Liu Haitao
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name loser">Liu Haitao</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="10"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Chang Yu-Lung
# "><div><div class="flag"><img alt="Chinese Taipei" src="/img/flags/png-country-4x2-none/res-40x30/chinesetaipei.png" title="Chinese Taipei"/></div><div class="name">Chang Yu-Lung</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="25.Apr 2019 18:00"><span class="date">Thu</span> <span class="time">18:00</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="500" data-roundno="7" data-starttime="2019-04-26 03:57:00" id="match-5216196">
# <td class="matchno" id="match-500">500</td>
# <td class="info"><span class="comment" data-comment="Session 3 | Match 2" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Wang Can
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name loser">Wang Can</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="0"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Wu Jiaqing
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name">Wu Jiaqing</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="25.Apr 2019 20:57"><span class="date">Thu</span> <span class="time">20:57</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr><tr class="round" data-roundno="8" id="round-8"><th colspan="100" style="padding: 0; padding-top: 20px;"><div class="roundHead material"><h3>Semi final</h3> <div class="distance"><span>Race to</span> <span class="distanceHolder">11</span> </div> </div> </th></tr>
# <tr class="match public finished" data-matchno="501" data-roundno="8" data-starttime="2019-04-26 16:00:00" id="match-5216197">
# <td class="matchno" id="match-501">501</td>
# <td class="info"><span class="comment" data-comment="Session 1 | Match 1" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Joshua Filler
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name">Joshua Filler</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="8"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Jeffrey De Luna
# "><div><div class="flag"><img alt="Philippines" src="/img/flags/png-country-4x2-none/res-40x30/ph.png" title="Philippines"/></div><div class="name loser">Jeffrey De Luna</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R2</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="26.Apr 2019 09:00"><span class="date">Fri</span> <span class="time">09:00</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr> <tr class="match public finished" data-matchno="502" data-roundno="8" data-starttime="2019-04-26 18:30:00" id="match-5216198">
# <td class="matchno" id="match-502">502</td>
# <td class="info"><span class="comment" data-comment="Session 1 | Match 2" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Chang Yu-Lung
# "><div><div class="flag"><img alt="Chinese Taipei" src="/img/flags/png-country-4x2-none/res-40x30/chinesetaipei.png" title="Chinese Taipei"/></div><div class="name loser">Chang Yu-Lung</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA"><div class="scoreboard"><input class="number" readonly="" type="text" value="5"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">11</span> &nbsp;</td> -->
# <td class="scoreB winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="11"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Wu Jiaqing
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name">Wu Jiaqing</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts"></div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="26.Apr 2019 11:30"><span class="date">Fri</span> <span class="time">11:30</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr><tr class="round" data-roundno="9" id="round-9"><th colspan="100" style="padding: 0; padding-top: 20px;"><div class="roundHead material"><h3>Final</h3> <div class="distance"><span>Race to</span> <span class="distanceHolder">13</span> </div> </div> </th></tr>
# <tr class="match public finished" data-matchno="503" data-roundno="9" data-starttime="2019-04-26 21:40:00" id="match-5216199">
# <td class="matchno" id="match-503">503</td>
# <td class="info"><span class="comment" data-comment="" onclick="Cue.Match.showComment(event, this);"> </span><a class="videoLink" href="" target="_blank"> </a></td>
# <td class="playerA" onclick="Cue.Match.selectPlayer(this);" title="Joshua Filler
# "><div><div class="flag"><img alt="Germany" src="/img/flags/png-country-4x2-none/res-40x30/de.png" title="Germany"/></div><div class="name">Joshua Filler</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R3</div></div></td>
# <td class="setScoreA"></td>
# <td class="scoreA winner"><div class="scoreboard"><input class="number" readonly="" type="text" value="13"/></div></td>
# <td class="separator"><div class="separatorButton" onclick="Cue.Match.toggleMatchDetails(this);" title="Click to expand match-details."></div></td>
# <!--	<td class="distance"><span class="value">13</span> &nbsp;</td> -->
# <td class="scoreB"><div class="scoreboard"><input class="number" readonly="" type="text" value="10"/></div></td>
# <td class="setScoreB"></td>
# <td class="playerB" onclick="Cue.Match.selectPlayer(this);" title="Wu Jiaqing
# "><div><div class="flag"><img alt="China" src="/img/flags/png-country-4x2-none/res-40x30/cn.png" title="China"/></div><div class="name loser">Wu Jiaqing</div> <div class="handicap"></div><div class="lagWin" rel="tooltip" title="Winner of the lag"></div><div class="runouts" rel="tooltip" title="Runouts">R3</div></div></td>
# <td class="venue"></td>
# <td class="time center" onclick="Cue.Match.selectTime(this);" rel="tooltip" title="26.Apr 2019 14:40"><span class="date">Fri</span> <span class="time">14:40</span> </td>
# <td class="table" onclick="Cue.Match.selectTable(this);">Table 1 </td>
# <td class="matchstatus hide" value="2"></td>
# </tr></tbody></table>

# %%
trtags = table.find_all('tr',  attrs={'class' : 'match'})

# Helper Function to get information 
def get_info(winner, winnerScore, loser, loserScore): 
    result = {}
    result["winner"] = winner.find('div', attrs={'class': 'name'}).text.strip()
    result["winnerNationality"] = winner.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["winnerRunouts"] = winner.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["winnerRunouts"] == '':
        result["winnerRunouts"] = 0
    result["winnerScore"] = winnerScore

    result["loser"] = loser.find('div', attrs={'class': 'name'}).text.strip()
    result["loserNationality"] = loser.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["loserRunouts"] = loser.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["loserRunouts"] == '':
        result["loserRunouts"] = 0
    result["loserScore"] = loserScore
    return(result)

results_lst = []
for row in trtags: 
    
    # Determine winner and loser
    playerAScore = row.find('td', attrs={'class': 'scoreA'}).find('input').get("value")
    playerBScore = row.find('td', attrs={'class': 'scoreB'}).find('input').get("value")
    if playerAScore > playerBScore: 
        winner = row.find('td', attrs={'class': 'playerA'})
        loser = row.find('td', attrs={'class': 'playerB'})
        result = get_info(winner, playerAScore, loser, playerBScore)
    else: 
        winner = row.find('td', attrs={'class': 'playerB'})
        loser = row.find('td', attrs={'class': 'playerA'})
        result = get_info(winner, playerBScore, loser, playerAScore)
        
    # Get Match Number
    result['matchNum'] = row.find('td', attrs={'class': 'matchno'}).text.strip()
    # Get Match Time
    
    result['matchTime'] = row.find('td', attrs={'class': 'time'}).get('title')
    
     
    results_lst.append(result)

# %%
usopen = pd.DataFrame(results_lst)

# %%
usopen["tournament"] = "US Open 9 Ball Championship 2019"

# %%
usopen
# Out:
#               winner winnerNationality winnerRunouts winnerScore  \
# 0        Jayson Shaw          Scotland             2          11
# 1     Jason Williams     United States             0           4
# 2    Hunter Lombardo     United States             0          11
# 3        Chad Rhodes     United States             0           4
# 4         Naoyuki Oi             Japan             0           9
# ..               ...               ...           ...         ...
# 498    Chang Yu-Lung    Chinese Taipei             0          11
# 499       Wu Jiaqing             China             0          11
# 500  Jeffrey De Luna       Philippines             2           8
# 501    Chang Yu-Lung    Chinese Taipei             0           5
# 502    Joshua Filler           Germany             3          13
#
#                        loser loserNationality loserRunouts loserScore  \
# 0              Marcus Westen          Germany            0          0
# 1               Tom Staveley   United Kingdom            1         11
# 2                Kosuke Tojo            Japan            2         10
# 3    Radwan Jameel R Sorouji     Saudi Arabia            0         11
# 4              Marco Vignola            Italy            0         11
# ..                       ...              ...          ...        ...
# 498               Liu Haitao            China            0         10
# 499                 Wang Can            China            0          0
# 500            Joshua Filler          Germany            0         11
# 501               Wu Jiaqing            China            0         11
# 502               Wu Jiaqing            China            3         10
#
#     matchNum          matchTime                        tournament
# 0          1  21.Apr 2019 08:43  US Open 9 Ball Championship 2019
# 1          2  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 2          3  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 3          4  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 4          5  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# ..       ...                ...                               ...
# 498      499  25.Apr 2019 18:00  US Open 9 Ball Championship 2019
# 499      500  25.Apr 2019 20:57  US Open 9 Ball Championship 2019
# 500      501  26.Apr 2019 09:00  US Open 9 Ball Championship 2019
# 501      502  26.Apr 2019 11:30  US Open 9 Ball Championship 2019
# 502      503  26.Apr 2019 14:40  US Open 9 Ball Championship 2019
#
# [503 rows x 11 columns]

# %%
players = pd.concat([usopen.winner, usopen.loser] )

# %%
players.value_counts()
# Out:
# Joshua Filler      11
# Wang Can           10
# Wu Jiaqing         10
# Marco Teutscher     9
# Jeffrey Ignacio     9
#                    ..
# Marcel Price        2
# Bryan Farah         2
# Kelii Chuberko      2
# Thomas Welle        2
# Roderick Malone     2
# Length: 256, dtype: int64

# %%
# How many players
nplayers = len(players.value_counts())
nplayers
# Out:
# 256

# %%
url = "https://cuescore.com/tournament/Turning+Stone+Classic+XXVII+Mid+Season+Championship/1284289"

# %%
# Plan 
    # Go to https://wpapool.com/ranking/ 
    # look at all the qualifying events
    # Scrape scores from Cuescore 
    # Get priors on Elo system 
    # Use Priors to predict future tournaments
