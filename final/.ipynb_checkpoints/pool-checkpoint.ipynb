# %% [markdown]
# # Pool Elo

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

# %%
data = pd.read_csv('data/predatorCLP.csv')

# %%
players = pd.concat([data.WinnerName, data.LoserName] )

# %%
players.value_counts()
# Out:
# Albin Ouschan        52
# Mieszko Fortunski    40
# Niels Feijen         36
# Billy Thorpe         33
# Marc Bijsterbosch    27
# Kelly Fisher         26
# Eklent Kaci          22
# David Alcaide        22
# Naoyuki Oi           21
# Alex Kazakis         15
# Chris Melling        15
# Roberto Gomez        14
# Kristina Tkach       12
# Ralf Souquet         12
# Casper Matikainen    12
# Denis Grabe           7
# Jasmin Ouschan        6
# Chris Robinson        6
# Darren Appleton       6
# dtype: int64

# %%
# How many players
nplayers = len(players.value_counts())
nplayers
# Out:
# 19

# %%
# Plot barplot
players.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Visualize Loser Racks
data.LoserRacks.value_counts().loc[range(0,5,1)].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Validate Even games per table 
data.Table.value_counts()
# Out:
# 2    96
# 1    96
# Name: Table, dtype: int64

# %%
# Validate Games per group 
data.Group.value_counts()
# Out:
# 8    24
# 7    24
# 6    24
# 5    24
# 4    24
# 3    24
# 2    24
# 1    24
# Name: Group, dtype: int64

# %%
# Validate 16 Semi Finals
data.isSemi.value_counts()
# Out:
# 0    176
# 1     16
# Name: isSemi, dtype: int64

# %%
# Validate 8 Finals
data.isFinal.value_counts()
# Out:
# 0    184
# 1      8
# Name: isFinal, dtype: int64

# %%
# Elo Rating System 
# Constants
INITIAL_RATING = 1500
ELO_WIDTH = 400
K = 50

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

# %%
def run_tournament(data=data, INITIAL_RATING = INITIAL_RATING, ELO_WIDTH = ELO_WIDTH, k=K):
    
    # Initialize Elo Ratings
    elo_ratings = dict(zip(players.value_counts().index.unique(), 
                           np.repeat(INITIAL_RATING, nplayers)) )

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        winner = row["WinnerName"]
        loser = row["LoserName"]
        if row['isSemi'] == True: 
            k = K*2
        elif row['isFinal'] == True: 
            k = K*3
        else: 
            k = K
        new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
        elo_ratings[winner] = new_winner_rating
        elo_ratings[loser] = new_loser_rating
    ratings = pd.DataFrame.from_dict(elo_ratings, orient='index')
    ratings = ratings.rename(columns={0: "ratings"})
    return(ratings)

# %%
ratings = run_tournament()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-d62c6fb0be37> in <module>
# ----> 1 ratings = run_tournament()
#
# <ipython-input-98-2c48397e1cfb> in run_tournament(data, INITIAL_RATING, ELO_WIDTH, k)
#      15         else:
#      16             k = K
# ---> 17         new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
#      18         elo_ratings[winner] = new_winner_rating
#      19         elo_ratings[loser] = new_loser_rating
#
# KeyError: 'Kelly Fisher'

# %%
ratings.sort_values(by='ratings', ascending = False)
# Out:
#                    ratings
# Shannon Murphy      1475.0
# Robby Foldvari      1475.0
# Jang Moonseok       1475.0
# Francois Ellis      1475.0
# Himanshu Jain       1475.0
# ...                    ...
# Albin Ouschan        800.0
# Jayson Shaw          775.0
# Alex Pagulayan       750.0
# Dennis Orcollo       750.0
# Shane Van Boening    400.0
#
# [805 rows x 1 columns]

# %%
# Train-Test Split
winnersgroup = data[data.Group == 8]
prelims = data[data.Group != 8]

# %%
ratingsPrelims = run_tournament(data=prelims)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-904de0bd8d5a> in <module>
# ----> 1 ratingsPrelims = run_tournament(data=prelims)
#
# <ipython-input-98-2c48397e1cfb> in run_tournament(data, INITIAL_RATING, ELO_WIDTH, k)
#      15         else:
#      16             k = K
# ---> 17         new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
#      18         elo_ratings[winner] = new_winner_rating
#      19         elo_ratings[loser] = new_loser_rating
#
# KeyError: 'Kelly Fisher'

# %%
ratingsPrelims
ratingsPrelims.sort_values(by='ratings', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-486e8ea4bb0b> in <module>
# ----> 1 ratingsPrelims
#       2 ratingsPrelims.sort_values(by='ratings', ascending = False)
#
# NameError: name 'ratingsPrelims' is not defined

# %% [markdown]
# # Accustats

# %%
accustats = pd.read_csv("data/accustats.csv")

# %%
players = pd.concat([accustats.playerA, accustats.playerB] )
players.value_counts()
# Out:
# Shane Van Boening    53
# Dennis Orcollo       30
# Jayson Shaw          27
# Alex Pagulayan       26
# Mika Immonen         21
#                      ..
# Jason Kirkwood        1
# Sean Morgan           1
# Radoslaw Babica       1
# Omar Al-Shaheen       1
# Wu Jiaqing            1
# Length: 158, dtype: int64

# %%
# How many players
nplayers = len(players.value_counts())
nplayers
# Out:
# 158

# %%
# accustats['Date'] = pd.to_datetime(accustats.matchTime)

accustats = accustats.sort_values(by = "matchIndex")

# %%
accustats = accustats.rename(columns = {'matchTime':'date', 
                                       "Competition": 'competition'})
accustats = accustats.drop(columns = ['round'])
accustats.date = pd.to_datetime(accustats['date'])
accustats.head()
# Out:
#      matchIndex matchNumber       date               playerA  playerARacks  \
# 341           1     329B-01 2007-10-14     Shane Van Boening            11
# 342           2     329B-02 2007-10-14     Ernesto Dominguez            11
# 343           3     329B-03 2007-10-14           Tony Robles            11
# 344           4     329B-04 2007-10-14          Louis Ulrich            11
# 345           5     329B-05 2007-10-14  Francisco Bustamante            11
#
#                playerB  playerBRacks          competition
# 341     Ronnie Alcano              4  2007 US Open 9-Ball
# 342  Frankie Hernandez             5  2007 US Open 9-Ball
# 343    Rafael Martinez             5  2007 US Open 9-Ball
# 344     Alex Pagulayan             7  2007 US Open 9-Ball
# 345        Richie Orem             4  2007 US Open 9-Ball

# %%
# def run_tournament2(data=data, INITIAL_RATING = INITIAL_RATING, ELO_WIDTH = ELO_WIDTH, K=K):
    
#     # Initialize Elo Ratings
#     elo_ratings = dict(zip(players.value_counts().index.unique(), 
#                            np.repeat(INITIAL_RATING, nplayers)) )

#     # Iterate through rows of dataframe 
#     for index, row in data.iterrows():
#         winner = row["playerA"]
#         loser = row["playerB"]
#         new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
#         elo_ratings[winner] = new_winner_rating
#         elo_ratings[loser] = new_loser_rating
#     ratings = pd.DataFrame.from_dict(elo_ratings, orient='index')
#     ratings = ratings.rename(columns={0: "ratings"})
#     return(ratings)

# %%
# accustats_rankings = run_tournament2(data = accustats)

# %%
# accustats_rankings.sort_values(by='ratings', ascending = False)

# %% [markdown]
# # Eurotour

# %%
eurotour = pd.read_csv("data/EuroTourTreviso2020.csv")

# %%
import regex as re

def clean_names(df, column):
    result = []
    for idx, row in df.iterrows(): 
        names = re.split('[\\s]+', row[column])
        lastname = ""
        firstname = ""
        for name in names: 
            if name.isupper():
                lastname += str.title(name)
            elif name == "Jr.":
                pass
            else: 
                firstname += str.title(name) + " "
        fullname = firstname + lastname
        result.append(fullname)
    return(result)

# %%
eurotour.playerA = clean_names(eurotour, "playerA")
eurotour.playerB = clean_names(eurotour, "playerB")
eurotour = eurotour.rename(columns={"matchTime":'date'})
eurotour = eurotour.drop(columns = ['round'])
eurotour['competition'] = "2020 EuroTour Treviso"
eurotour.date = pd.to_datetime(eurotour['date'])

# %%
fulldf1 = pd.merge(accustats, eurotour, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchNumber',
                                          "competition"], 
                  how='outer')

# %%
fulldf1 = fulldf1.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)

# %%
fulldf1
# Out:
#      matchIndex matchNumber                date               playerA  \
# 0           1.0     329B-01 2007-10-14 00:00:00     Shane Van Boening
# 1           2.0     329B-02 2007-10-14 00:00:00     Ernesto Dominguez
# 2           3.0     329B-03 2007-10-14 00:00:00           Tony Robles
# 3           4.0     329B-04 2007-10-14 00:00:00          Louis Ulrich
# 4           5.0     329B-05 2007-10-14 00:00:00  Francisco Bustamante
# ..          ...         ...                 ...                   ...
# 771         NaN        SE27 2020-02-22 12:00:00           Eklent Kaci
# 772         NaN        SE28 2020-02-22 12:00:00         Mickey Krause
# 773         NaN        SE29 2020-02-22 14:00:00           Fedor Gorst
# 774         NaN        SE30 2020-02-22 15:30:00           Eklent Kaci
# 775         NaN        SE31 2020-02-22 17:30:00           Jayson Shaw
#
#      playerARacks              playerB  playerBRacks            competition
# 0              11       Ronnie Alcano              4    2007 US Open 9-Ball
# 1              11    Frankie Hernandez             5    2007 US Open 9-Ball
# 2              11      Rafael Martinez             5    2007 US Open 9-Ball
# 3              11       Alex Pagulayan             7    2007 US Open 9-Ball
# 4              11          Richie Orem             4    2007 US Open 9-Ball
# ..            ...                  ...           ...                    ...
# 771             9  Maximillian Lechner             0  2020 EuroTour Treviso
# 772             4    Mateusz Sniegocki             9  2020 EuroTour Treviso
# 773             3          Jayson Shaw             9  2020 EuroTour Treviso
# 774             9    Mateusz Sniegocki             6  2020 EuroTour Treviso
# 775             9          Eklent Kaci             8  2020 EuroTour Treviso
#
# [776 rows x 8 columns]

# %% [markdown]
# # WPA W9-Ball 2019

# %%
wpa = pd.read_csv("data/WPAW9Ball.csv")
wpa = wpa.rename(columns = {"WinnerName":"playerA", 
                      "LoserName": "playerB", 
                      "WinnerRacks":"playerARacks", 
                      "LoserRacks":"playerBRacks",
                      "Round":"round", 
                      "Date":'date',
                      "GameID": 'matchIndex'})
wpa['competition'] = "WPA World 9-Ball Championship"
wpa = wpa.drop(columns = 'round')
wpa.date = pd.to_datetime(wpa['date'])

# %%
wpa
# Out:
#     matchIndex            playerA            playerB  playerARacks  \
# 0            1  Casper Matikainen      Joshua Filler            11
# 1            2       Yip Kin Ling         John Morra            11
# 2            3      Albin Ouschan          Lin Ta Li            11
# 3            4        Denis Grabe  Marc Bijsterbosch            11
# 4            5     Jung-Lin Chang         Dang Jinhu            11
# ..         ...                ...                ...           ...
# 58          59      Chung Ko Ping        Do The Kien            11
# 59          60        Fedor Gorst          Pin Yi Ko            11
# 60          61     Jung-Lin Chang         Liu Haitao            11
# 61          62        Fedor Gorst      Chung Ko Ping            11
# 62          63        Fedor Gorst     Jung-Lin Chang            13
#
#     playerBRacks       date                    competition
# 0              7 2019-12-13  WPA World 9-Ball Championship
# 1              5 2019-12-13  WPA World 9-Ball Championship
# 2              5 2019-12-13  WPA World 9-Ball Championship
# 3              8 2019-12-13  WPA World 9-Ball Championship
# 4              9 2019-12-13  WPA World 9-Ball Championship
# ..           ...        ...                            ...
# 58             6 2019-12-16  WPA World 9-Ball Championship
# 59             6 2019-12-16  WPA World 9-Ball Championship
# 60             6 2019-12-17  WPA World 9-Ball Championship
# 61             7 2019-12-17  WPA World 9-Ball Championship
# 62            11 2019-12-18  WPA World 9-Ball Championship
#
# [63 rows x 7 columns]

# %%
fulldf2 = pd.merge(fulldf1, wpa, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
fulldf2 = fulldf2.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)

# %%
fulldf2
# Out:
#      matchIndex matchNumber                date               playerA  \
# 0           1.0     329B-01 2007-10-14 00:00:00     Shane Van Boening
# 1           2.0     329B-02 2007-10-14 00:00:00     Ernesto Dominguez
# 2           3.0     329B-03 2007-10-14 00:00:00           Tony Robles
# 3           4.0     329B-04 2007-10-14 00:00:00          Louis Ulrich
# 4           5.0     329B-05 2007-10-14 00:00:00  Francisco Bustamante
# ..          ...         ...                 ...                   ...
# 834         NaN        SE27 2020-02-22 12:00:00           Eklent Kaci
# 835         NaN        SE28 2020-02-22 12:00:00         Mickey Krause
# 836         NaN        SE29 2020-02-22 14:00:00           Fedor Gorst
# 837         NaN        SE30 2020-02-22 15:30:00           Eklent Kaci
# 838         NaN        SE31 2020-02-22 17:30:00           Jayson Shaw
#
#      playerARacks              playerB  playerBRacks            competition
# 0              11       Ronnie Alcano              4    2007 US Open 9-Ball
# 1              11    Frankie Hernandez             5    2007 US Open 9-Ball
# 2              11      Rafael Martinez             5    2007 US Open 9-Ball
# 3              11       Alex Pagulayan             7    2007 US Open 9-Ball
# 4              11          Richie Orem             4    2007 US Open 9-Ball
# ..            ...                  ...           ...                    ...
# 834             9  Maximillian Lechner             0  2020 EuroTour Treviso
# 835             4    Mateusz Sniegocki             9  2020 EuroTour Treviso
# 836             3          Jayson Shaw             9  2020 EuroTour Treviso
# 837             9    Mateusz Sniegocki             6  2020 EuroTour Treviso
# 838             9          Eklent Kaci             8  2020 EuroTour Treviso
#
# [839 rows x 8 columns]

# %% [markdown]
# # US Open

# %%
usopen = pd.read_csv("data/usopen2019.csv")
usopen = usopen.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex', 
                      'tournament':'competition'})
usopen = usopen.drop(columns = ["winnerNationality", "winnerRunouts", 
                                "loserNationality", "loserRunouts","Unnamed: 0" ])
usopen.date = pd.to_datetime(usopen['date'])

# %%
fulldf2.dtypes
# Out:
# matchIndex             float64
# matchNumber             object
# date            datetime64[ns]
# playerA                 object
# playerARacks             int64
# playerB                 object
# playerBRacks             int64
# competition             object
# dtype: object

# %%
usopen.dtypes
# Out:
# playerA                 object
# playerARacks             int64
# playerB                 object
# playerBRacks             int64
# matchIndex               int64
# date            datetime64[ns]
# competition             object
# dtype: object

# %%
fulldf3 = pd.merge(fulldf2, usopen, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf3 = fulldf3.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)

# %%
fulldf3
# Out:
#       matchIndex matchNumber                date               playerA  \
# 0            1.0     329B-01 2007-10-14 00:00:00     Shane Van Boening
# 1            2.0     329B-02 2007-10-14 00:00:00     Ernesto Dominguez
# 2            3.0     329B-03 2007-10-14 00:00:00           Tony Robles
# 3            4.0     329B-04 2007-10-14 00:00:00          Louis Ulrich
# 4            5.0     329B-05 2007-10-14 00:00:00  Francisco Bustamante
# ...          ...         ...                 ...                   ...
# 1329         NaN        SE27 2020-02-22 12:00:00           Eklent Kaci
# 1330         NaN        SE28 2020-02-22 12:00:00         Mickey Krause
# 1331         NaN        SE29 2020-02-22 14:00:00           Fedor Gorst
# 1332         NaN        SE30 2020-02-22 15:30:00           Eklent Kaci
# 1333         NaN        SE31 2020-02-22 17:30:00           Jayson Shaw
#
#       playerARacks              playerB  playerBRacks            competition
# 0               11       Ronnie Alcano              4    2007 US Open 9-Ball
# 1               11    Frankie Hernandez             5    2007 US Open 9-Ball
# 2               11      Rafael Martinez             5    2007 US Open 9-Ball
# 3               11       Alex Pagulayan             7    2007 US Open 9-Ball
# 4               11          Richie Orem             4    2007 US Open 9-Ball
# ...            ...                  ...           ...                    ...
# 1329             9  Maximillian Lechner             0  2020 EuroTour Treviso
# 1330             4    Mateusz Sniegocki             9  2020 EuroTour Treviso
# 1331             3          Jayson Shaw             9  2020 EuroTour Treviso
# 1332             9    Mateusz Sniegocki             6  2020 EuroTour Treviso
# 1333             9          Eklent Kaci             8  2020 EuroTour Treviso
#
# [1334 rows x 8 columns]

# %% [markdown]
# # Turning Stone Classic 2017

# %%
tstone = pd.read_csv("data/turningstone2017.csv")
tstone = tstone.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex', 
                      'tournament':'competition'})
tstone = tstone.drop(columns = ["winnerNationality", "winnerRunouts", 
                                "loserNationality", "loserRunouts","Unnamed: 0" ])
tstone.date = pd.to_datetime(tstone['date'])
tstone['competition'] = "2017 Turning Stone Classic XXVII 9-Ball Open"

# %%
tstone
# Out:
#              playerA  playerARacks        playerB  playerBRacks  matchIndex  \
# 0        Mike Yednak             9   Roger Miller             5           1
# 1      Johnny Archer             9  Jamie Addessi             2           2
# 2     Jonathan Smith             9   Brian Trinci             5           3
# 3    Oscar Dominguez             9   Mike Giurleo             3           4
# 4      Chris Braiman             9   Robert Ferry             7           5
# ..               ...           ...            ...           ...         ...
# 245     Dennis Hatch             9     John Morra             2         250
# 246      Jayson Shaw             9  Rodney Morris             3         251
# 247     Dennis Hatch             9      Amar Kang             8         252
# 248    Rodney Morris             9   Dennis Hatch             3         253
# 249    Rodney Morris             6    Jayson Shaw            13         254
#
#                    date                                   competition
# 0   2017-01-06 18:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 1   2017-01-06 18:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 2   2017-01-06 18:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 3   2017-01-06 18:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 4   2017-01-06 18:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# ..                  ...                                           ...
# 245 2017-01-08 13:23:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 246 2017-01-08 15:01:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 247 2017-01-08 15:00:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 248 2017-01-08 17:15:00  2017 Turning Stone Classic XXVII 9-Ball Open
# 249 2017-01-08 19:00:00  2017 Turning Stone Classic XXVII 9-Ball Open
#
# [250 rows x 7 columns]

# %%
fulldf4 = pd.merge(fulldf3, tstone, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf4 = fulldf4.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)

# %%
fulldf4['playerA'] = fulldf4['playerA'].str.strip()
fulldf4['playerB'] = fulldf4['playerB'].str.strip()

# %%
fulldf4['playerA'][fulldf4['playerA'] == "Francisco SanchezRuiz"] = "Francisco Sanchez Ruiz"
fulldf4['playerB'][fulldf4['playerB'] == "Francisco SanchezRuiz"] = "Francisco Sanchez Ruiz"
# Out:
# /Users/sethbilliau/python-virtual-environments/thesis/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sethbilliau/python-virtual-environments/thesis/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # WPA 2010-2018

# %%
wpa2 = pd.read_csv('data/WPAFull.csv')
wpa2.date = pd.to_datetime(wpa2['date'])

# %%
fulldf5 = pd.merge(fulldf4, wpa2, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf5 = fulldf5.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)

# %% [markdown]
# # World Pool Masters

# %%
wpm = pd.read_csv('data/worldpoolmasters.csv')
wpm.date = pd.to_datetime(wpm['date'])

# %%
fulldf6 = pd.merge(fulldf5, wpm, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf6 = fulldf6.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)
fulldf6
# Out:
#       matchIndex matchNumber                date               playerA  \
# 0            1.0     329B-01 2007-10-14 00:00:00     Shane Van Boening
# 1            2.0     329B-02 2007-10-14 00:00:00     Ernesto Dominguez
# 2            3.0     329B-03 2007-10-14 00:00:00           Tony Robles
# 3            4.0     329B-04 2007-10-14 00:00:00          Louis Ulrich
# 4            5.0     329B-05 2007-10-14 00:00:00  Francisco Bustamante
# ...          ...         ...                 ...                   ...
# 3097         NaN        SE27 2020-02-22 12:00:00           Eklent Kaci
# 3098         NaN        SE28 2020-02-22 12:00:00         Mickey Krause
# 3099         NaN        SE29 2020-02-22 14:00:00           Fedor Gorst
# 3100         NaN        SE30 2020-02-22 15:30:00           Eklent Kaci
# 3101         NaN        SE31 2020-02-22 17:30:00           Jayson Shaw
#
#       playerARacks              playerB  playerBRacks            competition  \
# 0               11        Ronnie Alcano             4    2007 US Open 9-Ball
# 1               11    Frankie Hernandez             5    2007 US Open 9-Ball
# 2               11      Rafael Martinez             5    2007 US Open 9-Ball
# 3               11       Alex Pagulayan             7    2007 US Open 9-Ball
# 4               11          Richie Orem             4    2007 US Open 9-Ball
# ...            ...                  ...           ...                    ...
# 3097             9  Maximillian Lechner             0  2020 EuroTour Treviso
# 3098             4    Mateusz Sniegocki             9  2020 EuroTour Treviso
# 3099             3          Jayson Shaw             9  2020 EuroTour Treviso
# 3100             9    Mateusz Sniegocki             6  2020 EuroTour Treviso
# 3101             9          Eklent Kaci             8  2020 EuroTour Treviso
#
#       Unnamed: 0
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3097         NaN
# 3098         NaN
# 3099         NaN
# 3100         NaN
# 3101         NaN
#
# [3102 rows x 9 columns]

# %%
fulldf = fulldf6

# %%
# Similar games 
# 10 ball
# 8 Ball

# World Pool Masters
# Turning Stone
# Mosconi Cup

# %%
players = pd.concat([fulldf.playerA, fulldf.playerB] )
players.value_counts().index.unique()
# How many players
# Out:
# Index(['Shane Van Boening', 'Darren Appleton', 'Jayson Shaw', 'Niels Feijen',
#        'Dennis Orcollo', 'Alex Pagulayan', 'Ralf Souquet', 'Thorsten Hohmann',
#        'Albin Ouschan', 'Mika Immonen',
#        ...
#        'Mohammad Sharif (pool player)', 'Xue Zhenqi', 'Tom Karabotsos',
#        'Konrad Juszcyzszyn', 'Shane McMinn', 'Maxim Dudanets', 'Joey Korsiak',
#        'Mohammad Sharif', 'Kim Ga Young', 'Jason Kirkwood'],
#       dtype='object', length=993)

# %%
def deduplicate_names(series):
    def switcher(argument):
        switcher = {
            'Abderrahmane Mebarki': 'Abder Rehman Mebarki', 
            'Ahmed M. Salah': 'Ahmad Mohamad Sllah',
            '(Kevin) Cheng Yu Hsuan': 'Kevin Cheng',
            'Cheng Yu-hsuan': 'Kevin Cheng',
            'YUKIO AKAGARIYAMA':'Yukio Akakariyama', 
            'Yukio Akagariyama':'Yukio Akakariyama', 
            'Akagariyama Yukio':'Yukio Akakariyama', 
            'Abdulla al-Yousif':  'Abdulla al-Yousif',
            'Alexander Kazakis': 'Alex Kazakis',
            'Ali Abdulhadi':  'Ali Abdulhadi Almeri',
            'Andrew Kong Bu Hong' :'Andrew Kong',
            'Artem Koshovoj':'Artem Koshovyi',
            'Badr al-Awadi':'Bader al-Awadhi',
            'Chang Jun Lin': 'Chang Jung-Lin',
            'Chang Jun Lin': 'Chang Jung-Lin',
            'Chang Jung-Lin': 'Chang Jung-Lin',
            'Chang Yu-lung': 'Chang Yu-Lung',
            'Chang Yu Lung': 'Chang Yu-Lung',
            'Chao Fong-pang':'Chao Fong-Pang',
            'Charles Williams':'Charlie Williams',
            'Dang Jinhu':'Dang Jin Hu',
            'David Alcaide Bermudez': 'David Alcaide',
            'Dennis Orcullo':'Dennis Orcollo',
            'Donnie Mills':'Donny Mills',
            'Dương Quốc Hoàng': 'Duong Quac Hoang',
            'Eklent Kaçi':'Eklent Kaci',
            'Eklent KaÇi': 'Eklent Kaci',
            'Erik  Hjorleifson':'Erik Hjorleifson',
            'Fjodor Gorst':'Fedor Gorst',
            'Francisco Díaz-Pizarro':'Francisco Diaz-Pizarro',
            'Francisco Sánchez Ruíz':'Francisco Sanchez Ruiz',
            'Francisco Sanchez-Ruiz':'Francisco Sanchez Ruiz',
            'Francisco Sánchez': 'Francisco Sanchez Ruiz',
            'Franklin Hernandez':'Frankie Hernandez',
            'HAYATO HIJIKATA':'Hayato Hijikata',
            'Hsieh Chia-chen': 'Hsieh Chia-Chen',
            'Hsu Kai-lun':'Hsu Kai Lun',
            'Jalal al-Sarisi':'Jalal Al Sarisi',
            'Jeff de Luna':'Jeffrey de Luna',
            'Jeffrey De Luna': 'Jeffrey de Luna',
            'Jeong Young-hwa':'Jeong Young Hwa',
            'Jeremy jones':'Jeremy Jones',
            'Jung Lin Chang':'Jung-Lin Chang',
            'Kai Lun Hsu':'Kai-Lun Hsu',
            'Ko Pin-Yi (秉逸柯)': 'Ko Pin Yi',
            'Ko Pin-yi':'Ko Pin Yi',
            'Ko Ping-chung': 'Ko Ping-Chung',
            'Ko Ping Chung': 'Ko Ping-Chung',
            'Ko Ping-han': 'Ko Ping Han',
            'konomopoulos': 'Nikos Ekonomopoulos',
            'Konrad Juszczyszn': 'Konrad Juszczyszyn',
            'Konstantin Stepanow':'Konstantin Stepanov',
            'Konstantinos Koukiadakis':'Kostas Koukiadakis',
            'Kuo Po Chen':'Kuo Po-Cheng',
            'Lee jun-ho':'Lee Jun-ho',
            'Lee Van Corteza': 'Lee Vann Corteza',
            'Li Hewen':'Li He Wen',
            'Liu Cheng-chieh': 'Liu Cheng Chieh',
            'Liu Haitao (pool player)': 'Liu Haitao',
            'Liu Hai Tao': 'Liu Haitao',
            'Liu Ri-teng':'Liu Ri Teng',
            'Lo Li-wen':'Lo Li-Wen',
            'Lưu Minh Phúc':'Luu Minh Phuc',
            'Majed Alazmi':'Majid N. Alazmi', 
            'Marc Vidal Claramunt': 'Marc Vidal',
            'MASATO YOSHIOKA':'Masato Yoshioka',
            'Mateusz Śniegocki':'Mateusz Sniegocki',
            'Matthew Edwards': 'Matt Edwards',
            'Maxim Dudanez':'Maxim Dudanets',
            'Maximillian Lechner':'Maximilian Lechner',
            'Mazen Berjaoui':'Mazen Berjawi',
            'Mazen Berjuai':'Mazen Berjawi',
            'Mazin Berjawi':'Mazen Berjawi',
            'Md al-Amin':'MD Almin',
            'Meshal al-Murdhi': 'Meshaal al-Murdhi',
            'Mieszko Fortuński':'Mieszko Fortunski',
            'Miesko Fortunski': 'Mieszko Fortunski',
            'Mohammed Berjaui':  'Mohammad Berjawi',
            'Mohammad Berjaoui':  'Mohammad Berjawi',
            'Mohammad Sharif (pool player)':'Mohammad Sharif',
            'Mohammed Saeed (pool player)':'Mohammed Saeed',
            'Muhammad Zulfikiri': 'Muhammad Zulfikri',
            'Naoyuki Ōi': 'Naoyuki Oi',
            'Omar Al-Shaheen':'Omar al-Shaheen',
            'Omar Al Shaheen': 'Omar al-Shaheen',
            'Óscar Domínguez':'Oscar Dominguez',
            'Radislaw Babica': 'Radoslaw Babica',
            'Ralf Souqet':'Ralf Souquet',
            'Raymund Faron':'Raymund Faraon',
            'Raymund Farun':'Raymund Faraon',
            'Ronato Alcano': 'Ronnie Alcano',
            'Ruslan Chinachov': 'Ruslan Chinakhov',
            'Ruslan Chinahov': 'Ruslan Chinakhov',
            'Ruslan Tschinachow': 'Ruslan Chinakhov',
            'Salah al-Remawi':'Salah Al Riwani',
            'Salaheldeen Al Rimawi':'Salah Al Riwani',
            'Sanjin Pehlivanović': 'Sanjin Pehlivanovic',
            'Sergei Luzker':  'Sergey Lutsker',
            'Stanimir Ruslanov':  'Stanimir Ruslanow',
            'Tomasz Kapłan':'Tomasz Kaplan',
            'Tōru Kuribayashi':'Toru Kurabayashi',
            'Wang Can (pool player)': 'Wang Can',
            'Wiktor Zieliński':'Wiktor Zielinski',
            'Wojciech Sroczyński':'Wojciech Sroczynski',
            'Wu Jia-qing': 'Wu Jiaqing',
            'Wu Kun Lin': 'Wu Kun-Lin',
            'Wu Kun-lin': 'Wu Kun-Lin',
            'Yang Ching-shun': 'Yang Ching Shun',
            'Yip Kin Ling Leo': 'Yip Kin Ling',
            'Yousseff Jalar':'Yousseff Jaffar',
            'Zhou Long (Poolbillardspieler)\xa0[Zhou ': 'Zhou Long',            
        }

        # get() method of dictionary data type returns 
        # value of passed argument if it is present 
        # in dictionary otherwise second argument will
        # be assigned as default value of passed argument
        val = switcher.get(argument, "nothing")
        if val == "nothing":
            return argument
        else:
#             print(val)
            return val
    
    lst = []
    for idx, item in enumerate(series): 
        lst.append(switcher(item))
#     print(lst)
    return(lst)
   
    
print(np.sum(fulldf["playerA"]== "Abder Rehman Mebarki"))
fulldf["playerA"] = deduplicate_names(fulldf["playerA"])
np.sum(fulldf["playerA"]== "Abder Rehman Mebarki")    
print(np.sum(fulldf["playerB"]== "Abder Rehman Mebarki"))
fulldf["playerB"] = deduplicate_names(fulldf["playerB"])
np.sum(fulldf["playerB"]== "Abder Rehman Mebarki")
# Out:
# 2
# 2
# 2

# %%
fulldf
# Out:
#       matchIndex matchNumber                date               playerA  \
# 0            1.0     329B-01 2007-10-14 00:00:00     Shane Van Boening
# 1            2.0     329B-02 2007-10-14 00:00:00     Ernesto Dominguez
# 2            3.0     329B-03 2007-10-14 00:00:00           Tony Robles
# 3            4.0     329B-04 2007-10-14 00:00:00          Louis Ulrich
# 4            5.0     329B-05 2007-10-14 00:00:00  Francisco Bustamante
# ...          ...         ...                 ...                   ...
# 3097         NaN        SE27 2020-02-22 12:00:00           Eklent Kaci
# 3098         NaN        SE28 2020-02-22 12:00:00         Mickey Krause
# 3099         NaN        SE29 2020-02-22 14:00:00           Fedor Gorst
# 3100         NaN        SE30 2020-02-22 15:30:00           Eklent Kaci
# 3101         NaN        SE31 2020-02-22 17:30:00           Jayson Shaw
#
#       playerARacks             playerB  playerBRacks            competition  \
# 0               11       Ronnie Alcano             4    2007 US Open 9-Ball
# 1               11   Frankie Hernandez             5    2007 US Open 9-Ball
# 2               11     Rafael Martinez             5    2007 US Open 9-Ball
# 3               11      Alex Pagulayan             7    2007 US Open 9-Ball
# 4               11         Richie Orem             4    2007 US Open 9-Ball
# ...            ...                 ...           ...                    ...
# 3097             9  Maximilian Lechner             0  2020 EuroTour Treviso
# 3098             4   Mateusz Sniegocki             9  2020 EuroTour Treviso
# 3099             3         Jayson Shaw             9  2020 EuroTour Treviso
# 3100             9   Mateusz Sniegocki             6  2020 EuroTour Treviso
# 3101             9         Eklent Kaci             8  2020 EuroTour Treviso
#
#       Unnamed: 0
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3097         NaN
# 3098         NaN
# 3099         NaN
# 3100         NaN
# 3101         NaN
#
# [3102 rows x 9 columns]

# %%
fulldf.to_csv("data/fulldf.csv")

# %% [markdown]
# # Elo

# %%
# Elo Rating System 
# Constants
INITIAL_RATING = 1500
ELO_WIDTH = 400
K = 50

players = pd.concat([fulldf.playerA, fulldf.playerB] )
print(players.value_counts().index.unique())
# How many players
nplayers = len(players.value_counts())
nplayers
# Out:
# Index(['Shane Van Boening', 'Dennis Orcollo', 'Darren Appleton', 'Jayson Shaw',
#        'Niels Feijen', 'Alex Pagulayan', 'Ralf Souquet', 'Thorsten Hohmann',
#        'Albin Ouschan', 'Ko Pin Yi',
#        ...
#        'Andrea Klasovic', 'Joey Korsiak', 'Konrad Juszcyzszyn', 'Mark Antony',
#        'Xue Zhenqi', 'Kuo Po Cheng', 'Fahad Salem N Alharbi', 'Aki Heiskanen',
#        'Chris Compton', 'Reymart Lin'],
#       dtype='object', length=885)
# 885

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

def run_tournament3(data=data, INITIAL_RATING = INITIAL_RATING, ELO_WIDTH = ELO_WIDTH, K=K):
    
    # Initialize Elo Ratings
    elo_ratings = dict(zip(players.value_counts().index.unique(), 
                           np.repeat(INITIAL_RATING, nplayers)) )

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        if row['playerARacks'] > row['playerBRacks']: 
            winner = row["playerA"]
            loser = row["playerB"]
        else: 
            winner = row['playerB']
            loser = row['playerA']
        new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], K, ELO_WIDTH)
        elo_ratings[winner] = new_winner_rating
        elo_ratings[loser] = new_loser_rating
    ratings = pd.DataFrame.from_dict(elo_ratings, orient='index')
    ratings = ratings.rename(columns={0: "ratings"})
    return(ratings)

# %%
ratings = run_tournament3(fulldf)

# %%
ratings
ratings.sort_values(by='ratings', ascending = False)[0:25]
# Out:
#                             ratings
# Jayson Shaw             1927.588698
# Albin Ouschan           1782.909072
# Joshua Filler           1782.604750
# Liu Haitao              1776.916182
# Eklent Kaci             1776.856838
# Fedor Gorst             1767.150073
# Alex Pagulayan          1743.332035
# Jung-Lin Chang          1740.453030
# Francisco Sanchez Ruiz  1738.721867
# Jeffrey de Luna         1725.858950
# Carlo Biado             1722.961077
# Alex Kazakis            1711.576271
# David Alcaide           1704.777385
# Wu Jiaqing              1702.311039
# Ko Ping-Chung           1701.855770
# Mateusz Sniegocki       1701.275227
# Shane Van Boening       1701.200723
# Maximilian Lechner      1698.571761
# Wu Kun-Lin              1696.010973
# Niels Feijen            1690.972197
# Chang Yu-Lung           1690.767313
# Mieszko Fortunski       1682.472201
# Dennis Orcollo          1681.194438
# Aloysius Yapp           1679.184718
# Dennis Hatch            1668.844049

# %%
# np.sum(players.value_counts() >= 15)
# Out:
# 97

# %%
data = pd.read_csv('data/predatorCLP.csv')
playersCLP = pd.concat([data.WinnerName, data.LoserName] )

data
# Out:
#      GameID     WinnerName       LoserName  LoserRacks  Table  isSemi  \
# 0         1  Chris Melling    Ralf Souquet           0      1       0
# 1         2  Albin Ouschan  Chris Robinson           2      2       0
# 2         3   Kelly Fisher    Niels Feijen           4      1       0
# 3         4    Eklent Kaci   Albin Ouschan           4      2       0
# 4         5   Niels Feijen  Chris Robinson           3      1       0
# ..      ...            ...             ...         ...    ...     ...
# 187     188  Albin Ouschan    Niels Feijen           4      1       0
# 188     189     Naoyuki Oi   David Alcaide           4      2       0
# 189     190  Albin Ouschan     Eklent Kaci           2      1       1
# 190     191  David Alcaide   Chris Melling           2      2       1
# 191     192  Albin Ouschan   David Alcaide           1      1       0
#
#      isFinal  Group
# 0          0      1
# 1          0      1
# 2          0      1
# 3          0      1
# 4          0      1
# ..       ...    ...
# 187        0      8
# 188        0      8
# 189        0      8
# 190        0      8
# 191        1      8
#
# [192 rows x 8 columns]

# %%
ratings.index
# Out:
# Index(['Shane Van Boening', 'Jayson Shaw', 'Alex Pagulayan', 'Albin Ouschan',
#        'Darren Appleton', 'Joshua Filler', 'Thorsten Hohmann', 'Niels Feijen',
#        'Dennis Orcollo', 'Carlo Biado',
#        ...
#        'Le Quang Trun', 'Yukio Akagariyama', 'Shane McMinn', 'RJ Carmona',
#        'Xue Zhenqi', 'Hsieh Chia-Chen', 'Ricky Yang', 'Khaled Al Otaibi',
#        'Maxim Dudanets', 'Konstantin Stepanov'],
#       dtype='object', length=867)

# %%
# Get correct players
playersindex = []
names = []
for player in playersCLP.unique():
    if player in ratings.index:
        playersindex.append(np.where(players.value_counts().index == player)[0][0])
        names.append(np.where(ratings.index == player)[0][0])

# %%
# Games in the prior dataset
players.value_counts()[playersindex]
fullPlayerList = list(players.value_counts()[playersindex].index)
fullPlayerList.append("Kristina Tkach")
fullPlayerList.append("Kelly Fisher")

CLPratings = ratings.iloc[np.array(names)]
CLPratings = CLPratings.append([{"ratings": 1500},{"ratings": 1500}], ignore_index = True)

CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )

# %%
CLPratings.sort_values(by = "ratings", ascending = False)
# Out:
#                        ratings
# Albin Ouschan      2019.919609
# Eklent Kaci        1867.685854
# Niels Feijen       1708.146201
# Naoyuki Oi         1671.502146
# Alex Kazakis       1660.986234
# Denis Grabe        1660.541487
# Casper Matikainen  1653.057988
# Chris Melling      1650.580484
# Ralf Souquet       1636.702365
# David Alcaide      1586.413081
# Billy Thorpe       1553.752981
# Darren Appleton    1552.880974
# Mieszko Fortunski  1512.098181
# Kristina Tkach     1500.000000
# Kelly Fisher       1500.000000
# Jasmin Ouschan     1494.713956
# Chris Robinson     1476.787455
# Roberto Gomez      1467.617189
# Marc Bijsterbosch  1325.111635

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

import math

def get_loglikelihood(newdata, ratings, ELO_WIDTH = ELO_WIDTH):

    loglikelihood = 0
    # Iterate through rows of dataframe 
    for index, row in newdata.iterrows():
        winnerrating = ratings.loc[row["WinnerName"]]
        loserrating = ratings.loc[row["LoserName"]]
        proba = expected(winnerrating, loserrating, ELO_WIDTH)   
            

        loglikelihood += math.log(proba)

        
    return(loglikelihood)

# %%
get_loglikelihood(data, CLPratings)
# Out:
# -146.51677664879495

# %%
data
# Out:
#      GameID     WinnerName       LoserName  LoserRacks  Table  isSemi  \
# 0         1  Chris Melling    Ralf Souquet           0      1       0
# 1         2  Albin Ouschan  Chris Robinson           2      2       0
# 2         3   Kelly Fisher    Niels Feijen           4      1       0
# 3         4    Eklent Kaci   Albin Ouschan           4      2       0
# 4         5   Niels Feijen  Chris Robinson           3      1       0
# ..      ...            ...             ...         ...    ...     ...
# 187     188  Albin Ouschan    Niels Feijen           4      1       0
# 188     189     Naoyuki Oi   David Alcaide           4      2       0
# 189     190  Albin Ouschan     Eklent Kaci           2      1       1
# 190     191  David Alcaide   Chris Melling           2      2       1
# 191     192  Albin Ouschan   David Alcaide           1      1       0
#
#      isFinal  Group
# 0          0      1
# 1          0      1
# 2          0      1
# 3          0      1
# 4          0      1
# ..       ...    ...
# 187        0      8
# 188        0      8
# 189        0      8
# 190        0      8
# 191        1      8
#
# [192 rows x 8 columns]

# %% [markdown]
# # Tuning K

# %%
K = np.arange(1, 101, 1)

# %%
log_likelihoods = []
for k in K: 
    # Get ratings 
    allratings = run_tournament3(fulldf, K=k)
    
    # Filter ratings 
    CLPratings = allratings.iloc[np.array(names)]
    CLPratings = CLPratings.append([{"ratings": 1500},{"ratings": 1500}], ignore_index = True)
    CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
    
    log_likelihoods.append(get_loglikelihood(data, CLPratings))

# %%
ax = plt.axes()
ax.plot(K, log_likelihoods, '--bo')
ax.axvline(log_likelihoods.index(max(log_likelihoods)))
ax.set(xlim=(0, 100),
       xlabel='x', ylabel='sin(x)',
       title='Log-likelihood');
print("Optimal K is " + str(log_likelihoods.index(max(log_likelihoods))))
# Out:
# Optimal K is 15

# %%
# Get ratings 
allratings = run_tournament3(fulldf, K=15)
allratings.sort_values(by='ratings', ascending = False)[0:25]
# Out:
#                             ratings
# Albin Ouschan           2019.919609
# Joshua Filler           2011.611488
# Jayson Shaw             2004.156218
# Carlo Biado             1992.937012
# Fedor Gorst             1935.577924
# Shane Van Boening       1931.939808
# Wu Kun-lin              1888.698797
# Alexander Kazakis       1879.168635
# Eklent Kaci             1867.685854
# Liu Haitao              1859.954339
# Francisco Sanchez Ruiz  1849.432702
# Ko Pin-yi               1839.891181
# Ko Ping-chung           1833.648930
# Roland Garcia           1827.932788
# Jeffrey De Luna         1812.331385
# Alex Pagulayan          1806.608476
# Corey Deuel             1799.868427
# Mateusz Sniegocki       1795.964189
# Dennis Hatch            1784.427158
# Eklent Kaçi             1775.872388
# Oscar Dominguez         1764.155387
# Thomasz Kaplan          1759.264569
# Cheng Yu-hsuan          1739.632999
# Mickey Krause           1738.339098
# Jung Lin Chang          1737.105234

# %%
# Filter ratings 
CLPratings = allratings.iloc[np.array(names)]
CLPratings = CLPratings.append([{"ratings": 1500},{"ratings": 1500}], ignore_index = True)
CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
CLPratings.sort_values(by='ratings', ascending = False)
# Out:
#                        ratings
# Albin Ouschan      2019.919609
# Eklent Kaci        1867.685854
# Niels Feijen       1708.146201
# Naoyuki Oi         1671.502146
# Alex Kazakis       1660.986234
# Denis Grabe        1660.541487
# Casper Matikainen  1653.057988
# Chris Melling      1650.580484
# Ralf Souquet       1636.702365
# David Alcaide      1586.413081
# Billy Thorpe       1553.752981
# Darren Appleton    1552.880974
# Mieszko Fortunski  1512.098181
# Kristina Tkach     1500.000000
# Kelly Fisher       1500.000000
# Jasmin Ouschan     1494.713956
# Chris Robinson     1476.787455
# Roberto Gomez      1467.617189
# Marc Bijsterbosch  1325.111635

# %% [markdown]
# # Update Posterior Ratings after Predator CLP

# %%
def run_tournament_with_prior_ratings(data, priorratings, ELO_WIDTH = ELO_WIDTH, K=29):
    

    # Initialize Elo Ratings
    elo_ratings = priorratings

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        winner = row["WinnerName"]
        loser = row["LoserName"]
        k=K
#         if row['isSemi'] == True: 
#             k = K*2
#         elif row['isFinal'] == True: 
#             k = K*3
#         else: 
#             k = K
        new_winner_rating, new_loser_rating = update_elo(elo_ratings.loc[winner][0], elo_ratings.loc[loser][0], k, ELO_WIDTH)
        elo_ratings.loc[winner][0] = new_winner_rating
        elo_ratings.loc[loser][0] = new_loser_rating
    return(elo_ratings)

# %%
posterior_ratings = run_tournament_with_prior_ratings(data, priorratings = CLPratings)

# %%
posterior_ratings.sort_values(by = "ratings", ascending = False)
# Out:
#                        ratings
# Eklent Kaci        1864.666825
# Albin Ouschan      1808.431719
# Chris Melling      1718.823379
# David Alcaide      1718.225060
# Niels Feijen       1712.572485
# Naoyuki Oi         1689.549540
# Denis Grabe        1667.401347
# Alex Kazakis       1649.613565
# Ralf Souquet       1575.542445
# Casper Matikainen  1570.423520
# Mieszko Fortunski  1556.702508
# Billy Thorpe       1526.286215
# Darren Appleton    1517.633283
# Marc Bijsterbosch  1514.306218
# Roberto Gomez      1500.575670
# Kelly Fisher       1488.673652
# Jasmin Ouschan     1484.961002
# Chris Robinson     1469.632556
# Kristina Tkach     1464.476829

# %%
# Things to Extend 
    # Figure out how to extend K 
        # K varying as a function of scoreline
    # Glicko 
        
    # Data collection
