# %% [markdown]
# # Pool Elo

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import csv
from datetime import datetime

# %% [markdown]
# # Elo

# %%
# Read Test Dataset 
data = pd.read_csv('data/predatorCLPClean.csv')
data['date'] = pd.to_datetime(data['date'])
fulldf = pd.read_csv("data/fulldf.csv")
fulldf['date'] = pd.to_datetime(fulldf['date'])

# %%
data
# Out:
#      Unnamed: 0  matchIndex        playerA         playerB  playerARacks  \
# 0             0           1  Chris Melling    Ralf Souquet             5
# 1             1           2  Albin Ouschan  Chris Robinson             5
# 2             2           3   Kelly Fisher    Niels Feijen             5
# 3             3           4    Eklent Kaci   Albin Ouschan             5
# 4             4           5   Niels Feijen  Chris Robinson             5
# ..          ...         ...            ...             ...           ...
# 187         187         188  Albin Ouschan    Niels Feijen             5
# 188         188         189     Naoyuki Oi   David Alcaide             5
# 189         189         190  Albin Ouschan     Eklent Kaci             5
# 190         190         191  David Alcaide   Chris Melling             5
# 191         191         192  Albin Ouschan   David Alcaide             5
#
#      playerBRacks  playerARacks.1       date        competition
# 0               0               5 2021-03-22  2021 Predator CLP
# 1               2               5 2021-03-22  2021 Predator CLP
# 2               4               5 2021-03-22  2021 Predator CLP
# 3               4               5 2021-03-22  2021 Predator CLP
# 4               3               5 2021-03-22  2021 Predator CLP
# ..            ...             ...        ...                ...
# 187             4               5 2021-03-29  2021 Predator CLP
# 188             4               5 2021-03-29  2021 Predator CLP
# 189             2               5 2021-03-29  2021 Predator CLP
# 190             2               5 2021-03-29  2021 Predator CLP
# 191             1               5 2021-03-29  2021 Predator CLP
#
# [192 rows x 9 columns]

# %%
# Elo Rating System 
# Constants
INITIAL_RATING = 1500
ELO_WIDTH = 400
K = 50

players = pd.concat([fulldf.playerA, fulldf.playerB] )
print(players.value_counts().index.unique())
# How many players
nplayers = len(players.value_counts())
nplayers
# Out:
# Index(['Shane Van Boening', 'Konrad Juszczyszyn', 'Eklent Kaci',
#        'Ruslan Chinakhov', 'Mateusz Sniegocki', 'Ivar Saris', 'Alex Kazakis',
#        'David Alcaide', 'Jayson Shaw', 'Pijus Labutis',
#        ...
#        'Ivica Putnik', 'Matt Reed', 'Randy Camantigue', 'Takashi Uraoka',
#        'Martin Wragg', 'Angel Gabriel Acosta', 'Ang Tuan Nguyen',
#        'Bogdan Alin Stoian', 'Marlon Villamor', 'Hugo Duivenvoorden'],
#       dtype='object', length=1144)
# 1144

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

def run_tournament3(data=data, INITIAL_RATING = INITIAL_RATING, ELO_WIDTH = ELO_WIDTH, K=K):
    
    # Initialize Elo Ratings
    elo_ratings = dict(zip(players.value_counts().index.unique(), 
                           np.repeat(INITIAL_RATING, nplayers)) )

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        if row['playerARacks'] > row['playerBRacks']: 
            winner = row["playerA"]
            loser = row["playerB"]
        else: 
            winner = row['playerB']
            loser = row['playerA']
        new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], K, ELO_WIDTH)
        elo_ratings[winner] = new_winner_rating
        elo_ratings[loser] = new_loser_rating
    ratings = pd.DataFrame.from_dict(elo_ratings, orient='index')
    ratings = ratings.rename(columns={0: "ratings"})
    return(ratings)

# %%
ratings = run_tournament3(fulldf)

# %%
ratings
ratings.sort_values(by='ratings', ascending = False)[0:25]
# Out:
#                             ratings
# Konrad Juszczyszyn      1972.210492
# Jayson Shaw             1966.827610
# Fedor Gorst             1915.447002
# Eklent Kaci             1913.658331
# Mateusz Sniegocki       1873.317629
# Maximilian Lechner      1837.878061
# Thomas Kaplan           1835.967350
# Jung-Lin Chang          1829.252311
# Liu Haitao              1825.143307
# Niels Feijen            1815.132176
# Pijus Labutis           1805.952218
# Albin Ouschan           1788.131245
# Francisco Sanchez Ruiz  1785.403713
# Casper Matikainen       1766.593465
# Alex Pagulayan          1764.148241
# Ivar Saris              1763.284897
# Ko Ping-Chung           1758.659242
# Mieszko Fortunski       1756.854304
# Ko Pin Yi               1755.351940
# Jeffrey de Luna         1748.587590
# Joshua Filler           1731.899894
# Jeffrey Ignacio         1714.410619
# David Alcaide           1703.414999
# Aloysius Yapp           1702.662995
# Wu Kun-Lin              1700.245281

# %%
playersCLP = pd.concat([data.playerA, data.playerB] )

# %%
# Get correct players
playersindex = []
names = []
for player in playersCLP.unique():
    if player in ratings.index:
        playersindex.append(np.where(players.value_counts().index == player)[0][0])
        names.append(np.where(ratings.index == player)[0][0])
playersindex
names
# Out:
# [36, 20, 922, 2, 10, 14, 196, 44, 7, 16, 90, 43, 1107, 113, 91, 6, 15, 18, 543]

# %%
# Games in the prior dataset
players.value_counts()[playersindex]
fullPlayerList = list(players.value_counts()[playersindex].index)
print(fullPlayerList)
# fullPlayerList.append("Kristina Tkach")
# fullPlayerList.append("Kelly Fisher")

CLPratings = ratings.iloc[np.array(names)]
print(CLPratings)
# CLPratings = CLPratings.append([{"ratings": 1500}], ignore_index = True)

CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
# Out:
# ['Chris Melling', 'Albin Ouschan', 'Kelly Fisher', 'Eklent Kaci', 'Niels Feijen', 'Ralf Souquet', 'Chris Robinson', 'Mieszko Fortunski', 'David Alcaide', 'Darren Appleton', 'Billy Thorpe', 'Naoyuki Oi', 'Kristina Tkach', 'Roberto Gomez', 'Marc Bijsterbosch', 'Alex Kazakis', 'Casper Matikainen', 'Denis Grabe', 'Jasmin Ouschan']
#                        ratings
# Chris Melling      1499.974241
# Albin Ouschan      1788.131245
# Kelly Fisher       1481.262584
# Eklent Kaci        1913.658331
# Niels Feijen       1815.132176
# Ralf Souquet       1664.990115
# Chris Robinson     1469.337828
# Mieszko Fortunski  1756.854304
# David Alcaide      1703.414999
# Darren Appleton    1632.777908
# Billy Thorpe       1640.542337
# Naoyuki Oi         1666.061955
# Kristina Tkach     1469.825223
# Roberto Gomez      1434.111050
# Marc Bijsterbosch  1456.864732
# Alex Kazakis       1661.460708
# Casper Matikainen  1766.593465
# Denis Grabe        1629.400153
# Jasmin Ouschan     1501.408340

# %%
CLPratings.sort_values(by = "ratings", ascending = False)
# Out:
#                        ratings
# Eklent Kaci        1913.658331
# Niels Feijen       1815.132176
# Albin Ouschan      1788.131245
# Casper Matikainen  1766.593465
# Mieszko Fortunski  1756.854304
# David Alcaide      1703.414999
# Naoyuki Oi         1666.061955
# Ralf Souquet       1664.990115
# Alex Kazakis       1661.460708
# Billy Thorpe       1640.542337
# Darren Appleton    1632.777908
# Denis Grabe        1629.400153
# Jasmin Ouschan     1501.408340
# Chris Melling      1499.974241
# Kelly Fisher       1481.262584
# Kristina Tkach     1469.825223
# Chris Robinson     1469.337828
# Marc Bijsterbosch  1456.864732
# Roberto Gomez      1434.111050

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

import math

def get_loglikelihood(newdata, ratings, ELO_WIDTH = ELO_WIDTH):

    loglikelihood = 0
    # Iterate through rows of dataframe 
    for index, row in newdata.iterrows():
        if row['playerARacks'] > row['playerBRacks']: 
            winner = row["playerA"]
            loser = row["playerB"]
        else: 
            winner = row['playerB']
            loser = row['playerA']
        winnerrating = ratings.loc[winner]
        loserrating = ratings.loc[loser]
        proba = expected(winnerrating, loserrating, ELO_WIDTH)   
        
    
        loglikelihood += math.log(proba)

        
    return(loglikelihood)

# %%
get_loglikelihood(data, CLPratings)
# Out:
# -138.96528985222406

# %%
data
# Out:
#      Unnamed: 0  matchIndex        playerA         playerB  playerARacks  \
# 0             0           1  Chris Melling    Ralf Souquet             5
# 1             1           2  Albin Ouschan  Chris Robinson             5
# 2             2           3   Kelly Fisher    Niels Feijen             5
# 3             3           4    Eklent Kaci   Albin Ouschan             5
# 4             4           5   Niels Feijen  Chris Robinson             5
# ..          ...         ...            ...             ...           ...
# 187         187         188  Albin Ouschan    Niels Feijen             5
# 188         188         189     Naoyuki Oi   David Alcaide             5
# 189         189         190  Albin Ouschan     Eklent Kaci             5
# 190         190         191  David Alcaide   Chris Melling             5
# 191         191         192  Albin Ouschan   David Alcaide             5
#
#      playerBRacks  playerARacks.1       date        competition
# 0               0               5 2021-03-22  2021 Predator CLP
# 1               2               5 2021-03-22  2021 Predator CLP
# 2               4               5 2021-03-22  2021 Predator CLP
# 3               4               5 2021-03-22  2021 Predator CLP
# 4               3               5 2021-03-22  2021 Predator CLP
# ..            ...             ...        ...                ...
# 187             4               5 2021-03-29  2021 Predator CLP
# 188             4               5 2021-03-29  2021 Predator CLP
# 189             2               5 2021-03-29  2021 Predator CLP
# 190             2               5 2021-03-29  2021 Predator CLP
# 191             1               5 2021-03-29  2021 Predator CLP
#
# [192 rows x 9 columns]

# %% [markdown]
# # Tuning K

# %%
K = np.arange(1, 101, 1)

# %%
log_likelihoods = []
for k in K: 
    # Get ratings 
    allratings = run_tournament3(fulldf, K=k)
    
    # Filter ratings 
    CLPratings = allratings.iloc[np.array(names)]
#     CLPratings = CLPratings.append([{"ratings": 1500}], ignore_index = True)
    CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
    
    log_likelihoods.append(get_loglikelihood(data, CLPratings))

# %%
ax = plt.axes()
ax.plot(K, log_likelihoods, '--bo')
ax.axvline(log_likelihoods.index(max(log_likelihoods)))
ax.set(xlim=(0, 100),
       xlabel='x', ylabel='sin(x)',
       title='Log-likelihood');

print("Optimal K is " + str(log_likelihoods.index(max(log_likelihoods))))
# Out:
# Optimal K is 9

# %%
bestK = log_likelihoods.index(max(log_likelihoods))

# %%
# Get ratings 
allratings = run_tournament3(fulldf, K=bestK)
allratings.sort_values(by='ratings', ascending = False)[0:25]
# Out:
#                             ratings
# Konrad Juszczyszyn      1755.259486
# Ivar Saris              1660.353114
# Mateusz Sniegocki       1659.731955
# Eklent Kaci             1658.590245
# Jayson Shaw             1653.625154
# Shane Van Boening       1632.615672
# Pijus Labutis           1628.231917
# Albin Ouschan           1620.026825
# Fedor Gorst             1614.895120
# Niels Feijen            1614.545451
# Casper Matikainen       1601.021352
# Dennis Orcollo          1593.388591
# Liu Haitao              1586.771539
# Carlo Biado             1584.931828
# Ko Ping-Chung           1581.267758
# Ko Pin Yi               1579.759731
# Thomas Kaplan           1578.535568
# Ruslan Chinakhov        1569.299756
# David Alcaide           1568.683308
# Maximilian Lechner      1568.073932
# Alex Kazakis            1564.524874
# Jeffrey de Luna         1563.976812
# Jeffrey Ignacio         1563.972602
# Mieszko Fortunski       1562.930626
# Francisco Sanchez Ruiz  1558.634657

# %%
# Filter ratings 
CLPratings = allratings.iloc[np.array(names)]
# CLPratings = CLPratings.append([{"ratings": 1500}], ignore_index = True)
CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
CLPratings.sort_values(by='ratings', ascending = False)
# Out:
#                        ratings
# Eklent Kaci        1658.590245
# Albin Ouschan      1620.026825
# Niels Feijen       1614.545451
# Casper Matikainen  1601.021352
# David Alcaide      1568.683308
# Alex Kazakis       1564.524874
# Mieszko Fortunski  1562.930626
# Ralf Souquet       1555.833923
# Darren Appleton    1546.178469
# Naoyuki Oi         1533.216049
# Chris Melling      1517.122629
# Billy Thorpe       1512.756402
# Denis Grabe        1503.474812
# Jasmin Ouschan     1500.321820
# Kristina Tkach     1495.280258
# Kelly Fisher       1493.562722
# Chris Robinson     1488.408288
# Marc Bijsterbosch  1486.868769
# Roberto Gomez      1481.166939

# %% [markdown]
# # Update Posterior Ratings after Predator CLP

# %%
def run_tournament_with_prior_ratings(data, priorratings, ELO_WIDTH = ELO_WIDTH, K=bestK):
    

    # Initialize Elo Ratings
    elo_ratings = priorratings

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        if row['playerARacks'] > row['playerBRacks']: 
            winner = row["playerA"]
            loser = row["playerB"]
        else: 
            winner = row['playerB']
            loser = row['playerA']
        k=K
#         if row['isSemi'] == True: 
#             k = K*2
#         elif row['isFinal'] == True: 
#             k = K*3
#         else: 
#             k = K
        new_winner_rating, new_loser_rating = update_elo(elo_ratings.loc[winner][0], elo_ratings.loc[loser][0], k, ELO_WIDTH)
        elo_ratings.loc[winner][0] = new_winner_rating
        elo_ratings.loc[loser][0] = new_loser_rating
    return(elo_ratings)

# %%
posterior_ratings = run_tournament_with_prior_ratings(data, priorratings = CLPratings)

# %%
posterior_ratings.sort_values(by = "ratings", ascending = False)
# Out:
#                        ratings
# Eklent Kaci        1687.487641
# Albin Ouschan      1649.882073
# David Alcaide      1618.435623
# Niels Feijen       1611.489466
# Alex Kazakis       1576.345557
# Naoyuki Oi         1568.644487
# Chris Melling      1566.672226
# Casper Matikainen  1555.276594
# Denis Grabe        1528.701888
# Mieszko Fortunski  1527.195758
# Marc Bijsterbosch  1522.458193
# Darren Appleton    1518.767032
# Ralf Souquet       1517.385321
# Roberto Gomez      1493.849788
# Billy Thorpe       1478.732740
# Kelly Fisher       1478.493897
# Chris Robinson     1448.860399
# Jasmin Ouschan     1385.912084
# Kristina Tkach     1276.488560

# %%
# Out:
#                    0
# Chris Melling      0
# Albin Ouschan      0
# Kelly Fisher       0
# Eklent Kaci        0
# Niels Feijen       0
# Ralf Souquet       0
# Chris Robinson     0
# Mieszko Fortunski  0
# David Alcaide      0
# Darren Appleton    0
# Billy Thorpe       0
# Naoyuki Oi         0
# Kristina Tkach     0
# Roberto Gomez      0
# Marc Bijsterbosch  0
# Alex Kazakis       0
# Casper Matikainen  0
# Denis Grabe        0
# Jasmin Ouschan     0

# %% [markdown]
# # Varying K

# %%
# Elo Rating System 
# Constants
INITIAL_RATING = 0
ELO_WIDTH = 400

def expected_Glickman(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** (-1 * (A - B) / elo_width))
    return( proba )

def standard_update_elo_Glickman(Rpre, Ropp, S, k, m0, elo_width):
    expected_win = expected(Rpre, Ropp, elo_width)
    T = 14
    if (k *(S-expected_win)) <= (T * np.sqrt(m0)[0]): 
        B = 0
    else: 
        B = k *(S-expected_win) - (T * np.sqrt(m0)[0])
    Rpost = Rpre + k *(S-expected_win) + B
    return Rpost

def special_update_elo_Glickman(Rpre, Ropp, N, WL, m, elo_width):
    Rpost = (N * Rpre + m * Ropp + WL*elo_width)/(N + m)
    return Rpost





def run_tournament_varyingK(data, priorratings, priorgames, ELO_WIDTH = ELO_WIDTH, dictflag=False):
    
    # Initialize Elo Ratings
    tournamentgames = pd.DataFrame(np.zeros(len( priorratings.index), dtype=int), index= priorratings.index )
    elo_ratings = priorratings
    WLrecord = pd.DataFrame(np.zeros(len( priorratings.index), dtype=int), index= priorratings.index )
    opponentrating = pd.DataFrame(np.zeros(len( priorratings.index), dtype=int), index= priorratings.index )

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        playerA = row["playerA"]
        playerB = row["playerB"]
        tournamentgames.loc[playerA] += 1
        tournamentgames.loc[playerB] += 1
        mA = tournamentgames.loc[playerA]
        mB = tournamentgames.loc[playerB]
#         print(tournamentgames)
        
        Apre = elo_ratings.loc[playerA][0]
        Bpre = elo_ratings.loc[playerB][0]
        SA = row['playerARacks'] > row['playerBRacks'] 
        SB = row['playerBRacks'] > row['playerARacks'] 
        
        if SA: 
            WLrecord.loc[playerA] += 1
        else: 
            WLrecord.loc[playerA] -= 1
            
        if SB: 
            WLrecord.loc[playerB] += 1
        else: 
            WLrecord.loc[playerB] -= 1

        if dictflag:
            NA = priorgames.loc[playerA][0]
            NB = priorgames.loc[playerB][0]
        else:
            NA = priorgames[playerA]
            NB = priorgames[playerB]
            

        
        if NA < 50: 
            ANr = 50/np.sqrt(0.662 + 0.00000739*(2569 - Apre)**2)
        else: 
            ANr = 50
        if NB < 50: 
            BNr = 50/np.sqrt(0.662 + 0.00000739*(2569 - Bpre)**2)
        else: 
            BNr = 50
            
        Ne = min(ANr, BNr)
        
        if NA <=8: 
            Apost = special_update_elo_Glickman(Apre, Bpre, NA, WLrecord.loc[playerA][0], mA, ELO_WIDTH)
        else: 
            K = 800/ (NA + Ne)
            Apost = standard_update_elo_Glickman(Apre, Bpre, SA, K, mA, ELO_WIDTH)
        
        if NB <=8: 
            Bpost = special_update_elo_Glickman(Bpre, Apre, NB, WLrecord.loc[playerB][0], mB, ELO_WIDTH)
        else: 
            K = 800/ (NB + Ne)
            Bpost = standard_update_elo_Glickman(Bpre, Apre, SB, K, mB, ELO_WIDTH)
        
        if dictflag:
            priorgames.loc[playerA][0] += 1
            priorgames.loc[playerB][0] += 1 
        else:
            priorgames[playerA] += 1
            priorgames[playerB] += 1
        
        elo_ratings.loc[playerA][0] = Apost
        elo_ratings.loc[playerB][0] = Bpost
    return(elo_ratings)

# %%
players.value_counts()[np.array(names)]
# Out:
# Chris Melling         54
# Albin Ouschan         73
# Kelly Fisher           2
# Eklent Kaci          125
# Niels Feijen          88
# Ralf Souquet          82
# Chris Robinson         9
# Mieszko Fortunski     42
# David Alcaide        100
# Darren Appleton       81
# Billy Thorpe          23
# Naoyuki Oi            43
# Kristina Tkach         1
# Roberto Gomez         17
# Marc Bijsterbosch     23
# Alex Kazakis         108
# Casper Matikainen     81
# Denis Grabe           76
# Jasmin Ouschan         4
# dtype: int64

# %%
playergames = players.value_counts()
print(playergames)
# Out:
# Shane Van Boening       132
# Konrad Juszczyszyn      131
# Eklent Kaci             125
# Ruslan Chinakhov        120
# Mateusz Sniegocki       119
#                        ...
# Angel Gabriel Acosta      1
# Ang Tuan Nguyen           1
# Bogdan Alin Stoian        1
# Marlon Villamor           1
# Hugo Duivenvoorden        1
# Length: 1144, dtype: int64

# %%
ratings = run_tournament_varyingK(data, priorratings = CLPratings, priorgames=playergames).sort_values(by='ratings', ascending = False)
ratings
# Out:
#                        ratings
# Eklent Kaci        2053.065784
# Albin Ouschan      1996.317398
# Niels Feijen       1983.215600
# Naoyuki Oi         1973.496128
# Alex Kazakis       1930.351692
# Ralf Souquet       1910.734663
# Mieszko Fortunski  1903.882915
# Darren Appleton    1901.294659
# Chris Melling      1875.351708
# David Alcaide      1854.302047
# Casper Matikainen  1846.580787
# Marc Bijsterbosch  1805.860393
# Denis Grabe        1805.812267
# Kelly Fisher       1769.185237
# Roberto Gomez      1758.583706
# Kristina Tkach     1733.756797
# Billy Thorpe       1711.140404
# Jasmin Ouschan     1692.916092
# Chris Robinson     1633.915406

# %%
# Get ratings 
init = pd.DataFrame(np.zeros_like(allratings), index = allratings.index).rename(columns={0:'ratings'})
allratings = run_tournament_varyingK(fulldf, init + 1500, init, dictflag =True)
allratings.sort_values(by='ratings', ascending = False)[0:40]
# Out:
#                             ratings
# Ivica Putnik            2714.865084
# Craig Osbome            2542.398385
# Sandor Tot              2498.580338
# Han Yu                  2459.659470
# Pepijn DeWit            2452.741698
# Nitiwat Kanjanasri      2441.682190
# Jere Virtaranta         2431.279720
# Sebastian Laramee       2403.018563
# Yu-Lung Chang           2400.527952
# Fu Jianbo               2391.320990
# Tobias Bongers          2387.351634
# Tom Karabotsos          2381.180421
# Gîndac Ciprian Gabriel  2373.793139
# Tim DeRuyter            2360.024835
# Hanni Al Howri          2354.657668
# Anthony Brabin          2354.486467
# Li He Wen               2346.052188
# Alex Montpellier        2321.502466
# Elmer Haya              2316.873645
# Roland Garcia           2316.705594
# James Aranas            2309.479835
# Marco Dorenburg         2296.942663
# Kim Laaksonen           2289.825838
# Abdul Rahman al-Amar    2281.842564
# Marharyta Fefilava      2278.703464
# So Shaw                 2275.146646
# MD Almin                2263.410542
# Dilian Tiklev           2261.943326
# Tom D'alfonso           2247.959723
# Scott Higgins           2247.860862
# Wu Kun-Lin              2242.433746
# Karen Corr              2242.339861
# Jarrod Clowery          2235.136680
# Dennis Hatch            2234.275593
# Tom Teriault            2234.141512
# Antonis Vourthis        2232.747608
# Mehmet Bakici           2224.367562
# Phil Davis              2222.836814
# Jani Uski               2219.593738
# Antonio Lining          2217.949735

# %%
# Filter ratings 
CLPratings = allratings.iloc[np.array(names)]
# CLPratings = CLPratings.append([{"ratings": 1500}], ignore_index = True)
CLPratings = CLPratings.set_index(pd.Index(fullPlayerList) )
CLPratings.sort_values(by='ratings', ascending = False)
# Out:
#                        ratings
# Eklent Kaci        2042.723933
# Niels Feijen       2006.787290
# Albin Ouschan      2005.320421
# Naoyuki Oi         1999.288109
# Mieszko Fortunski  1998.243686
# Ralf Souquet       1950.445073
# Alex Kazakis       1934.429030
# Darren Appleton    1930.218145
# Casper Matikainen  1876.696072
# Chris Melling      1829.879396
# Jasmin Ouschan     1799.588509
# David Alcaide      1787.335338
# Denis Grabe        1783.357441
# Marc Bijsterbosch  1759.160055
# Kelly Fisher       1714.233658
# Roberto Gomez      1681.886571
# Chris Robinson     1629.899594
# Billy Thorpe       1603.955979
# Kristina Tkach      969.854545

# %%
def get_loglikelihood(newdata, ratings, ELO_WIDTH = ELO_WIDTH):

    loglikelihood = 0
    # Iterate through rows of dataframe 
    for index, row in newdata.iterrows():
        if row['playerARacks'] > row['playerBRacks']: 
            winner = row["playerA"]
            loser = row["playerB"]
        else: 
            winner = row['playerB']
            loser = row['playerA']
        winnerrating = ratings.loc[winner]
        loserrating = ratings.loc[loser]
        proba = expected(winnerrating, loserrating, ELO_WIDTH)   
#         print(proba)
    
        loglikelihood += math.log(proba)

        
    return(loglikelihood)

# %%
get_loglikelihood(data, CLPratings)
# Out:
# ratings    0.243431
# dtype: float64
# ratings    0.998519
# dtype: float64
# ratings    0.062734
# dtype: float64
# ratings    0.980255
# dtype: float64
# ratings    0.989912
# dtype: float64
# ratings    0.003575
# dtype: float64
# ratings    0.974771
# dtype: float64
# ratings    0.051857
# dtype: float64
# ratings    0.945794
# dtype: float64
# ratings    0.999804
# dtype: float64
# ratings    0.151193
# dtype: float64
# ratings    0.99997
# dtype: float64
# ratings    0.717485
# dtype: float64
# ratings    0.991741
# dtype: float64
# ratings    0.990352
# dtype: float64
# ratings    0.998847
# dtype: float64
# ratings    0.872942
# dtype: float64
# ratings    0.854712
# dtype: float64
# ratings    0.449685
# dtype: float64
# ratings    0.13214
# dtype: float64
# ratings    0.997077
# dtype: float64
# ratings    0.001153
# dtype: float64
# ratings    0.872942
# dtype: float64
# ratings    0.054206
# dtype: float64
# ratings    0.80632
# dtype: float64
# ratings    0.051857
# dtype: float64
# ratings    0.127058
# dtype: float64
# ratings    0.999804
# dtype: float64
# ratings    0.449685
# dtype: float64
# ratings    0.996053
# dtype: float64
# ratings    0.821351
# dtype: float64
# ratings    0.164376
# dtype: float64
# ratings    0.988244
# dtype: float64
# ratings    0.019745
# dtype: float64
# ratings    0.952811
# dtype: float64
# ratings    0.996425
# dtype: float64
# ratings    0.849088
# dtype: float64
# ratings    0.524793
# dtype: float64
# ratings    0.009648
# dtype: float64
# ratings    0.983772
# dtype: float64
# ratings    0.062734
# dtype: float64
# ratings    0.549773
# dtype: float64
# ratings    0.425265
# dtype: float64
# ratings    0.848807
# dtype: float64
# ratings    0.002923
# dtype: float64
# ratings    0.011756
# dtype: float64
# ratings    0.997077
# dtype: float64
# ratings    0.999804
# dtype: float64
# ratings    0.380133
# dtype: float64
# ratings    0.164376
# dtype: float64
# ratings    0.011756
# dtype: float64
# ratings    0.127058
# dtype: float64
# ratings    0.19368
# dtype: float64
# ratings    0.58311
# dtype: float64
# ratings    0.536875
# dtype: float64
# ratings    0.085606
# dtype: float64
# ratings    0.145071
# dtype: float64
# ratings    0.937266
# dtype: float64
# ratings    0.905747
# dtype: float64
# ratings    0.574735
# dtype: float64
# ratings    0.828359
# dtype: float64
# ratings    0.654018
# dtype: float64
# ratings    0.990352
# dtype: float64
# ratings    0.538282
# dtype: float64
# ratings    0.549773
# dtype: float64
# ratings    0.945705
# dtype: float64
# ratings    0.887257
# dtype: float64
# ratings    0.952811
# dtype: float64
# ratings    0.150912
# dtype: float64
# ratings    0.536875
# dtype: float64
# ratings    0.127058
# dtype: float64
# ratings    0.574735
# dtype: float64
# ratings    0.988244
# dtype: float64
# ratings    0.999985
# dtype: float64
# ratings    0.945705
# dtype: float64
# ratings    0.127058
# dtype: float64
# ratings    0.549773
# dtype: float64
# ratings    0.947841
# dtype: float64
# ratings    0.954925
# dtype: float64
# ratings    0.999944
# dtype: float64
# ratings    0.461718
# dtype: float64
# ratings    0.004645
# dtype: float64
# ratings    0.171641
# dtype: float64
# ratings    0.996851
# dtype: float64
# ratings    0.999955
# dtype: float64
# ratings    0.209847
# dtype: float64
# ratings    0.937266
# dtype: float64
# ratings    0.000268
# dtype: float64
# ratings    0.990352
# dtype: float64
# ratings    0.999688
# dtype: float64
# ratings    0.244883
# dtype: float64
# ratings    0.150912
# dtype: float64
# ratings    0.854929
# dtype: float64
# ratings    0.549773
# dtype: float64
# ratings    0.045075
# dtype: float64
# ratings    0.127058
# dtype: float64
# ratings    0.999315
# dtype: float64
# ratings    0.999944
# dtype: float64
# ratings    0.947841
# dtype: float64
# ratings    0.549773
# dtype: float64
# ratings    0.999985
# dtype: float64
# ratings    0.999879
# dtype: float64
# ratings    0.999742
# dtype: float64
# ratings    0.000711
# dtype: float64
# ratings    0.176948
# dtype: float64
# ratings    0.854929
# dtype: float64
# ratings    0.000147
# dtype: float64
# ratings    0.999955
# dtype: float64
# ratings    0.054013
# dtype: float64
# ratings    0.273504
# dtype: float64
# ratings    0.828359
# dtype: float64
# ratings    0.149705
# dtype: float64
# ratings    0.790153
# dtype: float64
# ratings    0.490783
# dtype: float64
# ratings    0.000039
# dtype: float64
# ratings    0.999732
# dtype: float64
# ratings    0.244883
# dtype: float64
# ratings    0.755117
# dtype: float64
# ratings    0.509217
# dtype: float64
# ratings    0.945987
# dtype: float64
# ratings    0.658772
# dtype: float64
# ratings    0.999289
# dtype: float64
# ratings    0.823052
# dtype: float64
# ratings    0.000121
# dtype: float64
# ratings    0.171641
# dtype: float64
# ratings    0.922983
# dtype: float64
# ratings    0.512987
# dtype: float64
# ratings    0.321549
# dtype: float64
# ratings    0.999251
# dtype: float64
# ratings    0.850295
# dtype: float64
# ratings    0.001445
# dtype: float64
# ratings    0.854929
# dtype: float64
# ratings    0.164379
# dtype: float64
# ratings    0.329646
# dtype: float64
# ratings    0.999315
# dtype: float64
# ratings    0.861255
# dtype: float64
# ratings    0.000147
# dtype: float64
# ratings    0.477806
# dtype: float64
# ratings    0.092471
# dtype: float64
# ratings    0.490783
# dtype: float64
# ratings    0.450227
# dtype: float64
# ratings    0.999251
# dtype: float64
# ratings    0.854929
# dtype: float64
# ratings    0.861255
# dtype: float64
# ratings    0.852125
# dtype: float64
# ratings    0.828359
# dtype: float64
# ratings    0.000749
# dtype: float64
# ratings    0.907529
# dtype: float64
# ratings    0.000711
# dtype: float64
# ratings    0.031182
# dtype: float64
# ratings    0.91642
# dtype: float64
# ratings    0.983602
# dtype: float64
# ratings    0.018547
# dtype: float64
# ratings    0.658772
# dtype: float64
# ratings    0.996731
# dtype: float64
# ratings    0.670354
# dtype: float64
# ratings    0.992257
# dtype: float64
# ratings    0.01558
# dtype: float64
# ratings    0.164379
# dtype: float64
# ratings    0.15645
# dtype: float64
# ratings    0.999853
# dtype: float64
# ratings    0.087647
# dtype: float64
# ratings    0.043031
# dtype: float64
# ratings    0.487013
# dtype: float64
# ratings    0.998555
# dtype: float64
# ratings    0.007743
# dtype: float64
# ratings    0.835621
# dtype: float64
# ratings    0.000147
# dtype: float64
# ratings    0.001153
# dtype: float64
# ratings    0.999171
# dtype: float64
# ratings    0.244883
# dtype: float64
# ratings    0.999386
# dtype: float64
# ratings    0.954925
# dtype: float64
# ratings    0.225619
# dtype: float64
# ratings    0.997077
# dtype: float64
# ratings    0.945794
# dtype: float64
# ratings    0.999998
# dtype: float64
# ratings    0.164376
# dtype: float64
# ratings    0.002103
# dtype: float64
# ratings    0.574735
# dtype: float64
# ratings    0.941519
# dtype: float64
# ratings    0.282515
# dtype: float64
# ratings    0.000121
# dtype: float64
# ratings    0.996053
# dtype: float64
# ratings    0.999961
# dtype: float64
# ratings    0.980255
# dtype: float64
# ratings    0.018247
# dtype: float64
# ratings    0.872942
# dtype: float64
# ratings    0.940033
# dtype: float64
# ratings    0.019745
# dtype: float64
# ratings    0.774381
# dtype: float64
# ratings    0.835624
# dtype: float64
# -278.3043750302369

# %%
ratings = run_tournament_varyingK(data, priorratings = CLPratings, priorgames=playergames).sort_values(by='ratings', ascending = False)
ratings

# %% [markdown]
# # Sandbox Code

# %%
# Elo Rating System 
# Constants
INITIAL_RATING = 1500
ELO_WIDTH = 400
K = 50

# %%
def expected(A, B, elo_width): 
    proba = 1/ ( 1 + 10 ** ((B - A) / elo_width))
    return( proba )

# https://www.kaggle.com/kplauritzen/elo-ratings-in-python
def update_elo(winner_elo, loser_elo, k, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expected_win = expected(winner_elo, loser_elo, elo_width)
    change_in_elo = k * (1-expected_win)
    winner_elo += change_in_elo
    loser_elo -= change_in_elo
    return winner_elo, loser_elo

# %%
def run_tournament(data=data, INITIAL_RATING = INITIAL_RATING, ELO_WIDTH = ELO_WIDTH, k=K):
    
    # Initialize Elo Ratings
    elo_ratings = dict(zip(players.value_counts().index.unique(), 
                           np.repeat(INITIAL_RATING, nplayers)) )

    # Iterate through rows of dataframe 
    for index, row in data.iterrows():
        winner = row["WinnerName"]
        loser = row["LoserName"]
        if row['isSemi'] == True: 
            k = K*2
        elif row['isFinal'] == True: 
            k = K*3
        else: 
            k = K
        new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
        elo_ratings[winner] = new_winner_rating
        elo_ratings[loser] = new_loser_rating

    return(elo_ratings)

# %%
ratings = run_tournament()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WinnerName'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-470-d62c6fb0be37> in <module>
# ----> 1 ratings = run_tournament()
#
# <ipython-input-469-75d3b66247f7> in run_tournament(data, INITIAL_RATING, ELO_WIDTH, k)
#       7     # Iterate through rows of dataframe
#       8     for index, row in data.iterrows():
# ----> 9         winner = row["WinnerName"]
#      10         loser = row["LoserName"]
#      11         if row['isSemi'] == True:
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if (
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     989
#     990         # Similar to Index.get_value, but we do not fall back to positional
# --> 991         loc = self.index.get_loc(label)
#     992         return self.index._get_values_for_loc(self, loc, label)
#     993
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 'WinnerName'

# %%
ratings.sort_values(by='ratings', ascending = False)
# Out:
#                    ratings
# Shannon Murphy      1475.0
# Robby Foldvari      1475.0
# Jang Moonseok       1475.0
# Francois Ellis      1475.0
# Himanshu Jain       1475.0
# ...                    ...
# Albin Ouschan        800.0
# Jayson Shaw          775.0
# Alex Pagulayan       750.0
# Dennis Orcollo       750.0
# Shane Van Boening    400.0
#
# [805 rows x 1 columns]

# %%
# Train-Test Split
winnersgroup = data[data.Group == 8]
prelims = data[data.Group != 8]

# %%
ratingsPrelims = run_tournament(data=prelims)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-904de0bd8d5a> in <module>
# ----> 1 ratingsPrelims = run_tournament(data=prelims)
#
# <ipython-input-98-2c48397e1cfb> in run_tournament(data, INITIAL_RATING, ELO_WIDTH, k)
#      15         else:
#      16             k = K
# ---> 17         new_winner_rating, new_loser_rating = update_elo(elo_ratings[winner], elo_ratings[loser], k, ELO_WIDTH)
#      18         elo_ratings[winner] = new_winner_rating
#      19         elo_ratings[loser] = new_loser_rating
#
# KeyError: 'Kelly Fisher'

# %%
ratingsPrelims
ratingsPrelims.sort_values(by='ratings', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-486e8ea4bb0b> in <module>
# ----> 1 ratingsPrelims
#       2 ratingsPrelims.sort_values(by='ratings', ascending = False)
#
# NameError: name 'ratingsPrelims' is not defined
