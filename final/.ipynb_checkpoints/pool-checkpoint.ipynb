# %% [markdown]
# # Pool scraper

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import csv

# %%
data = pd.read_csv('predatorCLP.csv')

# %%
players = [data.WinnerName, data.LoserName]

# %%
players
# Out:
# [0      Chris Melling
#  1      Albin Ouschan
#  2       Kelly Fisher
#  3        Eklent Kaci
#  4       Niels Feijen
#             ...
#  186    Albin Ouschan
#  187       Naoyuki Oi
#  188    Albin Ouschan
#  189    David Alcaide
#  190    Albin Ouschan
#  Name: WinnerName, Length: 191, dtype: object,
#  0        Ralf Souquet
#  1      Chris Robinson
#  2        Niels Feijen
#  3       Albin Ouschan
#  4      Chris Robinson
#              ...
#  186      Niels Feijen
#  187     David Alcaide
#  188       Eklent Kaci
#  189     Chris Melling
#  190     David Alcaide
#  Name: LoserName, Length: 191, dtype: object]

# %%
# Get div of interest
div = pool_soup.find_all('div', attrs={'class' : 'text-center'})

# %%
# Out:
# [<div class="col-2 col-xl order-3 order-lg-2 text-center">
#  <span class="menu-icon d-block d-xl-none"><i class="fas fa-bars fa-3x"></i></span>
#  <div class="d-none d-xl-block" id="standard-menu">
#  <div class="row align-items-center">
#  <div class="col-12 col-lg"></div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/">Home</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/news/">News</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/world-rankings/">World Rankings</a>
#  </div>
#  <div class="col-lg-3">
#  <div class="row">
#  <div class="col-12 col-lg"></div>
#  <div class="col-12 col-lg-8">
#  <div class="brand">
#  <a href="/">
#  <img alt="Matchroom Pool" class="brand-icon img-fluid" src="http://www.matchroompool.com/wp-content/uploads/matchroom-logo.svg?v=1"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-12 col-lg"></div>
#  </div>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/pool-club/">Pool Club</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/sponsorship/">Sponsorship</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/about/">About</a>
#  </div>
#  <div class="col-12 col-lg"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/mosconi-cup/">
#  <span class="brand-icon brand-icon-mosconi-cup"></span>
#  </a>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/world-cup-of-pool/">
#  <span class="brand-icon brand-icon-world-cup-of-pool"></span>
#  </a>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/world-pool-masters/">
#  <span class="brand-icon brand-icon-world-pool-masters"></span>
#  </a>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/usopenpool/">
#  <span class="brand-icon brand-icon-usopenpool"></span>
#  </a>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/worldpoolchampionship/">
#  <span class="brand-icon brand-icon-worldpoolchampionship"></span>
#  </a>
#  </div>,
#  <div class="col-12 col-sm-4 col-md col-lg col-xl text-center">
#  <a href="http://www.matchroompool.com/championship-league-pool/">
#  <span class="brand-icon brand-icon-championship-league-pool"></span>
#  </a>
#  </div>,
#  <div class="col-2 col-xl order-3 order-lg-2 text-center">
#  <span class="menu-icon d-block d-xl-none"><i class="fas fa-bars fa-3x"></i></span>
#  <div class="d-none d-xl-block" id="standard-menu">
#  <div class="row align-items-center">
#  <div class="col-12 col-lg"></div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/">Home</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/news/">News</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/world-rankings/">World Rankings</a>
#  </div>
#  <div class="col-lg-3">
#  <div class="row">
#  <div class="col-12 col-lg"></div>
#  <div class="col-12 col-lg-8">
#  <div class="brand">
#  <a href="/">
#  <img alt="Matchroom Pool" class="brand-icon img-fluid" src="http://www.matchroompool.com/wp-content/uploads/matchroom-logo.svg?v=1"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-12 col-lg"></div>
#  </div>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/pool-club/">Pool Club</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/sponsorship/">Sponsorship</a>
#  </div>
#  <div class="col-12 col-lg">
#  <a class="main-link" href="/about/">About</a>
#  </div>
#  <div class="col-12 col-lg"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">PLD</div>
#  <div class="col col-2 col-md-1">W</div>
#  <div class="col col-2 col-md-1">L</div>
#  <div class="col d-none d-md-block col-md-1">RW</div>
#  <div class="col d-none d-md-block col-md-1">RL</div>
#  <div class="col col-3 col-md-1">PTS</div>
#  <div class="col d-none d-md-block col-md">WON</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">28</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col col-3 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar2000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col d-none d-md-block col-md-1">24</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col d-none d-md-block col-md-1">22</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar4000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">22</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar900</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">22</div>
#  <div class="col d-none d-md-block col-md-1">28</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar700</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md-1">17</div>
#  <div class="col d-none d-md-block col-md-1">28</div>
#  <div class="col col-3 col-md-1">0</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar0</div>
#  </div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">0</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Melling</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Robinson</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Robinson</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Melling</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Melling</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Ralf Souquet</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Robinson</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Ralf Souquet</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Robinson</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Robinson</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Robinson</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Ralf Souquet</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Melling</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">PLD</div>
#  <div class="col col-2 col-md-1">W</div>
#  <div class="col col-2 col-md-1">L</div>
#  <div class="col d-none d-md-block col-md-1">RW</div>
#  <div class="col d-none d-md-block col-md-1">RL</div>
#  <div class="col col-3 col-md-1">PTS</div>
#  <div class="col d-none d-md-block col-md">WON</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">13</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">15</div>
#  <div class="col col-3 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar4000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col d-none d-md-block col-md-1">21</div>
#  <div class="col col-3 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col d-none d-md-block col-md-1">33</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar2000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">19</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar900</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">18</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar700</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">0</div>
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col d-none d-md-block col-md-1">15</div>
#  <div class="col d-none d-md-block col-md-1">30</div>
#  <div class="col col-3 col-md-1">0</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar0</div>
#  </div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Ralf Souquet</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Ralf Souquet</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Ralf Souquet</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Eklent Kaci</div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">PLD</div>
#  <div class="col col-2 col-md-1">W</div>
#  <div class="col col-2 col-md-1">L</div>
#  <div class="col d-none d-md-block col-md-1">RW</div>
#  <div class="col d-none d-md-block col-md-1">RL</div>
#  <div class="col col-3 col-md-1">PTS</div>
#  <div class="col d-none d-md-block col-md">WON</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">0</div>
#  <div class="col d-none d-md-block col-md-1">30</div>
#  <div class="col d-none d-md-block col-md-1">15</div>
#  <div class="col col-3 col-md-1">6</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar4000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col d-none d-md-block col-md-1">19</div>
#  <div class="col col-3 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar2000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">22</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar900</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">15</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar700</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md-1">17</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar0</div>
#  </div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Darren Appleton</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Darren Appleton</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Darren Appleton</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Billy Thorpe</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Billy Thorpe</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Darren Appleton</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Darren Appleton</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Billy Thorpe</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Kelly Fisher</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Darren Appleton</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">PLD</div>
#  <div class="col col-2 col-md-1">W</div>
#  <div class="col col-2 col-md-1">L</div>
#  <div class="col d-none d-md-block col-md-1">RW</div>
#  <div class="col d-none d-md-block col-md-1">RL</div>
#  <div class="col col-3 col-md-1">PTS</div>
#  <div class="col d-none d-md-block col-md">WON</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">13</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar2000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col d-none d-md-block col-md-1">16</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar4000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col d-none d-md-block col-md-1">14</div>
#  <div class="col col-3 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">19</div>
#  <div class="col d-none d-md-block col-md-1">19</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">16</div>
#  <div class="col d-none d-md-block col-md-1">26</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar900</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">14</div>
#  <div class="col d-none d-md-block col-md-1">24</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar700</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">0</div>
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col d-none d-md-block col-md-1">16</div>
#  <div class="col d-none d-md-block col-md-1">30</div>
#  <div class="col col-3 col-md-1">0</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar0</div>
#  </div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Naoyuki Oi</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Kristina Tkach</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Naoyuki Oi</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">0</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Kristina Tkach</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Kristina Tkach</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kristina Tkach</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kristina Tkach</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">0</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Naoyuki Oi</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Billy Thorpe</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Mieszko Fortunski</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Billy Thorpe</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kristina Tkach</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Kelly Fisher</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">3</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Billy Thorpe</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">0</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Mieszko Fortunski</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">0</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">PLD</div>
#  <div class="col col-2 col-md-1">W</div>
#  <div class="col col-2 col-md-1">L</div>
#  <div class="col d-none d-md-block col-md-1">RW</div>
#  <div class="col d-none d-md-block col-md-1">RL</div>
#  <div class="col col-3 col-md-1">PTS</div>
#  <div class="col d-none d-md-block col-md">WON</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">15</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md-1">27</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col col-3 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar2000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col d-none d-md-block col-md-1">19</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar1250</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col col-2 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md-1">23</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">3</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar4000</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">22</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar900</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">2</div>
#  <div class="col col-2 col-md-1">4</div>
#  <div class="col d-none d-md-block col-md-1">20</div>
#  <div class="col d-none d-md-block col-md-1">25</div>
#  <div class="col col-3 col-md-1">2</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar700</div>
#  </div>
#  </div>,
#  <div class="col col-md-6 text-center">
#  <div class="row no-gutters">
#  <div class="col col-2 col-md-1">6</div>
#  <div class="col col-2 col-md-1">1</div>
#  <div class="col col-2 col-md-1">5</div>
#  <div class="col d-none d-md-block col-md-1">16</div>
#  <div class="col d-none d-md-block col-md-1">29</div>
#  <div class="col col-3 col-md-1">1</div>
#  <div class="col d-none d-md-block col-md">&amp;dollar0</div>
#  </div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Marc Bijsterbosch</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">1</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Roberto Gomez</div>
#  </div>,
#  <div class="row no-gutters text-center">
# ...
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Marc Bijsterbosch</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Niels Feijen</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Marc Bijsterbosch</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">0</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">4</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Niels Feijen</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">3</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Marc Bijsterbosch</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">2</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Marc Bijsterbosch</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Naoyuki Oi</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Chris Melling</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">David Alcaide</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">4</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Naoyuki Oi</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Eklent Kaci</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">Albin Ouschan</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Chris Melling</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">2</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">5</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="row no-gutters text-center">
#  <div class="col-5">Albin Ouschan</div>
#  <div class="col-2">
#  <div class="row no-gutters">
#  <div class="col-4">5</div>
#  <div class="col-4">vs</div>
#  <div class="col-4">1</div>
#  </div>
#  </div>
#  <div class="col-5">David Alcaide</div>
#  </div>,
#  <div class="text-center">
#  <div class="row align-items-center">
#  <div class="col"></div>
#  <div class="col-11">
#  <script type="text/javascript"> jQuery(document).ready(function() {
#  		   jQuery(".placid_slider_fouc .placid_slider_set").show();
#  		});</script> <noscript><p><strong>This page has a slideshow that uses Javascript. Your browser either doesn't support Javascript or you have it turned off. To see this page as it is meant to appear please use a Javascript enabled browser.</strong></p> Slider Powered by <a href="http://slidervilla.com/placid/" target="_blank" title="Placid WordPress Slider Plugin">Placid WordPress Slider Plugin.</a></noscript><div class="placid_slider placid_slider_set"><div class="placid_slider_handle" style="width:100%;height:180px;">
#  <div id="placid_slider_7">
#  <div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="http://www.wpapool.com/"><img alt="world-pool_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/world-pool_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div><div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="http://www.saluc.com/html/home.htm"><img alt="aramith_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/aramith_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div><div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="http://www.iwansimonis.com/"><img alt="simonis_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/simonis_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div><div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="https://www.kamuibrand.com/"><img alt="kamui_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/kamui_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div><div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="http://www.rasson.cn/"><img alt="rasson_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/rasson_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div><div class="placid_slideri" data-focus-x="" data-focus-y="" style="background-color:transparent;border:0px solid #ffffff;width:240px;height:180px;">
#  <!-- placid_slideri --><a class="placid_thumb_anchor" href="https://www.predatorcues.com/"><img alt="predator_sponsor" class="placid_slider_thumbnail full placid_slider_thumbnail placid_img_gray" height="180" src="http://www.matchroompool.com/wp-content/uploads/predator_sponsor-1.svg" style="float:none;padding:0;margin:0 0px 0 0px;height:180px;border:0px solid #D8E7EE;display: block;margin: 0 auto;width:200px;" width="200"/></a><!-- /placid_slideri -->
#  </div>
#  </div>
#  </div>
#  </div><script type="text/javascript"> jQuery("html").addClass("placid_slider_fouc");jQuery(".placid_slider_fouc .placid_slider_set").hide();jQuery(document).ready(function() {
#
#  				jQuery("#placid_slider_7").simplyScroll({
#  					customClass: "placid_slider_instance",
#  					frameRate: "72",
#  					pauseOnHover: true,
#
#
#
#  					autoMode: "loop",
#  					speed:1
#  			    });});jQuery("body").append("<style> .simply-scroll-back.simply-scroll-btn-left {   background-image:url(http://www.matchroompool.com/wp-content/plugins/placid-slider/css/images/buttons/default/prev.png) !important; width:20px  !important; height:20px; } </style>");jQuery("body").append("<style> .simply-scroll-forward.simply-scroll-btn-right {   background-image:url(http://www.matchroompool.com/wp-content/plugins/placid-slider/css/images/buttons/default/next.png) !important; width:20px  !important; height:20px; } </style>");</script> </div>
#  <div class="col"></div>
#  </div>
#  </div>,
#  <div class="col-12 col-md text-center">
#
#              </div>,
#  <div class="col-12 col-md-6 text-center">
#  <div class="address-block">
#  <a class="brand text-center" href="/">
#  <span class="brand-icon brand-icon-matchroom"></span>
#  </a>
#  <span id="company-info">
#  <span><strong>Matchroom Multi Sport Ltd</strong></span>
#  <span id="company-address">Mascalls, Mascalls Lane,<br/>Brentwood, Essex, England CM14 5LJ</span>
#  </span>
#  <div class="row footer-contact no-gutters align-items-center">
#  <div class="col-12 col-md">
#  <span class="tel"><a href="tel:+441277359900">+44 (0)1277 359 900</a></span>
#  </div>
#  <div class="col-12 col-md-1 d-xs-none d-md-block">
#  <span class="spacer"> </span>
#  </div>
#  <div class="col-12 col-md">
#  <span class="email"><a href="mailto:pool@matchroom.com">pool@matchroom.com</a></span>
#  </div>
#  </div>
#  <div>
#  <p class="text-center copyright">Copyright © 2008 - 2021 Matchroom Multi Sport Ltd all rights reserved.</p>
#  </div>
#  <div class="text-center">
#  <ul class="social-menu list-inline">
#  <li class="list-inline-item">
#  <a href="http://www.twitter.com/matchroompool" target="_blank">
#  <i class="fab fa-twitter fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.facebook.com/matchroompool" target="_blank">
#  <i class="fab fa-facebook-f fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.youtube.com/matchroompool1" target="_blank">
#  <i class="fab fa-youtube fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.instagram.com/matchroompool" target="_blank">
#  <i class="fab fa-instagram fa-1x white"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="text-center">
#  <ul class="social-menu list-inline">
#  <li class="list-inline-item">
#  <a href="http://www.twitter.com/matchroompool" target="_blank">
#  <i class="fab fa-twitter fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.facebook.com/matchroompool" target="_blank">
#  <i class="fab fa-facebook-f fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.youtube.com/matchroompool1" target="_blank">
#  <i class="fab fa-youtube fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.instagram.com/matchroompool" target="_blank">
#  <i class="fab fa-instagram fa-1x white"></i>
#  </a>
#  </li>
#  </ul>
#  </div>,
#  <div class="col-12 col-md text-center">
#
#              </div>,
#  <div class="col-md-2 text-center">
#                  Site by <a href="http://freeze-design.co.uk" target="_blank">Freeze Creative Group</a>
#  </div>,
#  <div class="col text-center">
#  <span class="close-icon mb-3"><i class="fas fa-times-circle fa-3x"></i></span>
#  <div class="row">
#  <div class="col-12">
#  <a href="/"><h2>Home</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/mosconi-cup/"><h2>Mosconi Cup</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/world-cup-of-pool/"><h2>World Cup of Pool</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/world-pool-masters/"><h2>World Pool Masters</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/usopenpool/"><h2>US Open Pool Championship</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/worldpoolchampionship/"><h2>World Pool Championship</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="http://www.matchroompool.com/championship-league-pool/"><h2>Championship League Pool</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="/news/"><h2>News</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="/world-rankings/"><h2>World Rankings</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="/pool-club/"><h2>Pool Club</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="/sponsorship/"><h2>Sponsorship</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2">
#  <a href="/about/"><h2>About</h2></a>
#  <hr class="menu-divider"/>
#  </div>
#  <div class="col-12 col-xl-2 text-center">
#  <ul class="social-menu list-inline">
#  <li class="list-inline-item">
#  <a href="http://www.twitter.com/matchroompool" target="_blank">
#  <i class="fab fa-twitter fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.facebook.com/matchroompool" target="_blank">
#  <i class="fab fa-facebook-f fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.youtube.com/matchroompool1" target="_blank">
#  <i class="fab fa-youtube fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.instagram.com/matchroompool" target="_blank">
#  <i class="fab fa-instagram fa-1x white"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="col-12 col-xl-2 text-center">
#  <ul class="social-menu list-inline">
#  <li class="list-inline-item">
#  <a href="http://www.twitter.com/matchroompool" target="_blank">
#  <i class="fab fa-twitter fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.facebook.com/matchroompool" target="_blank">
#  <i class="fab fa-facebook-f fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.youtube.com/matchroompool1" target="_blank">
#  <i class="fab fa-youtube fa-1x white"></i>
#  </a>
#  </li>
#  <li class="list-inline-item">
#  <a href="http://www.instagram.com/matchroompool" target="_blank">
#  <i class="fab fa-instagram fa-1x white"></i>
#  </a>
#  </li>
#  </ul>
#  </div>]
