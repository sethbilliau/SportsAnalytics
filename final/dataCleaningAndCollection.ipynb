# %% [markdown]
# # Elo and Glicko Rating Systems for 9-Ball Pool - Data Collection
#
# Author: Seth Billiau
#
# This code was used to collect data for our project. All data is saved in csv files, so you don't need to run this script to run the main notebook, but we have included this code as an appendix.

# %% [markdown]
# # US Open Pool Scraper 2019 Data collection

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import csv
import datetime

# %%
url = "https://cuescore.com/tournament/US+Open+9-ball+Championship+2019/5185877"
my_page = requests.get(url)
# Use content 
soup = BeautifulSoup(my_page.content, "html.parser")

# %%
# Get div of interest
table = soup.find('table', attrs={'class' : 'score'})
trtags = table.find_all('tr',  attrs={'class' : 'match'})

# Helper Function to get information 
def get_info(winner, winnerScore, loser, loserScore): 
    result = {}
    result["winner"] = winner.find('div', attrs={'class': 'name'}).text.strip()
    result["winnerNationality"] = winner.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["winnerRunouts"] = winner.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["winnerRunouts"] == '':
        result["winnerRunouts"] = 0
    result["winnerScore"] = winnerScore

    result["loser"] = loser.find('div', attrs={'class': 'name'}).text.strip()
    result["loserNationality"] = loser.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["loserRunouts"] = loser.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["loserRunouts"] == '':
        result["loserRunouts"] = 0
    result["loserScore"] = loserScore
    return(result)

results_lst = []
for row in trtags: 
    
    # Determine winner and loser
    playerAScore = row.find('td', attrs={'class': 'scoreA'}).find('input').get("value")
    playerBScore = row.find('td', attrs={'class': 'scoreB'}).find('input').get("value")
    if playerAScore > playerBScore: 
        winner = row.find('td', attrs={'class': 'playerA'})
        loser = row.find('td', attrs={'class': 'playerB'})
        result = get_info(winner, playerAScore, loser, playerBScore)
    else: 
        winner = row.find('td', attrs={'class': 'playerB'})
        loser = row.find('td', attrs={'class': 'playerA'})
        result = get_info(winner, playerBScore, loser, playerAScore)
    
    # Get Match Number
    result['matchNum'] = row.find('td', attrs={'class': 'matchno'}).text.strip()
    # Get Match Time
    
    result['matchTime'] = row.find('td', attrs={'class': 'time'}).get('title')
    
    if result['winnerScore'] == "FF": 
        pass
    else: 
        results_lst.append(result)  

usopen = pd.DataFrame(results_lst)
usopen["tournament"] = "US Open 9 Ball Championship 2019"

# %%
usopen
# Out:
#               winner winnerNationality winnerRunouts winnerScore  \
# 0        Jayson Shaw          Scotland             2          11
# 1     Jason Williams     United States             0           4
# 2    Hunter Lombardo     United States             0          11
# 3        Chad Rhodes     United States             0           4
# 4         Naoyuki Oi             Japan             0           9
# ..               ...               ...           ...         ...
# 490    Chang Yu-Lung    Chinese Taipei             0          11
# 491       Wu Jiaqing             China             0          11
# 492  Jeffrey De Luna       Philippines             2           8
# 493    Chang Yu-Lung    Chinese Taipei             0           5
# 494    Joshua Filler           Germany             3          13
#
#                        loser loserNationality loserRunouts loserScore  \
# 0              Marcus Westen          Germany            0          0
# 1               Tom Staveley   United Kingdom            1         11
# 2                Kosuke Tojo            Japan            2         10
# 3    Radwan Jameel R Sorouji     Saudi Arabia            0         11
# 4              Marco Vignola            Italy            0         11
# ..                       ...              ...          ...        ...
# 490               Liu Haitao            China            0         10
# 491                 Wang Can            China            0          0
# 492            Joshua Filler          Germany            0         11
# 493               Wu Jiaqing            China            0         11
# 494               Wu Jiaqing            China            3         10
#
#     matchNum          matchTime                        tournament
# 0          1  21.Apr 2019 08:43  US Open 9 Ball Championship 2019
# 1          2  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 2          3  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 3          4  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# 4          5  21.Apr 2019 08:55  US Open 9 Ball Championship 2019
# ..       ...                ...                               ...
# 490      499  25.Apr 2019 18:00  US Open 9 Ball Championship 2019
# 491      500  25.Apr 2019 20:57  US Open 9 Ball Championship 2019
# 492      501  26.Apr 2019 09:00  US Open 9 Ball Championship 2019
# 493      502  26.Apr 2019 11:30  US Open 9 Ball Championship 2019
# 494      503  26.Apr 2019 14:40  US Open 9 Ball Championship 2019
#
# [495 rows x 11 columns]

# %%
usopen.to_csv("data/usopen2019.csv")

# %% [markdown]
# # Turning Stone Classic XXVII

# %%
url = "https://cuescore.com/tournament/Turning+Stone+Classic+XXVII+Mid+Season+Championship/1284289"
my_page = requests.get(url)

# Use content 
soup = BeautifulSoup(my_page.content, "html.parser")

# Get div of interest
table = soup.find('table', attrs={'class' : 'score'})

# %%
trtags = table.find_all('tr',  attrs={'class' : 'match'})

# Helper Function to get information 
def get_info(winner, winnerScore, loser, loserScore): 
    result = {}
    result["winner"] = winner.find('div', attrs={'class': 'name'}).text.strip()
    result["winnerNationality"] = winner.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["winnerRunouts"] = winner.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["winnerRunouts"] == '':
        result["winnerRunouts"] = 0
    result["winnerScore"] = winnerScore

    result["loser"] = loser.find('div', attrs={'class': 'name'}).text.strip()
    result["loserNationality"] = loser.find('div', attrs={'class': 'flag'}).find('img').get("title")
    result["loserRunouts"] = loser.find('div', attrs={'class': 'runouts'}).text.strip("R")
    if result["loserRunouts"] == '':
        result["loserRunouts"] = 0
    result["loserScore"] = loserScore
    return(result)

results_lst = []
for row in trtags: 
    
    # Determine winner and loser
    playerAScore = row.find('td', attrs={'class': 'scoreA'}).find('input').get("value")
    playerBScore = row.find('td', attrs={'class': 'scoreB'}).find('input').get("value")
    if playerAScore > playerBScore: 
        winner = row.find('td', attrs={'class': 'playerA'})
        loser = row.find('td', attrs={'class': 'playerB'})
        result = get_info(winner, playerAScore, loser, playerBScore)
    else: 
        winner = row.find('td', attrs={'class': 'playerB'})
        loser = row.find('td', attrs={'class': 'playerA'})
        result = get_info(winner, playerBScore, loser, playerAScore)
        
    # Get Match Number
    result['matchNum'] = row.find('td', attrs={'class': 'matchno'}).text.strip()
    # Get Match Time
    
    result['matchTime'] = row.find('td', attrs={'class': 'time'}).get('title')
    
    if result['winnerScore'] == "FF": 
        pass
    else: 
        results_lst.append(result)  


turningstone = pd.DataFrame(results_lst)

# %%
turningstone.to_csv("data/turningstone2017.csv")

# %%
turningstone
# Out:
#               winner winnerNationality  winnerRunouts winnerScore  \
# 0        Mike Yednak     United States              0           9
# 1      Johnny Archer     United States              0           9
# 2     Jonathan Smith     United States              0           9
# 3    Oscar Dominguez     United States              0           9
# 4      Chris Braiman     United States              0           9
# ..               ...               ...            ...         ...
# 245     Dennis Hatch     United States              0           9
# 246      Jayson Shaw          Scotland              0           9
# 247     Dennis Hatch     United States              0           9
# 248    Rodney Morris     United States              0           9
# 249    Rodney Morris     United States              0           6
#
#              loser loserNationality  loserRunouts loserScore matchNum  \
# 0     Roger Miller           Canada             0          5        1
# 1    Jamie Addessi    United States             0          2        2
# 2     Brian Trinci    United States             0          5        3
# 3     Mike Giurleo    United States             0          3        4
# 4     Robert Ferry    United States             0          7        5
# ..             ...              ...           ...        ...      ...
# 245     John Morra           Canada             0          2      250
# 246  Rodney Morris    United States             0          3      251
# 247      Amar Kang            India             0          8      252
# 248   Dennis Hatch    United States             0          3      253
# 249    Jayson Shaw         Scotland             0         13      254
#
#              matchTime
# 0    06.Jan 2017 18:23
# 1    06.Jan 2017 18:23
# 2    06.Jan 2017 18:23
# 3    06.Jan 2017 18:23
# 4    06.Jan 2017 18:23
# ..                 ...
# 245  08.Jan 2017 13:23
# 246  08.Jan 2017 15:01
# 247  08.Jan 2017 15:00
# 248  08.Jan 2017 17:15
# 249  08.Jan 2017 19:00
#
# [250 rows x 10 columns]

# %% [markdown]
# # WPA Wikipedia

# %%
import regex as re

def wpa_scraper(tables, begin, end):
    results_lst = []
    matchIndex = 1 

    # By inspection, choose interesting tables from beginning to end.
    for index in range(begin, end + 1, 1):
        table = tables[index]

        # Table
        table = table.dropna(axis=1, how='all').dropna(axis=0, how='all')

        new_header = table.iloc[0] #grab the first row for the header
        table = table[1:] #take the data less the header row
        table.drop(table.tail(1).index,inplace=True) # drop last n rows
        table.columns = new_header #set the header row as the df header      
        tablecopy = table.copy()

        table = table.loc[:, table.columns.notnull()]
        nonnancols = list(table.columns.unique())
        for idx, col in enumerate(nonnancols):
            if idx == (len(nonnancols) - 1):
                if index == end: 
                    tab = table[col].dropna(how='all').drop_duplicates()
                    tab.columns=["names", "scores"]
                else: 
                    tab = tablecopy.iloc[:,[(len(tablecopy.columns)-3),
                                            (len(tablecopy.columns) -2),
                                            (len(tablecopy.columns) -1)] ].dropna(how='all')
                    tab.columns=["names1", 'names2', "scores"]
                    tab['scores'].iloc[0] = tab['names2'].iloc[0]
                    tab['names2'].iloc[0] = tab['names1'].iloc[0]
                    tab = tab.drop(columns='names1')
                    tab.columns =["names", "scores"]


            else:   
                tab = table[col].dropna(how='all').drop_duplicates()
                tab.columns=["names", "scores"]


            # format Scores
            tab['scores'] = [re.sub(r'\D+', '', str(x)) for x in tab.scores]
            tab['scores'].replace('', np.nan, inplace=True)
            tab = tab.dropna(subset = ['scores'], how='all')

            nrows = tab.shape[0]
    #         print(tab)

            if nrows== 2: 
                nrows = 1
            for pair in range(0, nrows, 2):

                pair1 = pair
                pair2 = pair + 1
                def name_cleaner(tab, index): 
                    name = str(tab['names'].iloc[index])
                    if name[len(name)-1] == ']': 
                        name = name[0:(len(name)-5)]
                    return(name)
                result = {}


                result["playerA"] = name_cleaner(tab, pair1)
                result["playerB"] = name_cleaner(tab, pair2)
                result["playerARacks"] = tab['scores'].iloc[pair1] 
                result["playerBRacks"] = tab['scores'].iloc[pair2]
                result["matchIndex"] = matchIndex
                matchIndex += 1
                results_lst.append(result)

    wpa2018 = pd.DataFrame(results_lst)
    return(wpa2018)



def wpa_scraper_full(url, date, comp, begin, end): 
    tables = pd.read_html(url)
    wpa = wpa_scraper(tables, begin, end)
    wpa['date'] = date
    wpa['competition'] = comp
    return(wpa)

def wpa_scraper_single_table(table):
    results_lst = []
    matchIndex = 1 

    # Table
    table = table.dropna(axis=1, how='all').dropna(axis=0, how='all')

    new_header = table.iloc[0] #grab the first row for the header
    table = table[1:] #take the data less the header row
    table.drop(table.tail(1).index,inplace=True) # drop last n rows
    table.columns = new_header #set the header row as the df header      
    tablecopy = table.copy()

    table = table.loc[:, table.columns.notnull()]
    nonnancols = list(table.columns.unique())
    for idx, col in enumerate(nonnancols):
        tab = table[col].dropna(how='all').drop_duplicates()
        tab.columns=["names", "scores"]


        # format Scores
        tab['scores'] = [re.sub(r'\D+', '', str(x)) for x in tab.scores]
        tab['scores'].replace('', np.nan, inplace=True)
        tab = tab.dropna(subset = ['scores'], how='all')

        nrows = tab.shape[0]
#         print(tab)

        if nrows== 2: 
            nrows = 1
        for pair in range(0, nrows, 2):

            pair1 = pair
            pair2 = pair + 1
            def name_cleaner(tab, index): 
                name = str(tab['names'].iloc[index])
                if name[len(name)-1] == ']': 
                    name = name[0:(len(name)-5)]
                if name[0:2].isupper():
                    name = name[4:len(name)]
                return(name)
            result = {}


            result["playerA"] = name_cleaner(tab, pair1)
            result["playerB"] = name_cleaner(tab, pair2)
            result["playerARacks"] = tab['scores'].iloc[pair1] 
            result["playerBRacks"] = tab['scores'].iloc[pair2]
            result["matchIndex"] = matchIndex
            matchIndex += 1
            results_lst.append(result)

    wpa = pd.DataFrame(results_lst)
    return(wpa)

# %%
# Scrape pages 
wpa2018 = wpa_scraper_full("https://en.wikipedia.org/wiki/2018_WPA_World_Nine-ball_Championship#Preliminary_round", datetime.datetime(2018, 12, 10),
                           "2018 WPA World 9-Ball Championship", 2, 18)
wpa2017 = wpa_scraper_full("https://en.wikipedia.org/wiki/2017_WPA_World_Nine-ball_Championship#Preliminary_round", datetime.datetime(2017, 12, 9),
                           "2017 WPA World 9-Ball Championship", 2, 17)
wpa2016 = wpa_scraper_full("https://en.wikipedia.org/wiki/2016_WPA_World_Nine-ball_Championship#Preliminary_round", datetime.datetime(2016, 6, 30),
                           "2016 WPA World 9-Ball Championship", 2, 18)
wpa2015 = wpa_scraper_full("https://en.wikipedia.org/wiki/2015_WPA_World_Nine-ball_Championship#Preliminary_round", datetime.datetime(2015, 9, 7),
                           "2015 WPA World 9-Ball Championship", 2, 18)

# %%
wpa15_18 = pd.merge(wpa2018, wpa2017, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpa15_18 = pd.merge(wpa15_18, wpa2016, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpa15_18 = pd.merge(wpa15_18, wpa2015, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')

wpa15_18 = wpa15_18.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)
wpa15_18
# Out:
#                playerA              playerB playerARacks playerBRacks  \
# 0      Hunter Lombardo       Bashar Hussain            9            8
# 1       Irsal Nasution        Albin Ouschan            8            9
# 2         Khaled Farag      Hunter Lombardo            5            9
# 3       Irsal Nasution  Konstantin Stepanow            9            5
# 4        Albin Ouschan         Khaled Farag            9            5
# ..                 ...                  ...          ...          ...
# 876        Carlo Biado           Wu Kun-lin           11            4
# 877  Shane Van Boening       Chang Jung-lin           11            8
# 878      Joshua Filler    Alexander Kazakis           11           10
# 879        Carlo Biado    Shane Van Boening           11            6
# 880      Joshua Filler          Carlo Biado           13           10
#
#      matchIndex       date                         competition
# 0             1 2015-09-07  2015 WPA World 9-Ball Championship
# 1             2 2015-09-07  2015 WPA World 9-Ball Championship
# 2             3 2015-09-07  2015 WPA World 9-Ball Championship
# 3             4 2015-09-07  2015 WPA World 9-Ball Championship
# 4             5 2015-09-07  2015 WPA World 9-Ball Championship
# ..          ...        ...                                 ...
# 876         219 2018-12-10  2018 WPA World 9-Ball Championship
# 877         220 2018-12-10  2018 WPA World 9-Ball Championship
# 878         221 2018-12-10  2018 WPA World 9-Ball Championship
# 879         222 2018-12-10  2018 WPA World 9-Ball Championship
# 880         223 2018-12-10  2018 WPA World 9-Ball Championship
#
# [881 rows x 7 columns]

# %%
wpa15_18.to_csv("data/WPA2015_18.csv")

# %%
wpa15_18
# Out:
#                playerA              playerB playerARacks playerBRacks  \
# 0      Hunter Lombardo       Bashar Hussain            9            8
# 1       Irsal Nasution        Albin Ouschan            8            9
# 2         Khaled Farag      Hunter Lombardo            5            9
# 3       Irsal Nasution  Konstantin Stepanow            9            5
# 4        Albin Ouschan         Khaled Farag            9            5
# ..                 ...                  ...          ...          ...
# 876        Carlo Biado           Wu Kun-lin           11            4
# 877  Shane Van Boening       Chang Jung-lin           11            8
# 878      Joshua Filler    Alexander Kazakis           11           10
# 879        Carlo Biado    Shane Van Boening           11            6
# 880      Joshua Filler          Carlo Biado           13           10
#
#      matchIndex       date                         competition
# 0             1 2015-09-07  2015 WPA World 9-Ball Championship
# 1             2 2015-09-07  2015 WPA World 9-Ball Championship
# 2             3 2015-09-07  2015 WPA World 9-Ball Championship
# 3             4 2015-09-07  2015 WPA World 9-Ball Championship
# 4             5 2015-09-07  2015 WPA World 9-Ball Championship
# ..          ...        ...                                 ...
# 876         219 2018-12-10  2018 WPA World 9-Ball Championship
# 877         220 2018-12-10  2018 WPA World 9-Ball Championship
# 878         221 2018-12-10  2018 WPA World 9-Ball Championship
# 879         222 2018-12-10  2018 WPA World 9-Ball Championship
# 880         223 2018-12-10  2018 WPA World 9-Ball Championship
#
# [881 rows x 7 columns]

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2014_WPA_World_Nine-ball_Championship#Preliminary_round")
wpa2014 = wpa_scraper_single_table(tables[11])
wpa2014['date'] = datetime.datetime(2014, 6, 21)
wpa2014['competition'] = "2014 WPA World 9-Ball Championship"
wpa2014.to_csv("data/WPA2014.csv")

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2013_WPA_World_Nine-ball_Championship#Preliminary_round")

wpa2013 = wpa_scraper_single_table(tables[12])
wpa2013['date'] = datetime.datetime(2013, 9, 2)
wpa2013['competition'] = "2013 WPA World 9-Ball Championship"
wpa2013.to_csv("data/WPA2013.csv")

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2012_WPA_World_Nine-ball_Championship#Preliminary_round")

wpa2012 = wpa_scraper_single_table(tables[2])
wpa2012['date'] = datetime.datetime(2012, 6, 22)
wpa2012['competition'] = "2012 WPA World 9-Ball Championship"
wpa2012.to_csv("data/WPA2012.csv")
wpa2012
# Out:
#             playerA          playerB playerARacks playerBRacks  matchIndex  \
# 0      Ralf Souquet       Nick Malai           11            4           1
# 1    Jonny Martinez   Takashi Uraoka           11            8           2
# 2        Fu Che-wei  Andrea Klasovic           11            4           3
# 3       Jayson Shaw   Bruno Muratore            6           11           4
# 4     Aki Heiskanen      Hsu Kai-lun            5           11           5
# ..              ...              ...          ...          ...         ...
# 58       Naoyuki Ōi       Karl Boyes           11            9          59
# 59  Darren Appleton        Ko Pin-yi           11            9          60
# 60     Ralf Souquet         Li Hewen            6           11          61
# 61       Naoyuki Ōi  Darren Appleton            7           11          62
# 62         Li Hewen  Darren Appleton           12           13          63
#
#          date                         competition
# 0  2012-06-22  2012 WPA World 9-Ball Championship
# 1  2012-06-22  2012 WPA World 9-Ball Championship
# 2  2012-06-22  2012 WPA World 9-Ball Championship
# 3  2012-06-22  2012 WPA World 9-Ball Championship
# 4  2012-06-22  2012 WPA World 9-Ball Championship
# ..        ...                                 ...
# 58 2012-06-22  2012 WPA World 9-Ball Championship
# 59 2012-06-22  2012 WPA World 9-Ball Championship
# 60 2012-06-22  2012 WPA World 9-Ball Championship
# 61 2012-06-22  2012 WPA World 9-Ball Championship
# 62 2012-06-22  2012 WPA World 9-Ball Championship
#
# [63 rows x 7 columns]

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2011_WPA_World_Nine-ball_Championship#Preliminary_round")
# 1 to 9
tables[4]

def wpa_scraper_2011(tables, begin, end):
    results_lst = []
    matchIndex = 1 

    # By inspection, choose interesting tables from beginning to end.
    for index in range(begin, end + 1, 1):
        table = tables[index]

        # Table
        table = table.dropna(axis=1, how='all').dropna(axis=0, how='all')

        new_header = table.iloc[0] #grab the first row for the header
        table = table[1:] #take the data less the header row
        table.drop(table.tail(1).index,inplace=True) # drop last n rows
        table.columns = new_header #set the header row as the df header      
        tablecopy = table.copy()

        table = table.loc[:, table.columns.notnull()]
        nonnancols = list(table.columns.unique())
        for idx, col in enumerate(nonnancols):

            tab = table[col].dropna(how='all').drop_duplicates()

            tab.columns=["namesextra","names", "scores"]


            # format Scores
            tab['scores'] = [re.sub(r'\D+', '', str(x)) for x in tab.scores]
            tab['scores'].replace('', np.nan, inplace=True)
            tab = tab.dropna(subset = ['scores'], how='all')

            nrows = tab.shape[0]
    #         print(tab)

            if nrows== 2: 
                nrows = 1
            for pair in range(0, nrows, 2):

                pair1 = pair
                pair2 = pair + 1
                def name_cleaner(tab, index): 
                    name = str(tab['names'].iloc[index])
                    if name[len(name)-1] == ']': 
                        name = name[0:(len(name)-5)]
                    return(name)
                result = {}


                result["playerA"] = name_cleaner(tab, pair1)
                result["playerB"] = name_cleaner(tab, pair2)
                result["playerARacks"] = tab['scores'].iloc[pair1] 
                result["playerBRacks"] = tab['scores'].iloc[pair2]
                result["matchIndex"] = matchIndex
                matchIndex += 1
                results_lst.append(result)

    wpa2018 = pd.DataFrame(results_lst)
    return(wpa2018)


wpa2011 = wpa_scraper_2011(tables, 1 , 9 )
wpa2011['date'] = datetime.datetime(2011, 6, 25)
wpa2011['competition'] = "2011 WPA World 9-Ball Championship"
wpa2011.to_csv("data/WPA2011.csv")
wpa2011
# Out:
#               playerA            playerB playerARacks playerBRacks  \
# 0        Ralf Souquet          Serge Das           11            5
# 1     Radosław Babica  Mariusz Skoneczny            7           11
# 2    Thorsten Hohmann          Lo Li-wen            7           11
# 3   Nick van den Berg   Vicenancio Tanio            7           11
# 4        Ralf Souquet  Mariusz Skoneczny           11            2
# ..                ...                ...          ...          ...
# 58      Ronnie Alcano   Tōru Kuribayashi           11           10
# 59     Dennis Orcullo        Daryl Peach           11            4
# 60  Yukio Akakariyama          Mark Gray           11           10
# 61      Ronnie Alcano     Dennis Orcullo           11            9
# 62  Yukio Akakariyama      Ronnie Alcano           13           11
#
#     matchIndex       date                         competition
# 0            1 2011-06-25  2011 WPA World 9-Ball Championship
# 1            2 2011-06-25  2011 WPA World 9-Ball Championship
# 2            3 2011-06-25  2011 WPA World 9-Ball Championship
# 3            4 2011-06-25  2011 WPA World 9-Ball Championship
# 4            5 2011-06-25  2011 WPA World 9-Ball Championship
# ..         ...        ...                                 ...
# 58          59 2011-06-25  2011 WPA World 9-Ball Championship
# 59          60 2011-06-25  2011 WPA World 9-Ball Championship
# 60          61 2011-06-25  2011 WPA World 9-Ball Championship
# 61          62 2011-06-25  2011 WPA World 9-Ball Championship
# 62          63 2011-06-25  2011 WPA World 9-Ball Championship
#
# [63 rows x 7 columns]

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2010_WPA_World_Nine-ball_Championship#Preliminary_round")
wpa2010 = wpa_scraper(tables, 2, 21)
lastIndex = max(wpa2010.matchIndex)
tab = wpa_scraper_2011(tables, 22, 22)
tab['matchIndex'] = tab['matchIndex'] + lastIndex
wpa2010
wpa2010 = pd.merge(wpa2010, tab, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'matchIndex'], 
                  how='outer')
wpa2010['date'] = datetime.datetime(2010, 6, 29)
wpa2010['competition'] = "2010 WPA World 9-Ball Championship"
wpa2010.to_csv("data/WPA2010.csv")

# %%
wpafull = pd.merge(wpa15_18, wpa2014, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpafull = pd.merge(wpafull, wpa2013, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpafull = pd.merge(wpafull, wpa2012, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpafull = pd.merge(wpafull, wpa2011, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')
wpafull = pd.merge(wpafull, wpa2010, 
                    on=["playerA", "playerB", "playerARacks",
                        "playerBRacks", 'date', 'matchIndex',
                        "competition"], 
                  how='outer')

wpafull = wpafull.sort_values(by= ['date', 'matchIndex']).reset_index(drop=True)
wpafull
# Out:
#                   playerA              playerB playerARacks playerBRacks  \
# 0           Mazen Berjawi    Mariusz Skoneczny            9            2
# 1         Hasan Zeraatgar       Bruno Muratore            3            9
# 2     Abdulla a. Al Daham        Mazen Berjawi            6            9
# 3             Imran Majid       Bruno Muratore            7            9
# 4       Shane Van Boening  Abdulla a. Al Daham            9            6
# ...                   ...                  ...          ...          ...
# 1354          Carlo Biado           Wu Kun-lin           11            4
# 1355    Shane Van Boening       Chang Jung-lin           11            8
# 1356        Joshua Filler    Alexander Kazakis           11           10
# 1357          Carlo Biado    Shane Van Boening           11            6
# 1358        Joshua Filler          Carlo Biado           13           10
#
#       matchIndex       date                         competition
# 0              1 2010-06-29  2010 WPA World 9-Ball Championship
# 1              2 2010-06-29  2010 WPA World 9-Ball Championship
# 2              3 2010-06-29  2010 WPA World 9-Ball Championship
# 3              4 2010-06-29  2010 WPA World 9-Ball Championship
# 4              5 2010-06-29  2010 WPA World 9-Ball Championship
# ...          ...        ...                                 ...
# 1354         219 2018-12-10  2018 WPA World 9-Ball Championship
# 1355         220 2018-12-10  2018 WPA World 9-Ball Championship
# 1356         221 2018-12-10  2018 WPA World 9-Ball Championship
# 1357         222 2018-12-10  2018 WPA World 9-Ball Championship
# 1358         223 2018-12-10  2018 WPA World 9-Ball Championship
#
# [1359 rows x 7 columns]

# %%
wpafull.to_csv("data/WPAFull.csv")

# %% [markdown]
# # World Pool Masters

# %%
def wpm_scraper(tables, begin, end):
    results_lst = []
    matchIndex = 1 

    # By inspection, choose interesting tables from beginning to end.
    for index in range(begin, end + 1, 1):
        table = tables[index]

        # Table
        table = table.dropna(axis=1, how='all').dropna(axis=0, how='all')

        new_header = table.iloc[0] #grab the first row for the header
        table = table[1:] #take the data less the header row
        table.drop(table.tail(1).index,inplace=True) # drop last n rows
        table.columns = new_header #set the header row as the df header      
        tablecopy = table.copy()

        table = table.loc[:, table.columns.notnull()]
        nonnancols = list(table.columns.unique())
        for idx, col in enumerate(nonnancols):

            tab = table[col].dropna(how='all').drop_duplicates()

            tab.columns=["rankings","names", "scores"]


            # format Scores
            tab['scores'] = [re.sub(r'\D+', '', str(x)) for x in tab.scores]
            tab['scores'].replace('', np.nan, inplace=True)
            tab = tab.dropna(subset = ['scores'], how='all')

            nrows = tab.shape[0]
    #         print(tab)

            if nrows== 2: 
                nrows = 1
            for pair in range(0, nrows, 2):

                pair1 = pair
                pair2 = pair + 1
                def name_cleaner(tab, index): 
                    name = str(tab['names'].iloc[index])
                    if name[len(name)-1] == ']': 
                        name = name[0:(len(name)-5)]
                    return(name)
                result = {}


                result["playerA"] = name_cleaner(tab, pair1)
                result["playerB"] = name_cleaner(tab, pair2)
                result["playerARacks"] = tab['scores'].iloc[pair1] 
                result["playerBRacks"] = tab['scores'].iloc[pair2]
                result["matchIndex"] = matchIndex
                matchIndex += 1
                results_lst.append(result)

    wpm = pd.DataFrame(results_lst)
    return(wpm)

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/2019_World_Pool_Masters#Main_draw")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-41-51543d67926c> in <module>
# ----> 1 tables = pd.read_html("https://en.wikipedia.org/wiki/2019_World_Pool_Masters#Main_draw")
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1099         na_values=na_values,
#    1100         keep_default_na=keep_default_na,
# -> 1101         displayed_only=displayed_only,
#    1102     )
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     896
#     897         try:
# --> 898             tables = p.parse_tables()
#     899         except ValueError as caught:
#     900             # if `io` is an io-like object, check if it's seekable
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/html.py in parse_tables(self)
#     215         list of parsed (header, body, footer) tuples from tables.
#     216         """
# --> 217         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     218         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     219
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/html.py in _build_doc(self)
#     734                     pass
#     735             else:
# --> 736                 raise e
#     737         else:
#     738             if not hasattr(r, "text_content"):
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/html.py in _build_doc(self)
#     715         try:
#     716             if is_url(self.io):
# --> 717                 with urlopen(self.io) as f:
#     718                     r = parse(f, parser=parser)
#     719             else:
#
# ~/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     135     import urllib.request
#     136
# --> 137     return urllib.request.urlopen(*args, **kwargs)
#     138
#     139
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 61] Connection refused>

# %% [markdown]
# # Clean Test Dataset

# %%
import datetime
def date_switcher(argument):
    date_switcher_dict = {
        1: datetime.datetime(2021, 3,22),
        2: datetime.datetime(2021, 3,23),
        3: datetime.datetime(2021, 3,24),
        4: datetime.datetime(2021, 3,25),
        5: datetime.datetime(2021, 3,26),
        6: datetime.datetime(2021, 3,27),
        7: datetime.datetime(2021, 3,28),
        8: datetime.datetime(2021, 3,29)
    }
    val = date_switcher_dict.get(argument, None)
    return(val)
    

data = pd.read_csv('data/predatorCLP.csv')
data["playerARacks"] = 5


dates = []
for _, row in data.iterrows():
#     print(row["Group"])
    dates.append(date_switcher(row.loc["Group"]))
# print(dates)
data["date"] = dates
data["competition"] = "2021 Predator CLP"
data = data.rename(columns={"GameID": "matchIndex", 
                     "WinnerName": "playerA", 
                     "LoserName": "playerB",
                    "LoserRacks": "playerBRacks"})
data = data.drop(columns = ["isFinal","isSemi", "Group", "Table"])

data = data[["matchIndex", "playerA", "playerB", "playerARacks", "playerBRacks", "playerARacks", "date", "competition"]]


data.to_csv("data/predatorCLPClean.csv")

# %% [markdown]
# # Knitting Things Together
#
# This code was used to knit together our csv's into fulldf.csv

# %% [markdown]
# ### Accustats

# %%
accustats = pd.read_csv("data/accustats.csv")

accustats = accustats.sort_values(by = "matchIndex")
accustats = accustats.rename(columns = {'matchTime':'date', 
                                       "Competition": 'competition'})
accustats = accustats.drop(columns = ['round'])
accustats.date = pd.to_datetime(accustats['date'])
accustats
# Out:
#      matchIndex matchNumber       date               playerA  playerARacks  \
# 341           1     329B-01 2007-10-14     Shane Van Boening            11
# 342           2     329B-02 2007-10-14     Ernesto Dominguez            11
# 343           3     329B-03 2007-10-14           Tony Robles            11
# 344           4     329B-04 2007-10-14          Louis Ulrich            11
# 345           5     329B-05 2007-10-14  Francisco Bustamante            11
# ..          ...         ...        ...                   ...           ...
# 3           351     D22-9B4 2020-01-24     Konrad Juszczyszn             9
# 4           352     D22-9B5 2020-01-24         Joshua Filler             9
# 5           353     D22-9B6 2020-01-24          James Aranas             9
# 6           354     D22-9B7 2020-01-24         Joshua Filler             9
# 7           355     D22-9B8 2020-01-24      Lee Vann Corteza            11
#
#                playerB  playerBRacks                          competition
# 341     Ronnie Alcano              4                  2007 US Open 9-Ball
# 342  Frankie Hernandez             5                  2007 US Open 9-Ball
# 343    Rafael Martinez             5                  2007 US Open 9-Ball
# 344     Alex Pagulayan             7                  2007 US Open 9-Ball
# 345        Richie Orem             4                  2007 US Open 9-Ball
# ..                 ...           ...                                  ...
# 3        Chris Melling             6  2020 Derby City Classic XXII 9 Ball
# 4    Shane Van Boening             2  2020 Derby City Classic XXII 9 Ball
# 5       Justin Bergman             1  2020 Derby City Classic XXII 9 Ball
# 6       Dennis Orcollo             4  2020 Derby City Classic XXII 9 Ball
# 7        Joshua Filler             4  2020 Derby City Classic XXII 9 Ball
#
# [355 rows x 8 columns]

# %% [markdown]
# ### Eurotour

# %%
eurotour = pd.read_csv("data/EuroTourTreviso2020.csv")

# %%
# Clean names
import regex as re

def clean_names(df, column):
    result = []
    for idx, row in df.iterrows(): 
        names = re.split('[\\s]+', row[column])
        lastname = ""
        firstname = ""
        for name in names: 
            if name.isupper():
                lastname += str.title(name)
            elif name == "Jr.":
                pass
            else: 
                firstname += str.title(name) + " "
        fullname = firstname + lastname
        result.append(fullname)
    return(result)

# %%
eurotour.playerA = clean_names(eurotour, "playerA")
eurotour.playerB = clean_names(eurotour, "playerB")
eurotour = eurotour.rename(columns={"matchTime":'date'})
eurotour = eurotour.drop(columns = ['round','matchNumber'])
eurotour['competition'] = "2020 EuroTour Treviso"
eurotour.date = pd.to_datetime(eurotour['date'])
eurotour['matchIndex'] = range(1, len(eurotour.date ) + 1, 1)

# %%
def eurotour_single_table(table, dropdups = False, verbose = False):
    results_lst = []
    matchIndex = 1 

    # Table
    table = table.dropna(axis=1, how='all').dropna(axis=0, how='all')

    new_header = table.iloc[0] #grab the first row for the header
    table = table[1:] #take the data less the header row
#     table.drop(table.tail(1).index,inplace=True) # drop last n rows
    table.columns = new_header #set the header row as the df header      
    tablecopy = table.copy()

    table = table.loc[:, table.columns.notnull()]
    nonnancols = list(table.columns.unique())
    for idx, col in enumerate(nonnancols):
    
        tab = table[col].dropna(how='all')
        tab.columns=["names", "scores"]

        # format Scores
        tab['scores'] = [re.sub(r'\D+', '', str(x)) for x in tab.scores]
        tab['scores'].replace('', np.nan, inplace=True)
        tab = tab.dropna(subset = ['scores'], how='all')
        if dropdups == True:
            tab = tab.drop_duplicates()

        nrows = tab.shape[0]
        if verbose == True:
            print(tab)
        
        
        if nrows== 2: 
            nrows = 1
 


        for pair in range(0, nrows, 2):
            pair1 = pair
            pair2 = pair + 1
            def name_cleaner(tab, index): 
                name = str(tab['names'].iloc[index])
                if name[len(name)-1] == ')': 
                    name = name[0:(len(name)-6)]
                if name[0:2].isupper():
                    name = name[4:len(name)]
                return(name)
            result = {}
            result["playerA"] = name_cleaner(tab, pair1)
            result["playerB"] = name_cleaner(tab, pair2)
            result["playerARacks"] = int(tab['scores'].iloc[pair1] )
            result["playerBRacks"] = int(tab['scores'].iloc[pair2])
            result["matchIndex"] = matchIndex
            matchIndex += 1
            results_lst.append(result)

    wpa = pd.DataFrame(results_lst)
    return(wpa)

def eurotour_scraper_full(url, tableindex, date, comp, dropDups= False, verbose = False): 
    tables = pd.read_html(url)
    treviso19 = eurotour_single_table(tables[tableindex], dropDups, verbose)
    treviso19['date'] = date
    treviso19['competition'] = comp
    return(treviso19)

# %%
url = 'https://en.wikipedia.org/wiki/2019_Leende_Open'
tables = pd.read_html(url)
# tables[2]
leende19 = eurotour_scraper_full(url, 2, datetime.datetime(2019, 2, 17), "2019 Leende Open", True)
eurotourwiki = pd.merge(eurotour, leende19, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = 'https://en.wikipedia.org/wiki/2018_Leende_Open'
leende18 = eurotour_scraper_full(url, 2, datetime.datetime(2018, 9, 20), "2018 Leende Open", True)
eurotourwiki = pd.merge(eurotourwiki, leende18, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = 'https://en.wikipedia.org/wiki/2017_Dutch_Open'
leende17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 9, 10), "2017 Leende Open", True)
eurotourwiki = pd.merge(eurotourwiki, leende17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = 'https://en.wikipedia.org/wiki/2016_Leende_Open'
leende16 = eurotour_scraper_full(url, 2, datetime.datetime(2016, 9, 29), "2016 Leende Open", True) 
eurotourwiki = pd.merge(eurotourwiki, leende16, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2019_Treviso_Open'
treviso19 = eurotour_scraper_full(url, 2, datetime.datetime(2019, 5, 8), "2019 Treviso Open")
eurotourwiki = pd.merge(eurotourwiki, treviso19, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = "https://en.wikipedia.org/wiki/2018_Italian_Open_(pool)"
treviso18 = eurotour_scraper_full(url, 2, datetime.datetime(2018, 3, 1), "2018 Treviso Open", True)
eurotourwiki = pd.merge(eurotourwiki, treviso18, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
url = 'https://en.wikipedia.org/wiki/2017_Treviso_Open'
treviso17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 11, 16), "2017 Treviso Open",True)
eurotourwiki = pd.merge(eurotourwiki, treviso17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = 'https://en.wikipedia.org/wiki/2017_Italian_Open_(pool)'
italian17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 2, 23), "2017 Italian Open",True)
eurotourwiki = pd.merge(eurotourwiki, italian17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')


url = 'https://en.wikipedia.org/wiki/2016_Treviso_Open'
treviso16 = eurotour_scraper_full(url, 1, datetime.datetime(2016, 11, 24), "2016 Treviso Open",True)
eurotourwiki = pd.merge(eurotourwiki, treviso16, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2019_Austria_Open'
austria19 = eurotour_scraper_full(url, 2, datetime.datetime(2019, 2, 17), "2019 Austria Open")
eurotourwiki = pd.merge(eurotourwiki, austria19, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = "https://en.wikipedia.org/wiki/2018_Austria_Open"
austria18 = eurotour_scraper_full(url, 2, datetime.datetime(2018, 4, 12), "2018 Austria Open", True)
eurotourwiki = pd.merge(eurotourwiki, austria18, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')


url = 'https://en.wikipedia.org/wiki/2017_Austria_Open'
austria17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 5, 17), "2017 Austria Open", True)
eurotourwiki = pd.merge(eurotourwiki, austria17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2019_Klagenfurt_Open'
klagen19 = eurotour_scraper_full(url, 2, datetime.datetime(2019, 10, 13), "2019 Klagenfurt Open")
eurotourwiki = pd.merge(eurotourwiki, klagen19, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')


url = 'https://en.wikipedia.org/wiki/2018_Klagenfurt_Open'
klagen18 = eurotour_scraper_full(url, 2, datetime.datetime(2018, 10, 10), "2018 Klagenfurt Open", True)
eurotourwiki = pd.merge(eurotourwiki, klagen18, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

url = 'https://en.wikipedia.org/wiki/2017_Klagenfurt_Open'
klagen17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 10, 5), "2017 Klagenfurt Open", True)
eurotourwiki = pd.merge(eurotourwiki, klagen17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2019_Antalya_Open_(pool)'
antalya19 = eurotour_scraper_full(url, 2, datetime.datetime(2019, 11, 7), "2019 Antalya Open", dropDups = True)
eurotourwiki = pd.merge(eurotourwiki, antalya19, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2018_Veldhoven_Open'
veld18 = eurotour_scraper_full(url, 2, datetime.datetime(2018, 8, 2), "2018 Veldhoven Open", True)
eurotourwiki = pd.merge(eurotourwiki, veld18, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2017_Portugal_Open'
portugal17 = eurotour_scraper_full(url, 2, datetime.datetime(2017, 3, 30), "2017 Portugal Open", True)
eurotourwiki = pd.merge(eurotourwiki, portugal17, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2016_Albanian_Open'
albanian16 = eurotour_scraper_full(url, 2, datetime.datetime(2016, 9, 4), "2016 Albanian Open",True)
eurotourwiki = pd.merge(eurotourwiki, albanian16, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
url = 'https://en.wikipedia.org/wiki/2016_North_Cyprus_Open'
cyprus16 = eurotour_scraper_full(url, 2, datetime.datetime(2016, 6, 2), "2016 North Cyprus Open", True)
eurotourwiki = pd.merge(eurotourwiki, cyprus16, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

# %%
eurotourwiki
# eurotourwiki.to_csv('data/eurotourFull.csv')
# Out:
#                     date              playerA  playerARacks  \
# 0    2020-02-20 09:00:00       Sergio Lagunas             9
# 1    2020-02-20 09:00:00            Jan Rempe             9
# 2    2020-02-20 09:00:00     Henrique Correia             9
# 3    2020-02-20 10:30:00     Thorsten Hohmann             2
# 4    2020-02-20 10:30:00        Stefan Gruber             7
# ...                  ...                  ...           ...
# 1035 2016-06-02 00:00:00      Karol Skowerski             7
# 1036 2016-06-02 00:00:00         Ralf Souquet             5
# 1037 2016-06-02 00:00:00  Nikos Ekonomopoulos             9
# 1038 2016-06-02 00:00:00          Jayson Shaw             4
# 1039 2016-06-02 00:00:00  Nikos Ekonomopoulos             5
#
#                     playerB  playerBRacks             competition  matchIndex
# 0              Adrian Weiss             7   2020 EuroTour Treviso           1
# 1     Valeriia Trushevskaia             6   2020 EuroTour Treviso           2
# 2        Massimiliano Corso             3   2020 EuroTour Treviso           3
# 3            Petri Makkonen             9   2020 EuroTour Treviso           4
# 4          Moritz Neuhausen             9   2020 EuroTour Treviso           5
# ...                     ...           ...                     ...         ...
# 1035            Jayson Shaw             9  2016 North Cyprus Open          27
# 1036               Mario He             9  2016 North Cyprus Open          28
# 1037           Mika Immonen             4  2016 North Cyprus Open          29
# 1038               Mario He             9  2016 North Cyprus Open          30
# 1039               Mario He             9  2016 North Cyprus Open          31
#
# [1040 rows x 7 columns]

# %% [markdown]
# ### WPA 2010-2019

# %%
wpa = pd.read_csv('data/WPAFull.csv').drop(columns ="Unnamed: 0")
wpa.date = pd.to_datetime(wpa['date'])
wpa
# Out:
#                   playerA              playerB  playerARacks  playerBRacks  \
# 0           Mazen Berjawi    Mariusz Skoneczny             9             2
# 1         Hasan Zeraatgar       Bruno Muratore             3             9
# 2     Abdulla a. Al Daham        Mazen Berjawi             6             9
# 3             Imran Majid       Bruno Muratore             7             9
# 4       Shane Van Boening  Abdulla a. Al Daham             9             6
# ...                   ...                  ...           ...           ...
# 1354          Carlo Biado           Wu Kun-lin            11             4
# 1355    Shane Van Boening       Chang Jung-lin            11             8
# 1356        Joshua Filler    Alexander Kazakis            11            10
# 1357          Carlo Biado    Shane Van Boening            11             6
# 1358        Joshua Filler          Carlo Biado            13            10
#
#       matchIndex       date                         competition
# 0              1 2010-06-29  2010 WPA World 9-Ball Championship
# 1              2 2010-06-29  2010 WPA World 9-Ball Championship
# 2              3 2010-06-29  2010 WPA World 9-Ball Championship
# 3              4 2010-06-29  2010 WPA World 9-Ball Championship
# 4              5 2010-06-29  2010 WPA World 9-Ball Championship
# ...          ...        ...                                 ...
# 1354         219 2018-12-10  2018 WPA World 9-Ball Championship
# 1355         220 2018-12-10  2018 WPA World 9-Ball Championship
# 1356         221 2018-12-10  2018 WPA World 9-Ball Championship
# 1357         222 2018-12-10  2018 WPA World 9-Ball Championship
# 1358         223 2018-12-10  2018 WPA World 9-Ball Championship
#
# [1359 rows x 7 columns]

# %% [markdown]
# ### US Open

# %%
usopen = pd.read_csv("data/usopen2019.csv")
usopen = usopen.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex', 
                      'tournament':'competition'})
usopen = usopen.drop(columns = ["winnerNationality", "winnerRunouts", 
                                "loserNationality", "loserRunouts","Unnamed: 0" ])
usopen.date = pd.to_datetime(usopen['date'])
usopen
# Out:
#              playerA  playerARacks                  playerB  playerBRacks  \
# 0        Jayson Shaw            11            Marcus Westen             0
# 1     Jason Williams             4             Tom Staveley            11
# 2    Hunter Lombardo            11              Kosuke Tojo            10
# 3        Chad Rhodes             4  Radwan Jameel R Sorouji            11
# 4         Naoyuki Oi             9            Marco Vignola            11
# ..               ...           ...                      ...           ...
# 490    Chang Yu-Lung            11               Liu Haitao            10
# 491       Wu Jiaqing            11                 Wang Can             0
# 492  Jeffrey De Luna             8            Joshua Filler            11
# 493    Chang Yu-Lung             5               Wu Jiaqing            11
# 494    Joshua Filler            13               Wu Jiaqing            10
#
#      matchIndex                date                       competition
# 0             1 2019-04-21 08:43:00  US Open 9 Ball Championship 2019
# 1             2 2019-04-21 08:55:00  US Open 9 Ball Championship 2019
# 2             3 2019-04-21 08:55:00  US Open 9 Ball Championship 2019
# 3             4 2019-04-21 08:55:00  US Open 9 Ball Championship 2019
# 4             5 2019-04-21 08:55:00  US Open 9 Ball Championship 2019
# ..          ...                 ...                               ...
# 490         499 2019-04-25 18:00:00  US Open 9 Ball Championship 2019
# 491         500 2019-04-25 20:57:00  US Open 9 Ball Championship 2019
# 492         501 2019-04-26 09:00:00  US Open 9 Ball Championship 2019
# 493         502 2019-04-26 11:30:00  US Open 9 Ball Championship 2019
# 494         503 2019-04-26 14:40:00  US Open 9 Ball Championship 2019
#
# [495 rows x 7 columns]

# %% [markdown]
# ### Turning Stone Classic 2017

# %%
tstone = pd.read_csv("data/turningstone2017.csv")
tstone = tstone.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex', 
                      'tournament':'competition'})
tstone = tstone.drop(columns = ["winnerNationality", "winnerRunouts", 
                                "loserNationality", "loserRunouts","Unnamed: 0" ])
tstone.date = pd.to_datetime(tstone['date'])
tstone['competition'] = "2017 Turning Stone Classic XXVII 9-Ball Open"

# %% [markdown]
# ### World Pool Masters 2010-2019

# %%
wpm = pd.read_csv('data/worldpoolmasters.csv')
wpm.date = pd.to_datetime(wpm['date'])
wpm
# Out:
#                playerA                 playerB  playerARacks  playerBRacks  \
# 0        David Alcaide  Francisco Sánchez Ruíz             7             3
# 1    Shane Van Boening            Kelly Fisher             7             2
# 2          Wu Jia-qing          Alex Pagulayan             4             7
# 3          Eklent Kaci         Earl Strickland             7             2
# 4        Justin Sajich          Petri Makkonen             7             4
# ..                 ...                     ...           ...           ...
# 154   Toru Kuribayashi        Charlie Williams             8             6
# 155      Thomas Engert          Oliver Ortmann             6             8
# 156     Dennis Orcollo           Roberto Gomez             8             6
# 157   Toru Kuribayashi          Oliver Ortmann             8             3
# 158     Dennis Orcollo        Toru Kuribayashi             8             3
#
#      matchIndex       date              competition
# 0             1 2019-03-29  2019 World Pool Masters
# 1             2 2019-03-29  2019 World Pool Masters
# 2             3 2019-03-29  2019 World Pool Masters
# 3             4 2019-03-29  2019 World Pool Masters
# 4             5 2019-03-29  2019 World Pool Masters
# ..          ...        ...                      ...
# 154          27 2010-05-12  2010 World Pool Masters
# 155          28 2010-05-12  2010 World Pool Masters
# 156          29 2010-05-12  2010 World Pool Masters
# 157          30 2010-05-12  2010 World Pool Masters
# 158          31 2010-05-12  2010 World Pool Masters
#
# [159 rows x 7 columns]

# %% [markdown]
# ### CSI Brackets

# %%
url = "https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=d3cb7d4f-47f1-485e-9f61-6206391d2541"
my_page = requests.get(url)

# %%
# Use content 
soup = BeautifulSoup(my_page.content, "html.parser")

# %%
# TODO

def CSI_scraper(url, date, comp):
    my_page = requests.get(url)

    # Use content 
    soup = BeautifulSoup(my_page.content, "html.parser")

    results_lst = []
    match_index = 1
    for EachPart in soup.select('div[class*="round"]'):
        result = {}
        try:
            # Get player names 
            result["playerA"] = EachPart.find('div', attrs={'class':"p3"}).find('a').text.strip()
            result["playerB"] = EachPart.find('div', attrs={'class':"p2"}).find('a').text.strip()

            # 
            divwc = EachPart.find('div', attrs={'class':"wc"})
            scores = divwc.find_all('div', attrs={'class':"wsc"})
            result["playerARacks"] = int(scores[0].text.strip())
            result["playerBRacks"] = int(scores[1].text.strip())
            result["matchIndex"] = match_index
            match_index += 1
    #         print(result)


            results_lst.append(result)
        except: 
            pass
    #         print("Bad Div")
    wpaPlayers = pd.DataFrame(results_lst)
    wpaPlayers["date"] = date
    wpaPlayers["competition"] = comp
    
    return(wpaPlayers)

# %%
# WPA 2019 Players Championship
url = 'https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=80ed7d8c-ac4c-4dbc-92d0-08d066dd6caa'
wpaPlayers = CSI_scraper(url, datetime.datetime(2019, 4, 16), "2019 WPA Players Championship")
wpaPlayers.to_csv("data/2019WPAPlayersChampionship.csv")

# %%
# WPA 2019 Players Championship Qualifier 1
url = "https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=d91d9c85-ec0c-4c66-a6d6-71c1d992807f"
wpaPlayers1 = CSI_scraper(url, datetime.datetime(2019, 4, 12), "2019 WPA Players Championship Qualifier 1")
wpaPlayers1.to_csv("data/2019WPAPlayersChampionshipQual1.csv")
# print(wpaPlayers1)

# WPA 2019 Players Championship Qualifier 2
url = "https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=d4e1f2bd-3ced-44e0-8231-0ac94a3e588d"
wpaPlayers2 = CSI_scraper(url, datetime.datetime(2019, 4, 13), "2019 WPA Players Championship Qualifier 2")
wpaPlayers2.to_csv("data/2019WPAPlayersChampionshipQual2.csv")
# print(wpaPlayers2)

# WPA 2019 Players Championship Qualifier 3
url = 'https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=59c77d29-0585-4a69-a540-e5aa9bc6476c'
wpaPlayers3 = CSI_scraper(url, datetime.datetime(2019, 4, 14), "2019 WPA Players Championship Qualifier 3")
wpaPlayers3.to_csv("data/2019WPAPlayersChampionshipQual3.csv")
# print(wpaPlayers3)

# WPA 2019 Players Championship Qualifier 4
url = 'https://ctsondemand.com/mobilebracketviewer.aspx?BracketID=7b9973e7-a6cc-460e-bb0e-2457a96e1843'
wpaPlayers4 = CSI_scraper(url, datetime.datetime(2019, 4, 15), "2019 WPA Players Championship Qualifier 4")
wpaPlayers4.to_csv("data/2019WPAPlayersChampionshipQual4.csv")
wpaPlayers4
# Out:
#                  playerA              playerB  playerARacks  playerBRacks  \
# 0        Chris Alexander      Chris Alexander             5             4
# 1          Michael Leahy            Lin Da-Li             1             5
# 2              Mark Todd       Mike Hutcheson             1             5
# 3         Chris McDaniel     Phuc Long Nguyen             5             1
# 4      Lefteris Georgiou        Ray Robles II             5             3
# 5            Tyler Styer        Vilmos Foldes             3             5
# 6            Chris Lulek        Donny Branson             3             5
# 7            Jason Merry     Konrad Piekarski             1             5
# 8     Kostas Koukiadakis         Daniel Baker             2             5
# 9            Gary Lutman  Sanjin Pehlivanovic             5             3
# 10          Dean Goddard            Gabe Owen             2             5
# 11           Kings Santy      Cheng-Chieh Liu             4             5
# 12          Lenny Rakers       Lance  Salazar             0             5
# 13        Raymund Faraon        Luu Minh Phuc             5             1
# 14             Del Smith            Lin Da-Li             1             5
# 15            Jui-An Hsu       Mike Hutcheson             5             1
# 16       Jeffrey De Luna       Chris McDaniel             5             3
# 17          Manuel Perez    Lefteris Georgiou             5             4
# 18          Chris Lawson        Vilmos Foldes             1             5
# 19       Ruslan Chinahov        Donny Branson             5             1
# 20  Marc Vidal Claramunt     Konrad Piekarski             5             3
# 21          Ian Costello         Jeremy Jones             2             5
# 22          Szu-Ting Kuo         Daniel Baker             5             4
# 23            Chris Mohr        Vang Bui Xuan             1             5
# 24         Ozzy Reynolds          Gary Lutman             5             4
# 25          Ken Thompson            Gabe Owen             1             5
# 26          Jalal Yousef      Cheng-Chieh Liu             5             1
# 27            Che-Wei Fu       Lance  Salazar             5             4
# 28        Raymund Faraon          Blake Baker             5             1
# 29             Lin Da-Li           Jui-An Hsu             0             5
# 30       Jeffrey De Luna         Manuel Perez             5             2
# 31         Vilmos Foldes      Ruslan Chinahov             1             5
# 32  Marc Vidal Claramunt         Jeremy Jones             5             2
# 33          Szu-Ting Kuo        Vang Bui Xuan             5             4
# 34         Ozzy Reynolds            Gabe Owen             4             5
# 35          Jalal Yousef           Che-Wei Fu             2             5
# 36        Raymund Faraon           Jui-An Hsu             5             1
# 37       Jeffrey De Luna      Ruslan Chinahov             5             3
# 38  Marc Vidal Claramunt         Szu-Ting Kuo             4             5
# 2          James Aranas        Niels Feijen             6             7
# 3     Andrew Wroblewski      Kurt Kobayashi             5             7
# 4        Chris McDaniel     Masato Yoshioka             7            55
# ..                  ...                 ...           ...           ...
# 99   Maximilian Lechner       Ping-Chung Ko             6             7
# 100        Niels Feijen  Carlos Ariel Casto             7             1
# 101   Mieszko Fortunski       Ping-Chung Ko             7             2
# 102        Niels Feijen   Mieszko Fortunski             7             2
# 103        Niels Feijen   Mieszko Fortunski             9             8
#
#      matchIndex       date                               competition
# 0             1 2019-07-17  2019 Diamond Las Vegas Open Championship
# 1             2 2019-07-17  2019 Diamond Las Vegas Open Championship
# 2             3 2019-07-17  2019 Diamond Las Vegas Open Championship
# 3             4 2019-07-17  2019 Diamond Las Vegas Open Championship
# 4             5 2019-07-17  2019 Diamond Las Vegas Open Championship
# ..          ...        ...                                       ...
# 99          100 2019-07-17  2019 Diamond Las Vegas Open Championship
# 100         101 2019-07-17  2019 Diamond Las Vegas Open Championship
# 101         102 2019-07-17  2019 Diamond Las Vegas Open Championship
# 102         103 2019-07-17  2019 Diamond Las Vegas Open Championship
# 103         104 2019-07-17  2019 Diamond Las Vegas Open Championship
#
# [104 rows x 7 columns]

# %%
csiFull = pd.merge(wpaPlayers, wpaPlayers1, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
csiFull = pd.merge(csiFull, wpaPlayers2, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
csiFull = pd.merge(csiFull, wpaPlayers3, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
csiFull = pd.merge(csiFull, wpaPlayers4, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

csiFull = pd.merge(csiFull, lasVegas, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

csiFull['playerA'] = csiFull['playerA'].str.strip()
csiFull['playerB'] = csiFull['playerB'].str.strip()
csiFull
# Out:
#                 playerA                 playerB  playerARacks  playerBRacks  \
# 0          Alex Kazakis        Toru Kuribayashi             2             7
# 1          Shaun Wilkie            Billy Thorpe             7             5
# 2        David Anderson              Max Eberle             7             5
# 3            Che-Wei Fu          Yu Hsuan Cheng             4             7
# 4         Chris Melling  Cristopher Tevez Ocamp             7             3
# ..                  ...                     ...           ...           ...
# 342  Maximilian Lechner           Ping-Chung Ko             6             7
# 343        Niels Feijen      Carlos Ariel Casto             7             1
# 344   Mieszko Fortunski           Ping-Chung Ko             7             2
# 345        Niels Feijen       Mieszko Fortunski             7             2
# 346        Niels Feijen       Mieszko Fortunski             9             8
#
#      matchIndex       date                               competition
# 0             1 2019-04-16             2019 WPA Players Championship
# 1             2 2019-04-16             2019 WPA Players Championship
# 2             3 2019-04-16             2019 WPA Players Championship
# 3             4 2019-04-16             2019 WPA Players Championship
# 4             5 2019-04-16             2019 WPA Players Championship
# ..          ...        ...                                       ...
# 342         100 2019-07-17  2019 Diamond Las Vegas Open Championship
# 343         101 2019-07-17  2019 Diamond Las Vegas Open Championship
# 344         102 2019-07-17  2019 Diamond Las Vegas Open Championship
# 345         103 2019-07-17  2019 Diamond Las Vegas Open Championship
# 346         104 2019-07-17  2019 Diamond Las Vegas Open Championship
#
# [347 rows x 7 columns]

# %% [markdown]
# ### 2019 Mezz Bucharest Open

# %%
mezz = pd.read_csv("data/MezzBucharestOpen2019.csv")
mezz.date = pd.to_datetime(mezz['date'])
mezz
# Out:
#      matchIndex                playerA                 playerB  playerARacks  \
# 0             1      Wojciech Szewczyk               Serge Das             9
# 1             2       Micha? Muklewicz           Gentjan Lengu             9
# 2             3       Antonis Vourthis           Ferdi Özdemir             9
# 3             4      Alexandru Tintaru   Arkadiusz Giernalczyk             0
# 4             5          Marcus Chamat  Preda Robert Alexandru             9
# ..          ...                    ...                     ...           ...
# 481         482           Jakub Koniar       Wojciech Szewczyk            10
# 482         483            Fedor Gorst       Shane Van Boening            10
# 483         484  Damianos Giallourakis             Jayson Shaw             6
# 484         485           Jakub Koniar             Fedor Gorst             4
# 485         486            Jayson Shaw             Fedor Gorst             9
#
#      playerBRacks       date               competition
# 0               8 2019-03-22  2019 Mezz Bucharest Open
# 1               1 2019-03-22  2019 Mezz Bucharest Open
# 2               6 2019-03-22  2019 Mezz Bucharest Open
# 3               9 2019-03-22  2019 Mezz Bucharest Open
# 4               2 2019-03-22  2019 Mezz Bucharest Open
# ..            ...        ...                       ...
# 481             9 2019-03-22  2019 Mezz Bucharest Open
# 482             5 2019-03-22  2019 Mezz Bucharest Open
# 483            10 2019-03-22  2019 Mezz Bucharest Open
# 484            11 2019-03-22  2019 Mezz Bucharest Open
# 485            10 2019-03-22  2019 Mezz Bucharest Open
#
# [486 rows x 7 columns]

# %% [markdown]
# ### WPS Events

# %%
def cueScoreScraper(url, comp):
    my_page = requests.get(url)

    # Use content 
    soup = BeautifulSoup(my_page.content, "html.parser")

    # Get div of interest
    table = soup.find('table', attrs={'class' : 'score'})

    trtags = table.find_all('tr',  attrs={'class' : 'match'})

    # Helper Function to get information 
    def get_info(winner, winnerScore, loser, loserScore): 
        result = {}
        result["winner"] = winner.find('div', attrs={'class': 'name'}).text.strip()
        result["winnerNationality"] = winner.find('div', attrs={'class': 'flag'}).find('img').get("title")
        result["winnerRunouts"] = winner.find('div', attrs={'class': 'runouts'}).text.strip("R")
        if result["winnerRunouts"] == '':
            result["winnerRunouts"] = 0
        result["winnerScore"] = winnerScore

        result["loser"] = loser.find('div', attrs={'class': 'name'}).text.strip()
        result["loserNationality"] = loser.find('div', attrs={'class': 'flag'}).find('img').get("title")
        result["loserRunouts"] = loser.find('div', attrs={'class': 'runouts'}).text.strip("R")
        if result["loserRunouts"] == '':
            result["loserRunouts"] = 0
        result["loserScore"] = loserScore
        return(result)

    results_lst = []
    for row in trtags: 

        # Determine winner and loser
        playerAScore = row.find('td', attrs={'class': 'scoreA'}).find('input').get("value")
        if playerAScore == "-" or playerAScore == "DIS": 
            pass
        else:
            playerBScore = row.find('td', attrs={'class': 'scoreB'}).find('input').get("value")
            if playerAScore > playerBScore: 
                winner = row.find('td', attrs={'class': 'playerA'})
                loser = row.find('td', attrs={'class': 'playerB'})
                result = get_info(winner, playerAScore, loser, playerBScore)
            else: 
                winner = row.find('td', attrs={'class': 'playerB'})
                loser = row.find('td', attrs={'class': 'playerA'})
                result = get_info(winner, playerBScore, loser, playerAScore)

            # Get Match Number
            result['matchNum'] = row.find('td', attrs={'class': 'matchno'}).text.strip()
            # Get Match Time

            result['matchTime'] = row.find('td', attrs={'class': 'time'}).get('title')

            if result['winnerScore'] == "FF": 
                pass
            else: 
                results_lst.append(result) 

    final = pd.DataFrame(results_lst)
    final['competition'] = comp
    final.winnerScore = final.winnerScore.astype(str).astype(int)
    final.loserScore = final.loserScore.astype(str).astype(int)
    final.matchNum = final.matchNum.astype(str).astype(int)
    
    final = final.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex'})
    final = final.drop(columns = ["winnerNationality", "winnerRunouts", 
                                    "loserNationality", "loserRunouts"])
    final.date = pd.to_datetime(final['date'])
    return(final)

# %%
url = 'https://cuescore.com/tournament/5th+Mezz+Cues+-+Stella+Artois+Open+Main+Event/7294542'
stella = cueScoreScraper(url, "2020 Stella Artois Open Main Event")
stella
# Out:
#                    playerA  playerARacks                 playerB  \
# 0             Ronald Regli             7            Nick Dierckx
# 1            Cyriel Ledoux             7            Birtan Canöz
# 2          Cliff Castelein             7            Lynn Pijpers
# 3            Tim De Ruyter             7            Jakub Koniar
# 4         Alex Montpellier             7            Rene Peeters
# 5              Jayson Shaw             7       Dimitris Loukatos
# 6          David Vanhauter             7           Frank Waerlop
# 7        Moritz Lauwereyns             7            Aris Çakiris
# 8        Mieszko Fortuński             7         Kacper Kielmans
# 9      Sanjin Pehlivanovic             7           Fran Palacios
# 10     Wojciech Sroczynski             7        Piotr Haraszczuk
# 11       Rattapol Sassmann             7             Davy de Lee
# 12         Olivér Szolnoki             7              Hoa Nguyen
# 13  David Alcaide Bermudez             7              Ivar Saris
# 14             Max Lechner             7              Adam Lewis
# 15           Mickey Krause             7            Erwin Artels
# 16           Daniel Maciol             7            Ronald Regli
# 17             Fedor Gorst             7           Cyriel Ledoux
# 18                Mario He             7         Cliff Castelein
# 19             Eklent KaÇi             7           Tim De Ruyter
# 20        Alex Montpellier             7       Elliott Sanderson
# 21             Jayson Shaw             7        Wiktor Zieliński
# 22           Albin Ouschan             7         David Vanhauter
# 23      Konrad Juszczyszyn             7       Moritz Lauwereyns
# 24       Mieszko Fortuński             7       Wojciech Szewczyk
# 25  Francisco Sanchez Ruiz             7     Sanjin Pehlivanovic
# 26       Francesco Candela             7     Wojciech Sroczynski
# 27             Denis Grabe             7       Rattapol Sassmann
# 28         Olivér Szolnoki             7           Chris Melling
# 29            Niels Feijen             7  David Alcaide Bermudez
# 30             Max Lechner             7            Alex Kazakis
# 31         Ruslan Chinahov             7           Mickey Krause
# 32           Mickey Krause             7            Nick Dierckx
# 33            Alex Kazakis             7            Birtan Canöz
# 34  David Alcaide Bermudez             7            Lynn Pijpers
# 35            Jakub Koniar             7           Chris Melling
# 36            Rene Peeters             7       Rattapol Sassmann
# 37       Dimitris Loukatos             7     Wojciech Sroczynski
# 38     Sanjin Pehlivanovic             7           Frank Waerlop
# 39       Wojciech Szewczyk             7            Aris Çakiris
# 40       Moritz Lauwereyns             7         Kacper Kielmans
# 41         David Vanhauter             7           Fran Palacios
# 42        Wiktor Zieliński             7        Piotr Haraszczuk
# 43             Davy de Lee             7       Elliott Sanderson
# 44              Hoa Nguyen             7           Tim De Ruyter
# 45         Cliff Castelein             7              Ivar Saris
# 46              Adam Lewis             7           Cyriel Ledoux
# 47            Ronald Regli             7            Erwin Artels
# 48             Fedor Gorst             7           Daniel Maciol
# 49             Eklent KaÇi             7                Mario He
# 50             Jayson Shaw             7        Alex Montpellier
# 51      Konrad Juszczyszyn             7           Albin Ouschan
# 52       Mieszko Fortuński             7  Francisco Sanchez Ruiz
# 53             Denis Grabe             7       Francesco Candela
# 54            Niels Feijen             7         Olivér Szolnoki
# 55             Max Lechner             7         Ruslan Chinahov
# 56           Mickey Krause             7            Alex Kazakis
# 57  David Alcaide Bermudez             7            Jakub Koniar
# 58       Dimitris Loukatos             7            Rene Peeters
# 59     Sanjin Pehlivanovic             7       Wojciech Szewczyk
# 60       Moritz Lauwereyns             7         David Vanhauter
# 61        Wiktor Zieliński             7             Davy de Lee
# 62         Cliff Castelein             7              Hoa Nguyen
# 63            Ronald Regli             7              Adam Lewis
# 64           Albin Ouschan             7           Mickey Krause
# 65        Alex Montpellier             7  David Alcaide Bermudez
# 66                Mario He             7       Dimitris Loukatos
# 67     Sanjin Pehlivanovic             7           Daniel Maciol
# 68         Ruslan Chinahov             7       Moritz Lauwereyns
# 69        Wiktor Zieliński             7         Olivér Szolnoki
# 70       Francesco Candela             7         Cliff Castelein
# 71            Ronald Regli             7  Francisco Sanchez Ruiz
# 72             Fedor Gorst             9     Sanjin Pehlivanovic
# 73             Eklent KaÇi             9         Ruslan Chinahov
# 74             Jayson Shaw             9        Wiktor Zieliński
# 75      Konrad Juszczyszyn             9        Alex Montpellier
# 76       Mieszko Fortuński             9       Francesco Candela
# 77             Denis Grabe             9            Ronald Regli
# 78            Niels Feijen             9                Mario He
# 79             Max Lechner             9           Albin Ouschan
# 80             Eklent KaÇi             9             Fedor Gorst
# 81      Konrad Juszczyszyn             9             Jayson Shaw
# 82             Denis Grabe             9       Mieszko Fortuński
# 83            Niels Feijen             9             Max Lechner
# 84             Eklent KaÇi             9      Konrad Juszczyszyn
# 85             Denis Grabe             9            Niels Feijen
# 86             Eklent KaÇi             9             Denis Grabe
#
#     playerBRacks  matchIndex                date  \
# 0              3           1 2020-02-09 09:00:00
# 1              5           2 2020-02-09 09:05:00
# 2              2           3 2020-02-09 09:00:00
# 3              3           4 2020-02-09 09:05:00
# 4              3           5 2020-02-09 09:00:00
# 5              0           6 2020-02-09 09:05:00
# 6              6           7 2020-02-09 09:47:00
# 7              5           8 2020-02-09 09:45:00
# 8              0           9 2020-02-09 09:56:00
# 9              2          10 2020-02-09 10:01:00
# 10             3          11 2020-02-09 10:01:00
# 11             3          12 2020-02-09 10:02:00
# 12             5          13 2020-02-09 10:58:00
# 13             4          14 2020-02-09 10:58:00
# 14             6          15 2020-02-09 11:10:00
# 3  2018-04-21 12:11:00  2018 Simonis 9-Ball Players Championship
# 4  2018-04-21 13:49:00  2018 Simonis 9-Ball Players Championship
# 5  2018-04-21 13:49:00  2018 Simonis 9-Ball Players Championship
# 6  2018-04-21 13:49:00  2018 Simonis 9-Ball Players Championship
# 7  2018-04-21 13:49:00  2018 Simonis 9-Ball Players Championship
# 8  2018-04-21 16:26:00  2018 Simonis 9-Ball Players Championship
# 9  2018-04-21 16:26:00  2018 Simonis 9-Ball Players Championship
# 10 2018-04-21 16:27:00  2018 Simonis 9-Ball Players Championship
# 11 2018-04-21 16:27:00  2018 Simonis 9-Ball Players Championship
# 12 2018-04-21 18:56:00  2018 Simonis 9-Ball Players Championship
# 13 2018-04-21 18:56:00  2018 Simonis 9-Ball Players Championship
# 14 2018-04-22 14:27:00  2018 Simonis 9-Ball Players Championship

# %%
url = 'https://cuescore.com/tournament/WPS+US+Open+Qualifier/3665330'
wps = cueScoreScraper(url, "2020 US Open WPS Qualifier")
wps
# Out:
#             playerA  playerARacks          playerB  playerBRacks  matchIndex  \
# 0      Tommy Tokoph             9     Alex Kazakis            11           2
# 1  Alex Borukhovich             8    Michael Leahy            11           7
# 2      Alex Kazakis             4   Petri Makkonen            11           9
# 3     Ray Feliciano             4  Maksim Dudanets            11          10
# 4        John Morra             8      Denis Grabe            11          11
# 5     Michael Leahy             2    Joshua Filler            11          12
# 6    Petri Makkonen             9  Maksim Dudanets            11          13
# 7       Denis Grabe             9    Joshua Filler            11          14
# 8     Joshua Filler            11  Maksim Dudanets            10          15
#
#                  date                 competition
# 0 2019-01-21 11:37:00  2020 US Open WPS Qualifier
# 1 2019-01-21 11:37:00  2020 US Open WPS Qualifier
# 2 2019-01-21 13:48:00  2020 US Open WPS Qualifier
# 3 2019-01-21 11:38:00  2020 US Open WPS Qualifier
# 4 2019-01-21 11:38:00  2020 US Open WPS Qualifier
# 5 2019-01-21 14:10:00  2020 US Open WPS Qualifier
# 6 2019-01-21 15:17:00  2020 US Open WPS Qualifier
# 7 2019-01-21 15:26:00  2020 US Open WPS Qualifier
# 8 2019-01-21 17:18:00  2020 US Open WPS Qualifier

# %%
wps = pd.merge(wps, stella, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date','matchIndex',
                                          "competition"], 
                  how='outer')
wps = pd.merge(wps, aramith, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
wps = pd.merge(wps, simonis, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
wps
# Out:
#               playerA  playerARacks          playerB  playerBRacks  \
# 0        Tommy Tokoph             9     Alex Kazakis            11
# 1    Alex Borukhovich             8    Michael Leahy            11
# 2        Alex Kazakis             4   Petri Makkonen            11
# 3       Ray Feliciano             4  Maksim Dudanets            11
# 4          John Morra             8      Denis Grabe            11
# ..                ...           ...              ...           ...
# 163       Klentì KaÇi             9    Kenney Nguyen             2
# 164     Joshua Filler             9   Raphael Dabreo             4
# 165       Jayson Shaw             9  Hunter Lombardo             1
# 166       Klentì KaÇi             9    Joshua Filler             6
# 167       Jayson Shaw             7      Klentì KaÇi            11
#
#      matchIndex                date                               competition
# 0             2 2019-01-21 11:37:00                2020 US Open WPS Qualifier
# 68  Shane Van Boening             3  2012 Mosconi Cup
# 69       Dennis Hatch             3  2012 Mosconi Cup
# 70      Johnny Archer             5  2012 Mosconi Cup
# 71      Brandon Shuff             2  2012 Mosconi Cup
# 72  Shane Van Boening             0  2012 Mosconi Cup
# 73       Dennis Hatch             5  2012 Mosconi Cup
# 74      Johnny Archer             5  2012 Mosconi Cup
# 75  Shane Van Boening             5  2012 Mosconi Cup
# 76      Brandon Shuff             2  2012 Mosconi Cup
# 77      Mike Dechaine             2  2012 Mosconi Cup
# 78      Rodney Morris             0  2011 Mosconi Cup
# 79  Shane Van Boening             5  2011 Mosconi Cup
# 80      Mike Dechaine             6  2011 Mosconi Cup
# 81      Johnny Archer             1  2011 Mosconi Cup
# 82       Shawn Putnam             2  2011 Mosconi Cup
# 83  Shane Van Boening             6  2011 Mosconi Cup
# 84      Mike Dechaine             2  2011 Mosconi Cup
# 85  Shane Van Boening             6  2011 Mosconi Cup
# 86      Johnny Archer             6  2011 Mosconi Cup
# 87      Rodney Morris             4  2011 Mosconi Cup
# 88        Corey Deuel             6  2010 Mosconi Cup
# 89      Johnny Archer             6  2010 Mosconi Cup
# 90  Shane Van Boening             6  2010 Mosconi Cup
# 91      Rodney Morris             2  2010 Mosconi Cup
# 92       Dennis Hatch             4  2010 Mosconi Cup
# 93      Rodney Morris             1  2010 Mosconi Cup
# 94      Johnny Archer             6  2010 Mosconi Cup
# 95       Dennis Hatch             6  2010 Mosconi Cup
# 96  Shane Van Boening             2  2010 Mosconi Cup
# 97        Corey Deuel             4  2010 Mosconi Cup

# %% [markdown]
# # King 8

# %%
url = 'https://cuescore.com/tournament/KING8+ATHENS+9-BALL+OPEN+2020/6814919'
athens = cueScoreScraper(url, "2020 King8 Athens 9-Ball Open")
athens = athens.loc[athens.matchIndex >= 417]

# %% [markdown]
# # Dismal Swamp 2019

# %%
url = 'https://cuescore.com/tournament/Dismal+Swamp+Classic+2019/6683562'
def cueScoreScraper_swamp(url, comp):
    my_page = requests.get(url)

    # Use content 
    soup = BeautifulSoup(my_page.content, "html.parser")

    # Get div of interest
    table = soup.find('table', attrs={'class' : 'score'})

    trtags = table.find_all('tr',  attrs={'class' : 'match'})

    # Helper Function to get information 
    def get_info(winner, winnerScore, loser, loserScore): 
        result = {}
        result["winner"] = winner.find('div', attrs={'class': 'name'}).text.strip()
        result["winnerNationality"] = winner.find('div', attrs={'class': 'flag'}).find('img').get("title")
        result["winnerRunouts"] = winner.find('div', attrs={'class': 'runouts'}).text.strip("R")
        if result["winnerRunouts"] == '':
            result["winnerRunouts"] = 0
        result["winnerScore"] = winnerScore

        result["loser"] = loser.find('div', attrs={'class': 'name'}).text.strip()
        result["loserNationality"] = loser.find('div', attrs={'class': 'flag'}).find('img').get("title")
        result["loserRunouts"] = loser.find('div', attrs={'class': 'runouts'}).text.strip("R")
        if result["loserRunouts"] == '':
            result["loserRunouts"] = 0
        result["loserScore"] = loserScore
        return(result)

    results_lst = []
    for row in trtags: 

        # Determine winner and loser
        playerAScore = row.find('td', attrs={'class': 'scoreA'}).find('input').get("value")
        if playerAScore == "-" or playerAScore == "DIS": 
            pass
        else:
            playerBScore = row.find('td', attrs={'class': 'scoreB'}).find('input').get("value")
            if playerAScore > playerBScore: 
                winner = row.find('td', attrs={'class': 'playerA'})
                loser = row.find('td', attrs={'class': 'playerB'})
                result = get_info(winner, playerAScore, loser, playerBScore)
            else: 
                winner = row.find('td', attrs={'class': 'playerB'})
                loser = row.find('td', attrs={'class': 'playerA'})
                result = get_info(winner, playerBScore, loser, playerAScore)

            # Get Match Number
            result['matchNum'] = row.find('td', attrs={'class': 'matchno'}).text.strip()
            # Get Match Time

            result['matchTime'] = row.find('td', attrs={'class': 'time'}).get('title')

            if result['winnerScore'] == "FF": 
                pass
            else: 
                results_lst.append(result) 

    final = pd.DataFrame(results_lst)
    final['competition'] = comp
    final.winnerScore = final.winnerScore.astype(str).astype(int)
    final.loserScore = final.loserScore.astype(str).astype(int)
    final.matchNum = final.matchNum.astype(str).astype(int)
    
    final = final.rename(columns = {"winner":"playerA", 
                      "loser": "playerB", 
                      "winnerScore":"playerARacks", 
                      "loserScore":"playerBRacks",
                      "Round":"round", 
                      "matchTime":'date',
                      "matchNum": 'matchIndex'})
    final = final.drop(columns = ["winnerNationality", "winnerRunouts", 
                                    "loserNationality", "loserRunouts"])
#     final.date = pd.to_datetime(final['date'])
    return(final)
swamp = cueScoreScraper_swamp(url, "2019 Dismal Swamp Classic")

swamp['date'].loc[4] = "24.Oct 2019 22:41"
swamp['date'].loc[57] = "26.Oct 2019 16:34"
swamp['date'].loc[58] = "26.Oct 2019 16:35"
swamp.date = pd.to_datetime(swamp['date'])
swamp
# Out:
# /Users/sethbilliau/python-virtual-environments/thesis/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                playerA  playerARacks                playerB  playerBRacks  \
# 0    Shane Van Boening             8            Fedor Gorst             4
# 1          Pedro Botta             8         Austin Diluzio             2
# 2         James Aranas             8  Damianos Giallourakis             1
# 3            Robb Saez             8        Justin Martinez             7
# 4         Jalal Yousef             8             John Morra             5
# 5        Tommy Kennedy             8       Christopher Pyle             1
# 6          Denis Grabe             8          Spencer Ladin             3
# 7       Chris Robinson             8          Gary Urinoski             1
# 8   Nick Ekonomopoulos             8             Brian Lane             5
# 9      Billy Jr Ussery             8      Demetrius Jelatis             2
# 10         Jayson Shaw             8        Kenny Daughtrey             4
# 11     Skyler Woodward             8           Alex Kazakis             4
# 12       Roberto Gomez             8       Michael DeLawder             4
# 13       Chris Melling             8            Jesse Engel             1
# 14    Wiktor Zieliński             8      (Ryan) Hsu Jui-An             5
# 15   Shane Van Boening             8            Pedro Botta             2
# 16        James Aranas             8              Robb Saez             1
# 17        Josh Roberts             8           Jalal Yousef             4
# 18         Denis Grabe             8          Tommy Kennedy             4
# 19  Nick Ekonomopoulos             8         Chris Robinson             2
# 20         Jayson Shaw             8        Billy Jr Ussery             3
# 21       Roberto Gomez             8        Skyler Woodward             3
# 22       Chris Melling             8       Wiktor Zieliński             7
# 23         Fedor Gorst             8         Austin Diluzio             0
# 142         163 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 143         164 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 144         165 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 145         166 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 146         167 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 147         168 2019-03-16 08:29:00  2019 Datel Tallinn 9-Ball Open
# 148         169 2019-03-16 10:38:00  2019 Datel Tallinn 9-Ball Open
# 149         170 2019-03-16 10:38:00  2019 Datel Tallinn 9-Ball Open
# 150         171 2019-03-16 10:39:00  2019 Datel Tallinn 9-Ball Open
# 151         172 2019-03-16 10:39:00  2019 Datel Tallinn 9-Ball Open
# 152         173 2019-03-16 12:57:00  2019 Datel Tallinn 9-Ball Open
# 153         174 2019-03-16 14:43:00  2019 Datel Tallinn 9-Ball Open
# 154         175 2019-03-16 16:20:00  2019 Datel Tallinn 9-Ball Open

# %% [markdown]
# # Black Sea Cup 2019

# %%
url = 'https://cuescore.com/tournament/Black+Sea+Cup+2018/2818115'
blacksea = cueScoreScraper(url, "2018 Black Sea Cup")
blacksea
# Out:
#                     playerA  playerARacks                 playerB  \
# 0               Kagan Batir             9          Ruslan Popescu
# 1            Thomas Poeschi             9              Ivan Nunez
# 2            Ciprian Gindac             9         Cristian Bartos
# 3             Albin Ouschan             9         Ivaylo Simeonov
# 4            Traian Marinca             9             Taner Ayvaz
# 5              Dinca Steriu             9      Tiberiu Iorgulescu
# 6              Ioan Ladanyi             9      Kostas Koukiadakis
# 7             Kercso Zoltan             9        Claudiu Cristian
# 8           Levent Kurtuluş             9         Zurab Tsereteli
# 9          Babken Melkonyan             9             Kagan Batir
# 10        Dimitris Loukatos             9              Nick Malaj
# 11             Stefan Boaca             9            Bela Kulcear
# 12        Alexandru Cotescu             9          Beka Biashvili
# 13          Raileanu Silviu             9          Thomas Poeschi
# 14   PANAGIOTIS KSIPOLITEAS             9      Branislav Varbanov
# 15          Chiritoiu Liviu             9           Razvan Antohi
# 16           Ciprian Gindac             9           Chris Melling
# 17            Albin Ouschan             9             Emo Angelov
# 18       Konrad Juszczyszyn             9               Gabi Gosa
# 19          Ruslan Chinahov             9            Bogdan Sacal
# 20          Cristian Surdea             9      Vahdet Emre Varlik
# 21        Wojciech Szewczyk             9        Wiktor Zielinski
# 22             Marek Kudlik             9               Gabi Sera
# 23          ANDREI GALATANU             9         Madalina Ciocan
# 24             Mario Toader             9          Traian Marinca
# 25        Mieszko Fortunski             9            Dinca Steriu
# 26              Fedor Gorst             9          Claudiu Alicus
# 27              Denis Grabe             9            Robert Braga
# 28      valer florin tundra             9     Spataru Razvan Ilie
# 29           Ovidiu Cristea             9             Raul Maican
# 30        Marc Bijsterbosch             9            Niels Feijen
# 31            Joshua Filler             9            Nic Berendea
# 32             Ralf Souquet             9            Ioan Ladanyi
# 33            Kercso Zoltan             9        Dragos Radulescu
# 34        Stanimir Ruslanov             9             Eklent Kaci
# 35               GENER AMET             9             Jayson Shaw
# 36            Daniel Maciol             9              Pia Filler
# 37             Alex Kazakis             9                Mario He
# 38              Adam Mscisz             9         Valentin Laslau
# 39        Sorin Nicolae Son             9          Adrian Mitrana
# 40          Levent Kurtuluş             9      Corneliu Volosciuc
# 41       Corneliu Volosciuc             9          Ruslan Popescu
# 42               Ivan Nunez             9              Pia Filler
# 43         Dragos Radulescu             9         Cristian Bartos
# 44             Ioan Ladanyi             9         Ivaylo Simeonov
# 45             Dinca Steriu             9             Taner Ayvaz
# 46           Traian Marinca             9      Tiberiu Iorgulescu
# 47              Emo Angelov             9      Kostas Koukiadakis
# 48         Claudiu Cristian             9           Chris Melling
# 49          Zurab Tsereteli             9             Kagan Batir
# 50        Dimitris Loukatos             9        Babken Melkonyan
# 51        Alexandru Cotescu             9            Stefan Boaca
# 52   PANAGIOTIS KSIPOLITEAS             9         Raileanu Silviu
# 53          Chiritoiu Liviu             9          Ciprian Gindac
# 54            Albin Ouschan             9      Konrad Juszczyszyn
# 55          Ruslan Chinahov             9         Cristian Surdea
# 56             Marek Kudlik             9       Wojciech Szewczyk
# 57          ANDREI GALATANU             9            Mario Toader
# 58              Fedor Gorst             9       Mieszko Fortunski
# 59              Denis Grabe             9     valer florin tundra
# 60        Marc Bijsterbosch             9          Ovidiu Cristea
# 61            Joshua Filler             9            Ralf Souquet
# 62            Kercso Zoltan             9       Stanimir Ruslanov
# 63            Daniel Maciol             9              GENER AMET
# 64             Alex Kazakis             9             Adam Mscisz
# 65        Sorin Nicolae Son             9         Levent Kurtuluş
# 66       Corneliu Volosciuc             9          Adrian Mitrana
# 67                 Mario He             9         Valentin Laslau
# 68               Ivan Nunez             9             Jayson Shaw
# 69              Eklent Kaci             9        Dragos Radulescu
# 70             Nic Berendea             9            Ioan Ladanyi
# 71             Niels Feijen             9             Raul Maican
# 72      Spataru Razvan Ilie             9            Robert Braga
# 73             Dinca Steriu             9          Claudiu Alicus
# 74           Traian Marinca             9         Madalina Ciocan
# 75         Wiktor Zielinski             9               Gabi Sera
# 76       Vahdet Emre Varlik             9            Bogdan Sacal
# 77              Emo Angelov             9               Gabi Gosa
# 78            Razvan Antohi             9        Claudiu Cristian
# 79           Thomas Poeschi             9      Branislav Varbanov
# 80             Bela Kulcear             9          Beka Biashvili
# 81               Nick Malaj             9         Zurab Tsereteli
# 82             Mario Toader             9      Corneliu Volosciuc
# 83                 Mario He             9       Wojciech Szewczyk
# 84               Ivan Nunez             9         Cristian Surdea
# 85              Eklent Kaci             9      Konrad Juszczyszyn
# 86           Ciprian Gindac             9            Nic Berendea
# 87             Niels Feijen             9         Raileanu Silviu
# 88      Spataru Razvan Ilie             9            Stefan Boaca
# 89         Babken Melkonyan             9            Dinca Steriu
# 90          Levent Kurtuluş             9          Traian Marinca
# 91         Wiktor Zielinski             9             Adam Mscisz
# 92       Vahdet Emre Varlik             9              GENER AMET
# 93        Stanimir Ruslanov             9             Emo Angelov
# 94             Ralf Souquet             9           Razvan Antohi
# 15            Niels Feijen             9         Angelo Millauro
# 16           Arjan Matrizi             9       Francesco Candela
# 17             Eklent KaÇi             9  David Alcaide Bermudez
# 18             Edmond Zaja             9         Mauro Castriota
# 19            Niels Feijen             9            Besar Spahiu
# 20             Eklent KaÇi             9           Arjan Matrizi
# 21            Niels Feijen             9             Edmond Zaja
# 22            Niels Feijen             9             Eklent KaÇi
#
#     playerBRacks  matchIndex                date           competition
# 0              2           2 2019-10-06 09:03:00  2019 ProStar Cup VII
# 1              4           3 2019-10-06 09:03:00  2019 ProStar Cup VII
# 2              7           6 2019-10-06 09:03:00  2019 ProStar Cup VII
# 3              8           7 2019-10-06 09:03:00  2019 ProStar Cup VII
# 4              3          10 2019-10-06 09:03:00  2019 ProStar Cup VII
# 5              8          11 2019-10-06 09:03:00  2019 ProStar Cup VII
# 6              5          14 2019-10-06 09:03:00  2019 ProStar Cup VII
# 7              3          15 2019-10-06 09:03:00  2019 ProStar Cup VII
# 8              0          17 2019-10-06 10:40:00  2019 ProStar Cup VII
# 9              8          18 2019-10-06 11:09:00  2019 ProStar Cup VII
# 10             7          19 2019-10-06 11:34:00  2019 ProStar Cup VII
# 11             1          20 2019-10-06 11:10:00  2019 ProStar Cup VII
# 12             3          21 2019-10-06 10:52:00  2019 ProStar Cup VII
# 13             6          22 2019-10-06 11:14:00  2019 ProStar Cup VII
# 14             6          23 2019-10-06 10:40:00  2019 ProStar Cup VII
# 15             4          24 2019-10-06 11:04:00  2019 ProStar Cup VII
# 16             7          25 2019-10-06 13:53:00  2019 ProStar Cup VII
# 17             7          26 2019-10-06 13:25:00  2019 ProStar Cup VII
# 18             4          27 2019-10-06 13:43:00  2019 ProStar Cup VII
# 19             1          28 2019-10-06 13:08:00  2019 ProStar Cup VII
# 20             8          29 2019-10-06 16:17:00  2019 ProStar Cup VII
# 21             5          30 2019-10-06 15:38:00  2019 ProStar Cup VII
# 22             3          31 2019-10-06 18:13:00  2019 ProStar Cup VII

# %% [markdown]
# # Merge

# %%
fulldf1 = pd.merge(accustats, eurotourwiki, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf2 = pd.merge(fulldf1, wpa, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf3 = pd.merge(fulldf2, usopen, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf4 = pd.merge(fulldf3, tstone, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf5 = pd.merge(fulldf4, mezz, on=["playerA", "playerB", "playerARacks",
                                           "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf6 = pd.merge(fulldf5, wpm, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf7 = pd.merge(fulldf6, csiFull, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf8 = pd.merge(fulldf7, wps, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf9 = pd.merge(fulldf8, mosconi, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf10 = pd.merge(fulldf9, athens, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')

fulldf11 = pd.merge(fulldf10, swamp, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf12 = pd.merge(fulldf11, datel, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf13 = pd.merge(fulldf12, blacksea, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')
fulldf14 = pd.merge(fulldf13, prostar, on=["playerA", "playerB", "playerARacks",
                                   "playerBRacks", 'date', 'matchIndex',
                                          "competition"], 
                  how='outer')


fulldf = fulldf14
fulldf['playerA'] = fulldf['playerA'].str.strip()
fulldf['playerB'] = fulldf['playerB'].str.strip()

fulldf = fulldf.sort_values(by=['date', 'matchIndex']).reset_index(drop=True)
fulldf
# Out:
#       matchIndex matchNumber       date               playerA  playerARacks  \
# 0              1     329B-01 2007-10-14     Shane Van Boening            11
# 1              2     329B-02 2007-10-14     Ernesto Dominguez            11
# 2              3     329B-03 2007-10-14           Tony Robles            11
# 3              4     329B-04 2007-10-14          Louis Ulrich            11
# 4              5     329B-05 2007-10-14  Francisco Bustamante            11
# ...          ...         ...        ...                   ...           ...
# 5080           6         NaN 2020-12-02           Jayson Shaw             5
# 5081           8         NaN 2020-12-02           Fedor Gorst             5
# 5082          10         NaN 2020-12-02           Jayson Shaw             5
# 5083          12         NaN 2020-12-03         Joshua Filler             5
# 5084          14         NaN 2020-12-03           Jayson Shaw             5
#
#                 playerB  playerBRacks          competition
# 0         Ronnie Alcano             4  2007 US Open 9-Ball
# 1     Frankie Hernandez             5  2007 US Open 9-Ball
# 2       Rafael Martinez             5  2007 US Open 9-Ball
# 3        Alex Pagulayan             7  2007 US Open 9-Ball
# 4           Richie Orem             4  2007 US Open 9-Ball
# ...                 ...           ...                  ...
# 5080  Shane Van Boening             4     2020 Mosconi Cup
# 5081        Corey Deuel             2     2020 Mosconi Cup
# 5082       Billy Thorpe             3     2020 Mosconi Cup
# 5083    Skyler Woodward             0     2020 Mosconi Cup
# 5084  Shane Van Boening             3     2020 Mosconi Cup
#
# [5085 rows x 8 columns]

# %%
fulldf = pd.read_csv("data/fulldf.csv")

# %%
def deduplicate_names(series):
    def switcher(argument):
        switcher = {
            'ANDREI GALATANU': 'Andrei Gala',
            'Abderrahmane Mebarki': 'Abder Rehman Mebarki', 
            "Abdulatif Fawal": 'Abdul Latif al-Fawal', 
            'Abdulatif Alfawal': 'Abdul Latif al-Fawal',
            'Abdultif Fawal': 'Abdul Latif al-Fawal',
            'Abdullah Saeed O Alshammari': 'Abdullah Alshammari',
            'Abdulla al-Shemmari': 'Abdullah Alshammari',
            'Abdullah al-Yousef': 'Abdullah al-Yousif',
            'Abdulla al-Yousif': 'Abdullah al-Yousif',
            'Ahmed M. Salah': 'Ahmad Mohamad Sllah',
            'Aleksandar Filipovi?': 'Aleksandar Filipovic',
            'Ali Obaidly': 'Ali al-Obaidly',
            '(Kevin) Cheng Yu Hsuan': 'Kevin Cheng',
            'Cheng Yu-hsuan': 'Kevin Cheng',
            'YUKIO AKAGARIYAMA':'Yukio Akakariyama', 
            'Yukio Akagariyama':'Yukio Akakariyama', 
            'Akagariyama Yukio':'Yukio Akakariyama', 
            'Aleksandros Kazaqi': "Alex Kazakis",
            'Alexander Kazakis': 'Alex Kazakis',
            'Ali Abdulhadi':  'Ali Abdulhadi Almeri',
            'Andrew Kong Bu Hong' :'Andrew Kong',
            'Artem Koshovoj':'Artem Koshovyi',
            'Badr al-Awadi':'Bader al-Awadhi',
            'Casper  Matikainen': 'Casper Matikainen',
            'Casper Maitkainen': 'Casper Matikainen',
            'Carlo Castro': 'Carlos Castro',
            'Carlos Ariel Casto': 'Carlos Castro',
            'Chang Jung Lin': 'Chang Jung-Lin',
            'Chang Jung-lin': 'Chang Jung-Lin',
            'Chang Jun Lin': 'Chang Jung-Lin',
            'Chang Jun Lin': 'Chang Jung-Lin',
            'Chang Jung-Lin': 'Chang Jung-Lin',
            'Jung-Lin Chang': 'Chang Jung-Lin',
            'Jung Lin Chang':'Chang Jung-Lin',
            'Jung-Lin Chang': 'Chang Jung-Lin',
            'Chang Yu-lung': 'Chang Yu-Lung',
            'Chang Yu Lung': 'Chang Yu-Lung',
            'Chao Fong-pang':'Chao Fong-Pang',
            'Charles Williams':'Charlie Williams',
            'Christian Fröhlich': 'Christian Froehlich',
            'Cristian Barto?': 'Cristian Bartos',
            'Dang Jinhu':'Dang Jin Hu',
            'Daniel Macioł': 'Daniel Maciol',
            'Daniel Macio?': 'Daniel Maciol',
            'David Alcaide Bermudez': 'David Alcaide',
            'Darko Stankovi?': 'Darko Stankovic',
            'Dennis Orcullo':'Dennis Orcollo',
            'Deomark Alpajora': 'Deo Alpajora',
            'Dilian Tiklev':'Diliyan Tiklev',
            'Donnie Mills':'Donny Mills',
            'Dương Quốc Hoàng': 'Duong Quoc Hoang',
            'Duong Quac Hoang': 'Duong Quoc Hoang',
            'Hoang Duong Quoc' : 'Duong Quoc Hoang',
            'Eklent Kaçi':'Eklent Kaci',
            'Eklent KaÇi': 'Eklent Kaci',
            'Klentì KaÇi': 'Eklent Kaci',
            'Erik  Hjorleifson':'Erik Hjorleifson',
            'Emil-Andre Gangflot': 'Emil Andre Gangflot',
            'Emil André Gangfløt':'Emil Andre Gangflot',
            'Ekonomopoulos Nick': 'Nikos Ekonomopoulos',
            'Nick Ekonomopoulos': 'Nikos Ekonomopoulos',
            'Fjodor Gorst':'Fedor Gorst',
            'Francisco Díaz-Pizarro':'Francisco Diaz-Pizarro',
            'Francisco SanchezRuiz': 'Francisco Sanchez Ruiz',
            'Francisco Sánchez Ruíz':'Francisco Sanchez Ruiz',
            'Francisco Sanchez-Ruiz':'Francisco Sanchez Ruiz',
            'Francisco Sánchez': 'Francisco Sanchez Ruiz',
            'Franklin Hernandez':'Frankie Hernandez',
            'GENER AMET': 'Gener Amet',
            'Gerson Martinez Boza': 'Gerson Martinez',
            'Gerson Martínez': 'Gerson Martinez',
            'Gerasimos Trivizas': 'Gerasimos Trivyzas',
            'Gorgi Georgiev': 'Georgi Georgiev',
            'Gîndac Ciprian Gabriel': 'Gindac Ciprian Gabriel',
            'HAYATO HIJIKATA':'Hayato Hijikata',
            'Hsieh Chia-chen': 'Hsieh Chia-Chen',
            'Hsu Kai-lun':'Hsu Kai Lun',
            'Hasan Zeraatgar': 'Hassan Zeraatgar',
            'Jan Van Lierop': 'Jan van Lierop',
            'Jalal al-Sarisi':'Jalal Al Sarisi',
            'Javier DelSanto-Sanz': 'Javi Del Santo Sanz',
            'Jeff de Luna':'Jeffrey de Luna',
            'Jeffrey De Luna': 'Jeffrey de Luna',
            'Jeffry De Luna': 'Jeffrey de Luna',
            'Jeong Young-hwa':'Jeong Young Hwa',
            'Jeremy jones':'Jeremy Jones',
            'Jan VanLierop': 'Jan Van Lierop',
            'Johan Palé': 'Johan Pale',
            'John Moody Sr': 'John Moody',
            'John Scmidmt': 'John Schmidt',
            'John Scmidt': 'John Schmidt',
            'Jonas Souto Comino': 'Jonas Souto',
            'Jon De Met': 'Jon Demet',
            'José Alberto Delgado': 'Jose Delgado',
            'José Delgado': 'Jose Delgado',
            'Jose Alberto Delgado': 'Jose Delgado',
            'Kai Lun Hsu':'Kai-Lun Hsu',
            'Khalid K. Almutari': 'Khaled al-Mutairi',
            'Khalid al-Mutairi': 'Khaled al-Mutairi',
            'Ko Pin-Yi (秉逸柯)': 'Ko Pin Yi',
            'Ko Pin-yi':'Ko Pin Yi',
            'Pin Yi Ko': 'Ko Pin Yi',
            'Pin-Yi Ko': 'Ko Pin Yi',
            'Ko Ping-chung': 'Ko Ping-Chung',
            'Ko Ping Chung': 'Ko Ping-Chung',
            'Ping-Chung Ko': "Ko Ping-Chung",
            'Chung Ko Ping': "Ko Ping-Chung",
            'Ko Ping-han': 'Ko Ping Han',
            'konomopoulos': 'Nikos Ekonomopoulos',
            'Konrad Juszcyzszyn': 'Konrad Juszczyszyn',
            'Konrad Juszczyszn': 'Konrad Juszczyszyn',
            'Konstantin Stepanow':'Konstantin Stepanov',
            'Konstantinos Koukiadakis':'Kostas Koukiadakis',
            'Konstantin Koukiadakis': 'Kostas Koukiadakis',
            'Kuo Po Cheng':'Kuo Po-Cheng',
            'Kuo Po Chen':'Kuo Po-Cheng',
            'Lee jun-ho':'Lee Jun-ho',
            'Lee Van Corteza': 'Lee Vann Corteza',
            'Lin Ta Li':'Lin Da-Li',
            'Li Hewen':'Li He Wen',
            'Liu Cheng-chieh': 'Liu Cheng Chieh',
            'Liu Haitao (pool player)': 'Liu Haitao',
            'Liu Hai Tao': 'Liu Haitao',
            'Liu Ri-teng':'Liu Ri Teng',
            'Lương Chí Dũng': 'Luong Chi Dung',
            'Lo Li-wen': 'Lo Li-Wen',
            'Lo Li Wen':'Lo Li-Wen',
            'Lưu Minh Phúc':'Luu Minh Phuc',
            'Majed Alazmi':'Majid N. Alazmi', 
            'Marc Vidal Claramunt': 'Marc Vidal',
            'MASATO YOSHIOKA':'Masato Yoshioka',
            'Mateusz Śniegocki':'Mateusz Sniegocki',
            'Matthew Edwards': 'Matt Edwards',
            'Mauro Catriota': 'Mauro Castriota',
            'Maxim Dudanez':'Maxim Dudanets',
            'Max Lechner' : 'Maximilian Lechner',
            'Maximillian Lechner':'Maximilian Lechner',
            'Mazen Berjaoui':'Mazen Berjawi',
            'Mazen Berjuai':'Mazen Berjawi',
            'Mazin Berjawi':'Mazen Berjawi',
            'Md al-Amin':'MD Almin',
            'Mihai Alexandru Neacsu': 'Mihai Alexandru',
            'Michał Turkowski': 'Michal Turkowski',
            'Meshal al-Murdhi': 'Meshaal al-Murdhi',
            'Mieszko Fortuński':'Mieszko Fortunski',
            'Miesko Fortunski': 'Mieszko Fortunski',
            'Mihkel Rehepap' : 'Mihkel Rehepapp',
            'Mike Hutcheson': 'Michael Hutcheson',
            'Mitch Ellerman': 'Mitchell Ellerman',
            'Mohamad Ali Berjaoui': 'Mohammad-Ali Berjaoui',
            'Mohd. Ali Berjawi': 'Mohammad-Ali Berjaoui',
            'Mohammed Berjaui':  'Mohammad-Ali Berjaoui',
            'Mohammad Berjaoui':  'Mohammad-Ali Berjaoui',
            'NiMohammad-Ali Berjaoui': 'Mohammad-Ali Berjaoui',
            'Mohammad Berjawi': 'NiMohammad-Ali Berjaoui',
            'Mohamad Ali-Berjaoui': 'Mohammad-Ali Berjaoui',
            'Mohammad Sharif (pool player)':'Mohammad Sharif',
            'Mohammed Saeed (pool player)':'Mohammed Saeed',
            'Muhammad Zulfikiri': 'Muhammad Zulfikri',
            'Mike Yednak': 'Michael Yednak',
            'Naoyuki Ōi': 'Naoyuki Oi',
            'Nick Malaj': 'Nick Malai',
            'Nikos Milaj': 'Nick Malai',
            'Malaj Nick': 'Nick Malai',
            'Olivér Szolnoki': 'Oliver Szolnoki',
            'Omar Alshaheen': 'Omar al-Shaheen',
            'Omar Al-Shaheen':'Omar al-Shaheen',
            'Omar Al Shaheen': 'Omar al-Shaheen',
            'Óscar Domínguez':'Oscar Dominguez',
            'PANAGIOTIS KSIPOLITEAS': 'Panagiotis Ksipoliteas',
            'Patrick Flemming': 'Patrick Fleming',
            'Philipps Yee':'Phill Yee',
            'Philipp Stojanović' : 'Philipp Stojanovic',
            'Radislaw Babica': 'Radoslaw Babica',
            'Radosław Babica': 'Radoslaw Babica',
            'Ralf Souqet':'Ralf Souquet',
            'Raymund Faron':'Raymund Faraon',
            'Raymund Farun':'Raymund Faraon',
            'Roberto Gomez Jr': 'Roberto Gomez',
            'Ronato Alcano': 'Ronnie Alcano',
            'Ruben Bautista Escaler': 'Ruben Bautista',
            'Rubén Bautista': 'Ruben Bautista',
            'Ruslan Chinachov': 'Ruslan Chinakhov',
            'Ruslan Chinahov': 'Ruslan Chinakhov',
            'Ruslan Tschinachow': 'Ruslan Chinakhov',
            'Salah al-Remawi':'Salah Al Riwani',
            'Salaheldeen Al Rimawi':'Salah Al Riwani',
            'Sanjin Pehlivanović': 'Sanjin Pehlivanovic',
            'Santos Sambajon Jr.': 'Santos Sambajon',
            'Sean C Morgan': 'Sean Morgan',
            'Sergei Luzker':  'Sergey Lutsker',
            'Stanimir Ruslanov':  'Stanimir Ruslanow',
            'Sergey LUTSKER': 'Sergey Lutsker', 
            'Stefanel Nelu Boaca' : 'Stefan Boaca',
            'Tomasz Kapłan':'Tomasz Kaplan',
            'Tim DeRuyter': 'Tim De Ruyter',
            'Tim de Ruyter':'Tim De Ruyter',
            'Tōru Kuribayashi':'Toru Kuribayashi',
            'Toru Kurabiyashi': "Toru Kuribayashi",
            'Tohru Kuribayashi' : "Toru Kuribayashi",
            "Toru Kurabayashi" : 'Toru Kuribayashi',
            'Tom Theriault' : 'Tom Teriault',
            'Vilmos Földes': 'Vilmos Foldes',
            'Vinancio Tanio' : 'Venancio Tanio',
            'Wang Can (pool player)': 'Wang Can',
            'Wiktor Zieliński':'Wiktor Zielinski',
            'Wojciech Sroczyński':'Wojciech Sroczynski',
            'Wu Jia-qing': 'Wu Jiaqing',
            'Wu Kun Lin': 'Wu Kun-Lin',
            'Wu Kun-lin': 'Wu Kun-Lin',
            'Yang Ching-shun': 'Yang Ching Shun',
            'Yip Kin Ling Leo': 'Yip Kin Ling',
            'Kin-Ling Yip': "Yip Kin Ling",
            'Yousseff Jalar':'Yousseff Jaffar',
            'Yu-Hsuan Cheng':'Yu Hsuan Cheng',
            'Zhou Long (Poolbillardspieler)\xa0[Zhou': 'Zhou Long',   
            
        }

        # get() method of dictionary data type returns 
        # value of passed argument if it is present 
        # in dictionary otherwise second argument will
        # be assigned as default value of passed argument
        val = switcher.get(argument, "nothing")
        if val == "nothing":
            return argument
        else:
            return val
    
    lst = []
    for idx, item in enumerate(series): 
        lst.append(switcher(item))
    return(lst)
   
    

fulldf["playerA"] = deduplicate_names(fulldf["playerA"])

print("Should be 1: " + str(np.sum(fulldf["playerB"]== "Abder Rehman Mebarki")))
fulldf["playerB"] = deduplicate_names(fulldf["playerB"])
print("Should be 2: " + str(np.sum(fulldf["playerB"]== "Abder Rehman Mebarki")))
# Out:
# Should be 1: 2
# Should be 2: 2

# %%
players = pd.concat([fulldf.playerA, fulldf.playerB] )
sorted(list(players.unique()))[1000:len(list(players.unique()))]
# Out:
# ['Rico Diks',
#  'Ritchie Ogawa',
#  'Riyan Setiawan',
#  'Rob Hart',
#  'Rob Metz Jr',
#  'Rob Saez',
#  'Rob Sakell',
#  'Rob Staskowski',
#  'Robb Saez',
#  'Robbie Capito',
#  'Robby Foldvari',
#  'Robert Braga',
#  'Robert Ferry',
#  'Robert Goddard',
#  'Robert Hart',
#  'Robert Hewings',
#  'Roberto Brillantes',
#  'Roberto Gomez',
#  'Roberto Maione',
#  'Roderick Malone',
#  'Rodney Morris',
#  'Rodolfo Luat',
#  'Rodrigo Matias',
#  'Rogelio Belleca Sotero',
#  'Roger Miller',
#  'Roland Garcia',
#  'Roland Stock',
#  'Roman Hybler',
#  'Roman Schleiner',
#  'Ron Casanzio',
#  'Ron Hawes',
#  'Ron Williams',
#  'Ronald Mijatovic',
#  'Ronald Regli',
#  'Ronnie Alcano',
#  'Ruben Alves',
#  'Ruben Bautista',
#  'Ruslan Chinakhov',
#  'Ruslan Popescu',
#  'Russ Randall',
#  'Ryan Dacko',
#  'Ryo Yokawa',
#  'Ryoji Hori',
#  'Ryu Seung-woo',
#  'Saad-Ali Aldrees',
#  'Sakis Lainas',
#  'Salah Al Riwani',
#  'Samantha Barrett',
#  'Sameer al-Madhi',
#  'Sami Koylu',
#  'Samuel Santos',
#  'Sandor Tot',
#  'Sanjin Pehlivanovic',
#  'Santos Sambajon',
#  'Sascha Specchia',
#  'Sascha Trautmann',
#  'Sascha-Andrej Tege',
#  'Satoshi Kawabata',
#  'Savga Serghei',
#  'Sayeem Hossain',
#  'Scott Frost',
#  'Scott Higgins',
#  'Sean Morgan',
#  'Sebastian Batkowski',
#  'Sebastian Laramee',
#  'Sebastian Ludwig',
#  'Sebastian Mihai Ionita',
#  'Sebastian Staab',
#  'Seiji Kuwajima',
#  'Serge Das',
#  'Sergey Lutsker',
#  'Sergio Gandolfi',
#  'Sergio Lagunas',
#  'Sergiu Voicu',
#  'Shahbaz Adil Khan',
#  'Shane McMinn',
#  'Shane Van Boening',
#  'Shannon Daulton',
#  'Shannon Ducharme',
#  'Shannon Murphy',
#  'Sharik Aslam Sayed',
#  'Shaun Wilkie',
#  'Shawn Putnam',
#  'Siming Chen',
#  'Simo Saarniit',
#  'Simon Pickering',
#  'Sinha Fahim',
#  'Skyler Woodward',
#  'Slobodan Banjanac',
#  'So Shaw',
#  'Soheil Vahedi',
#  'Sonia Simionov',
#  'Sorin Nicolae Son',
#  'Spasian Spasov',
#  'Spataru Razvan Ilie',
#  'Spencer Auigbelle',
#  'Spencer Ladin',
#  'Stamatis Katsatos',
#  'Stan Tourangeau',
#  'Stanimir Ruslanow',
#  'Stanley Walton',
#  'Stefan Boaca',
#  'Stefan Danescu',
#  'Stefan Gruber',
#  'Stefan Huber',
#  'Stefan Sprangers',
#  'Stefano Dellino',
#  'Stephan Cohen',
#  'Stephen Defrasnes',
#  'Stephen Folan',
#  'Stephen Holem',
#  'Stephen Webber',
#  'Stevan Radenkovic',
#  'Steve Fleming',
#  'Steve Heeb',
#  'Steve Ho Lem',
#  'Steve Lillis',
#  'Steve Lingelbach',
#  'Steve Motilal',
#  'Steve Van Ness',
#  'Steven Lingafelter',
#  'Steven W Smith',
#  'Stevie Moore',
#  'Sundeep Gulati',
#  'Szu-Ting Kuo',
#  'Taher Hussain',
#  'Tahsin Kaplan',
#  'Takashi Uraoka',
#  'Takhti Zarekani',
#  'Tal Frank',
#  'Taner Ayvaz',
#  'Tao Ying Duo',
#  'Taqi Aldin Moustafawi',
#  'Teck Goh Chin',
#  'Thanasis Arguropoulos',
#  'The Kien Do',
#  'Thomas Charmantzis',
#  'Thomas Engert',
#  'Thomas Kaplan',
#  'Thomas Knittel',
#  'Thomas Poeschi',
#  'Thomas Poschl',
#  'Thomas Tokoph',
#  'Thomas Welle',
#  'Thomasz Kaplan',
#  'Thorsten Bonke',
#  'Thorsten Hohmann',
#  'Tiberiu Iorgulescu',
#  'Tim De Ruyter',
#  'Tim Jonkman',
#  'Toan Nguyen',
#  'Tobias Bongers',
#  'Toh Lian Han',
#  "Tom D'alfonso",
#  'Tom Gildea',
#  'Tom Griffith',
#  'Tom Karabotsos',
#  'Tom Staveley',
#  'Tom Teriault',
#  'Tom Zippler',
#  'Tomasz Kaplan',
#  'Tommi Harmaala',
#  'Tommie Yates',
#  'Tommy Kennedy',
#  'Tommy Najar',
#  'Tommy Tokoph',
#  'Tomoki Mekari',
#  'Tomoo Takano',
#  'Tomoya Iima',
#  'Toni Judet',
#  'Tony Antone',
#  'Tony Chohan',
#  'Tony Crosby',
#  'Tony Drago',
#  'Tony Robles',
#  'Torsten Schmitt',
#  'Toru Kuribayashi',
#  'Traian Marinca',
#  'Trif Alexandru Claudiu',
#  'Tudor Spulber',
#  'Tyler Fleshman',
#  'Tyler Styer',
#  'Uorsin Candrian',
#  'Vaggelis Gkremos',
#  'Vahdet Emre Varlik',
#  'Valentin Dinu',
#  'Valentin Laslau',
#  'Valeriia Trushevskaia',
#  'Valerio Castellano',
#  'Valery Kuloyants',
#  'Vang Bui Xuan',
#  'Vangelis Gremos',
#  'Vasile Cozma',
#  'Vasileios Zoidis',
#  'Vegar Kristiansen',
#  'Venancio Tanio',
#  'Viacheslav Skvortsov',
#  'Vicenancio Tanio',
#  'Victor Toma',
#  'Ville Hamalainen',
#  'Vilmos Foldes',
#  'Vincent Facquet',
#  'Vincent Gomez',
#  'Vincent Halliday',
#  'Vitaliy Patsura',
#  'Vlad Adrian Moscalu',
#  'Vladica Brkovic',
#  'Vladimir Babic',
#  'Vladimir Matvienko',
#  'Voiculescu Ciprian',
#  'Volosciuc Corneliu',
#  'Wael Tallat',
#  'Waleed Majid',
#  'Wang Can',
#  'Warren Kiamco',
#  'Wiktor Zielinski',
#  'Wilhelm Georg',
#  'Willie Oney',
#  'Wim Scrayen',
#  'Witalij Pazura',
#  'Wojciech Sroczynski',
#  'Wojciech Szewczyk',
#  'Wojciech Trajdos',
#  'Wu Jiaqing',
#  'Wu Kun-Lin',
#  'Xu Xiaocong',
#  'Yang Ching Shun',
#  'Yannick Pongers',
#  'Yasin Kartal',
#  'Yip Kin Ling',
#  'Yorben Vervondel',
#  'Yousseff Jaffar',
#  'Yu Hsuan Cheng',
#  'Yu-Lung Chang',
#  'Yukio Akakariyama',
#  'Yvonne Ullmann-Hybler',
#  'Zachary Bos',
#  'Zapryan Zapryanov',
#  'Zdenko Lisik',
#  'Zhou Long',
#  'Zhu Xihe',
#  'Zine el-Abidine Cherif',
#  'Zion Zvi',
#  'Zoran Krstic',
#  'Zoran Pucar',
#  'Zoran Svilar',
#  'Zurab Tsereteli',
#  'ciech Szewczyk',
#  'valer florin tundra',
#  'Νικος Κασσελακης',
#  'Νικος Τσελιος']

# %%
players = pd.concat([fulldf.playerA, fulldf.playerB] )
print(players.value_counts().index.unique())
# How many players
nplayers = len(players.value_counts() )
nplayers
# Out:
# Index(['Shane Van Boening', 'Niels Feijen', 'Jayson Shaw', 'Eklent Kaci',
#        'Ralf Souquet', 'Albin Ouschan', 'Joshua Filler', 'Alex Kazakis',
#        'David Alcaide', 'Denis Grabe',
#        ...
#        'Hwang Yong', 'Kostas Zotos', 'Loukas Meidanis', 'Kristina Tkach',
#        'Tony Crosby', 'Marlon Caneda', 'Rob Metz Jr', 'Craig Hauck',
#        'Jamie White', 'Khanh Hoang Nguyen'],
#       dtype='object', length=1276)
# 1276

# %%
pd.set_option('display.max_rows', 1200)
pd.DataFrame(players.value_counts().index.unique()).sort_values(by=0)
# Out:
#                         0
# 189     (Ryan) Hsu Jui-An
# 793           A Greenwood
# 567       ANDREI GALATANU
# 873          Aayush Kumar
# 850              Abas Ali
# ...                   ...
# 643       Zurab Tsereteli
# 1148       ciech Szewczyk
# 507   valer florin tundra
# 1187     Νικος Κασσελακης
# 1181        Νικος Τσελιος
#
# [1276 rows x 1 columns]

# %%
np.sum(players.value_counts())
print(np.sum(players.value_counts() > 15))
print(np.sum(players.value_counts() > 30))
print(np.sum(players.value_counts() > 50))
players.value_counts()[players.value_counts() > 50]
# Out:
# 133
# 72
# 36
# Shane Van Boening         171
# Niels Feijen              159
# Jayson Shaw               131
# Eklent Kaci               127
# Ralf Souquet              125
# Albin Ouschan             121
# Joshua Filler             112
# Alex Kazakis              109
# David Alcaide             104
# Denis Grabe               102
# Ruslan Chinakhov           95
# Darren Appleton            93
# Mario He                   92
# Fedor Gorst                90
# Dennis Orcollo             82
# Francisco Sanchez Ruiz     81
# Wojciech Szewczyk          77
# Mark Gray                  71
# Mika Immonen               70
# Alex Pagulayan             67
# Thorsten Hohmann           67
# Nikos Ekonomopoulos        66
# Wiktor Zielinski           66
# John Morra                 62
# Petri Makkonen             62
# Mieszko Fortunski          61
# Ko Pin Yi                  61
# Chris Melling              61
# Mateusz Sniegocki          60
# Nick van den Berg          57
# Konrad Juszczyszyn         57
# Carlo Biado                56
# Imran Majid                56
# Maximilian Lechner         55
# Nick Malai                 54
# Marc Bijsterbosch          52
# dtype: int64

# %%
fulldf = fulldf.drop(columns = 'matchNumber')

# %%
fulldf.to_csv('data/fulldf.csv')

# %%
fulldf
# Out:
#       matchIndex       date               playerA  playerARacks  \
# 0              1 2007-10-14     Shane Van Boening            11
# 1              2 2007-10-14     Ernesto Dominguez            11
# 2              3 2007-10-14           Tony Robles            11
# 3              4 2007-10-14          Louis Ulrich            11
# 4              5 2007-10-14  Francisco Bustamante            11
# ...          ...        ...                   ...           ...
# 5080           6 2020-12-02           Jayson Shaw             5
# 5081           8 2020-12-02           Fedor Gorst             5
# 5082          10 2020-12-02           Jayson Shaw             5
# 5083          12 2020-12-03         Joshua Filler             5
# 5084          14 2020-12-03           Jayson Shaw             5
#
#                 playerB  playerBRacks          competition
# 0         Ronnie Alcano             4  2007 US Open 9-Ball
# 1     Frankie Hernandez             5  2007 US Open 9-Ball
# 2       Rafael Martinez             5  2007 US Open 9-Ball
# 3        Alex Pagulayan             7  2007 US Open 9-Ball
# 4           Richie Orem             4  2007 US Open 9-Ball
# ...                 ...           ...                  ...
# 5080  Shane Van Boening             4     2020 Mosconi Cup
# 5081        Corey Deuel             2     2020 Mosconi Cup
# 5082       Billy Thorpe             3     2020 Mosconi Cup
# 5083    Skyler Woodward             0     2020 Mosconi Cup
# 5084  Shane Van Boening             3     2020 Mosconi Cup
#
# [5085 rows x 7 columns]

# %%
fulldf['date'].groupby([fulldf.date.dt.year]).agg('count')
# Out:
# date
# 2007      14
# 2008      17
# 2009      19
# 2010     288
# 2011     113
# 2012     118
# 2013     118
# 2014     115
# 2015     280
# 2016     384
# 2017     700
# 2018     649
# 2019    1669
# 2020     601
# Name: date, dtype: int64

# %%
len(fulldf.competition.unique())
# Out:
# 94

# %%
np.sum(fulldf.playerARacks) + np.sum(fulldf.playerBRacks)
# Out:
# 72530
